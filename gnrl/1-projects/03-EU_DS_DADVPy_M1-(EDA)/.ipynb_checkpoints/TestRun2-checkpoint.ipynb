# %%
### Comment Lines and useful info, commands

#grp_inx = list(df[df['make_model'] == 'Audi A3']['Body'].index)
#df[df["make_model"] == "Audi A3"]["body_type"].mode() ### Audi a3 lerdeki en cok body type.
#oto[col_name].iloc[grp_inx] = oto[col_name].iloc[grp_inx].fillna()
##############################################################################################
#[i for i in df.columns if df[i].notna().mean() < 0.5]
#############################################
#Fill previous Owners column with bfill to make homogenious distrbution
#df["Previous Owners1"] =  df["Previous Owners1"].fillna(method="bfill")
##############################################################################################

# in future i will update here to drop columns
# for i in df.columns:
#     if df.index.stop == df[i].isnull().sum():
#         print("------------------------->",i,df[i].isnull().sum())
#     print(i,df[i].isnull().sum())
##############################################################################################
# to see data in desired counts 
#pd.options.display.max_columns = 15
#pd.options.display.max_rows = 6
#############################################################################################
#df[["price"]].sort_values(by="price",axis=0)
#############################################################################################
#Delete rows that price is lower than 500Euros
#df.drop(df[df["price"]<500].index,inplace=True)
#############################################################################################
#df[["price"]].dropna()
#############################################################################################
#sns.boxplot(x='price',data = df)
#############################################################################################
#get_df_wo_outlier(df,"price")
#############################################################################################
#df.columns
#############################################################################################
#fix values at rows by deleting "\n" in it.
#dfdeneme  = df.replace("\n","")
#############################################################################################
#to have a quick look at data, which columns contain what and how many.
#for i in df.columns:
    #print(df[i].value_counts().rename_axis(i +' unique_values').reset_index(name=i +' counts'))
#############################################################################################    
# important_columns = ['make_model',
# 'km',
# 'registration',
# 'Type',
# 'Body',
# 'Gearing Type',
# 'Drive chain',
# 'Fuel',
# 'Consumption',
# 'Comfort & Convenience',
# 'Entertainment & Media',
# 'Extras',
# 'Safety & Security',
# 'Gears',
# 'Country version',
# 'Last Service Date']
#df[important_columns]
#############################################################################################
# if str(df.at[2765, 'Type'] == 'nan'):
#     print("sss")
# else:
#     print("aaa")
#############################################################################################
#get_all_df(df)
#df = df.astype({"Country version" : "str"})
#############################################################################################
#Convert list type columns to new column with list`s elements
# df = list_to_columns_add2(df,"Full Service") #### NO need to convert NAN to List..
# df = list_to_columns_add2(df,"Consumption") #### NO need to convert NAN to List..
# df = list_to_columns_add2(df,"Type") #### NO need to convert NAN to List..
#df  = list_to_columns_add2(df,"Country version")
#############################################################################################
#Nan_to_list(df,"Country version")
#df  = list_to_columns_add2(df,"Country version")
#df[["Country version"]]
#df[["Country version"]] = df[["Country version"]].replace('\\n',np.NaN, regex=True)
#df[["Country version"]]
#############################################################################################
#for i in df.columns:
    #print(i)
#############################################################################################
#print( [i for i in df["Body"][0] if i!='\n'] )
#############################################################################################
#list_of_columns
#non_list_of_columns
#############################################################################################
#pd.options.display.max_columns = 14
#pd.options.display.max_rows = 5
#df.columns.to_list()

# %% [markdown]
# # Functions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy.stats import zscore
import numpy as np
import itertools
import warnings
warnings.filterwarnings("ignore")

# %%
#Functions :
#convert lists values to new columns with this no need to change column type to string or NAN to [] values normally requires before applying below.
def list_to_columns(df,col): 
    dftemp = pd.DataFrame([pd.Series(x) for x in df[col]]) # that is better and quicker. no need to run NAN_to_list.?
    column_names= []
    max_element = len(max(df.loc[df[col].apply(lambda x : isinstance(x, list))][col], key=len))
    #max_element = len(max(df.loc[df[col].notna()][col], key=len))
    for i in range(max_element):
        column_names.append(col + str(i+1))
    dftemp.columns = column_names
    df = df.drop(col,axis=1)
    if max_element == 1:
        dftemp.rename(columns={col+'1': col},inplace = True)
    df_added = pd.concat([df, dftemp], axis=1, sort=False)
    return df_added

#Convert list of features as new columns and check if that feature exist on that car or not.
def list_to_feat_cols(df,col_list):
    dftemp = pd.DataFrame()
    for col in col_list:
        #max_list = max(df.loc[df[col].apply(lambda x : isinstance(x, list))][col], key=len)
        a = df[col].explode().unique()
        max_list = sorted([i for i in a if not pd.isnull(list(a)[list(a).index(i)])])
        for i in range(len(max_list)):
            dftemp[f"{col} {str(i+1)} {max_list[i]}"] = df[col].apply(lambda x : True if (type(x) == list and max_list[i] in x) \
               else (False if (type(x) == list and max_list[i] not in x) else x ))
        df = df.drop(col,axis=1)
    df_added = pd.concat([df, dftemp], axis=1, sort=False)
    return df_added


# check a column if it contains list of values. returns 2 list that we need to define
def check_is_list(df):
    list_of_columns = []
    non_list_of_columns = []
    for i in df.columns:
        counter_list=0
        counter_non_list=0
        for j in df[i].values:
            if isinstance(j, list):
                counter_list+=1
            else:
                counter_non_list+=1
        if counter_list > 0:
            list_of_columns.append(i)
        else :
            non_list_of_columns.append(i)
    return list_of_columns,non_list_of_columns
#changes a phrase in a list to another value
def del_str_phrase(phrase,liste):
    while(phrase in liste) : 
        liste.remove(phrase)
        
#get the df colon without outliers specified
def get_df_wo_outlier(df,col,range=1.5):
    Q1 = df[col].quantile(q=0.25)
    Q3 = df[col].quantile(q=0.75)
    IQR = Q3-Q1
    return df[col][~((df[col] <  Q1-(range*IQR)) |(df[col] > Q3+(range*IQR))) ]

#to have a look at data, which columns contain what and how many.
def get_all_df(df):
    for i in df.columns:
        print(df[i].value_counts(dropna = False).rename_axis(i +' unique_values').reset_index(name=i +' counts'))

#quick look on a column        
def get_col_details(df,col):
    print("VALUE COUNTS")
    print(df[col].value_counts(dropna=False))
    print("-----------------------\n","UNIQUE VALUES")
    print(df[col].unique())
    print("-----------------------\n","NULL SUM")
    print(df[col].isnull().sum())
    print("-----------------------\n","NULL Percentage")
    print(df[col].isnull().sum()*100 /df[col].index.stop )
    print("-----------------------\n","COLUMN with NONE-NULL-NAN")
    print(df.query(f'{col} != {col}')[col])
    
#updates values NAN to empty list : []
def Nan_to_list(df,col):
    Nan_rows = df[col].isnull()
    df.loc[Nan_rows,col] = df.loc[Nan_rows,col].apply(lambda x : [])
    
def outlier_zscore(df, col, min_z=1, max_z = 5, step = 0.1, print_list = False):
    z_scores = zscore(df[col].dropna())
    threshold_list = []
    for threshold in np.arange(min_z, max_z, step):
        threshold_list.append((threshold, len(np.where(z_scores > threshold)[0])))
        df_outlier = pd.DataFrame(threshold_list, columns = ['threshold', 'outlier_count'])
        df_outlier['pct'] = (df_outlier.outlier_count - df_outlier.outlier_count.shift(-1))/df_outlier.outlier_count*100
    plt.plot(df_outlier.threshold, df_outlier.outlier_count)
    best_treshold = round(df_outlier.iloc[df_outlier.pct.argmax(), 0],2)
    outlier_limit = int(df[col].dropna().mean() + (df[col].dropna().std()) * df_outlier.iloc[df_outlier.pct.argmax(), 0])
    percentile_threshold = stats.percentileofscore(df[col].dropna(), outlier_limit)
    plt.vlines(best_treshold, 0, df_outlier.outlier_count.max(), 
               colors="r", ls = ":"
              )
    plt.annotate("Zscore : {}\nValue : {}\nPercentile : {}".format(best_treshold, outlier_limit, 
                                                                   (np.round(percentile_threshold, 3), 
                                                                    np.round(100-percentile_threshold, 3))), 
                 (best_treshold, df_outlier.outlier_count.max()/2))
    #plt.show()
    if print_list:
        print(df_outlier)
    return (plt, df_outlier, best_treshold, outlier_limit, percentile)

def outlier_inspect(df, col, min_z=1, max_z = 5, step = 0.5, max_hist = None, bins = 50):
    fig = plt.figure(figsize=(20, 6))
    fig.suptitle(col, fontsize=16)
    plt.subplot(1,3,1)
    if max_hist == None:
        sns.distplot(df[col], kde=False, bins = 50)
    else :
        sns.distplot(df[df[col]<=max_hist][col], kde=False, bins = 50)
    plt.subplot(1,3,2)
    sns.boxplot(df[col])
    plt.subplot(1,3,3)
    z_score_inspect = outlier_zscore(df, col, min_z=min_z, max_z = max_z, step = step)
    plt.show()

# %%
# Fills missing values with combination of columns, Follows priority 
#firstly tries 3 column combination and fills nulls and applies remaining nulls with 2 colum combination and so on.
def fill_most_with1_temp(df,target_col,ref_col1):
    df_temp = df[[ref_col1,target_col]]
    for group1 in list(df_temp[ref_col1].unique()):
        grp_inx = list(df_temp[(df_temp[ref_col1]==group1)][target_col].index)
        try:
            fill_value = df_temp[(df_temp[ref_col1] == group1)][target_col].mode()[0]
        except:
            fill_value = 'NaN'
            continue
        df_temp[target_col].iloc[grp_inx] = df_temp[target_col].iloc[grp_inx].fillna(fill_value)
    return df_temp
def fill_most_with1_perm(df,target_col,ref_col1):
    for group1 in list(df[ref_col1].unique()):
        grp_inx = list(df[(df[ref_col1]==group1)][target_col].index)
        try:
            fill_value = df[(df[ref_col1] == group1)][target_col].mode()[0]
        except:
            fill_value = 'NaN'
            continue
        df[target_col].iloc[grp_inx] = df[target_col].iloc[grp_inx].fillna(fill_value)
    return df
def fill_most_with2_temp(df,target_col,col1, col2):
    df_temp = df[[col1,col2,target_col]]
    for group1 in list(df_temp[col1].unique()):
        for group2 in list(df_temp[df_temp[col1]==group1][col2].unique()):
            grp_inx = list(df_temp[(df_temp[col1]==group1) & (df_temp[col2] == group2)][target_col].index)
            try:
                fill_value = df_temp[(df_temp[col1] == group1) & (df_temp[col2] == group2)][target_col].mode()[0]
            except:
                fill_value = 'NaN'
                continue
            df_temp[target_col].iloc[grp_inx] = df_temp[target_col].iloc[grp_inx].fillna(fill_value)  
    return df_temp
def fill_most_with2_perm(df,target_col, col1, col2):
    for group1 in list(df[col1].unique()):
        for group2 in list(df[df[col1]==group1][col2].unique()):
            grp_inx = list(df[(df[col1]==group1) & (df[col2] == group2)][target_col].index)
            try:
                fill_value = df[(df[col1] == group1) & (df[col2] == group2)][target_col].mode()[0]
            except:
                fill_value = 'NaN'
                continue
            df[target_col].iloc[grp_inx] = df[target_col].iloc[grp_inx].fillna(fill_value)  
    return df
#df[(df["Make"] == "Audi") & (df["Model2"] == "A3")  & (df["Displacement (cc)"] == 1.5)]["body_type"].mode()[0]
def fill_most_with3_temp(df,target_col,col1, col2, col3):
    df_temp = df[[col1,col2,col3,target_col]]
    for group1 in list(df_temp[col1].unique()):
        for group2 in list(df_temp[df_temp[col1]==group1][col2].unique()):
            for group3 in list(df_temp[(df_temp[col1]==group1) & (df_temp[col2]==group2)][col3].unique()):
                grp_inx = list(df_temp[(df_temp[col1]==group1) & (df_temp[col2] == group2)& (df_temp[col3]==group3)][target_col].index)
                try:
                    fill_value = df_temp[(df_temp[col1] == group1) & (df_temp[col2] == group2) & (df_temp[col3] == group3)][target_col].mode()[0]
                except:
                    fill_value = 'NaN'
                    continue
                df_temp[target_col].iloc[grp_inx] = df_temp[target_col].iloc[grp_inx].fillna(fill_value)  
    return df_temp



def fill_most_with3_perm(df,target_col,col1, col2, col3):
    for group1 in list(df[col1].unique()):
        for group2 in list(df[df[col1]==group1][col2].unique()):
            for group3 in list(df[(df[col1]==group1) & (df[col2] == group2)][col3].unique()):
                grp_inx = list(df[(df[col1]==group1) & (df[col2] == group2)& (df[col3]==group3)][target_col].index)
                try:
                    fill_value = df[(df[col1] == group1) & (df[col2] == group2) & (df[col3] == group3)][target_col].mode()[0]
                except:
                    fill_value = 'NaN'
                    continue
                df[target_col].iloc[grp_inx] = df[target_col].iloc[grp_inx].fillna(fill_value)  
    return df

def fill_priority_perm(df,target_col,col1, col2, col3):
    fill_most_with3_perm(df,target_col,col1, col2, col3)
    fill_most_with2_perm(df,target_col,col1, col2)
    fill_most_with1_perm(df,target_col,col1)
    return df

def fill_priority_temp(df,target_col,col1, col2, col3):
    df_temp1 = fill_most_with3_temp(df,target_col,col1, col2, col3)
    df_temp2 = fill_most_with2_temp(df_temp1,target_col,col1, col2)
    df_temp3 = fill_most_with1_temp(df_temp2,target_col,col1)
    return df_temp3

# %% [markdown]
# # Entrance

# %%
# read json file with lines method.
df = pd.read_json("scout_car.json", lines=True)

# %%
#lets see all column and value_counts
#get_all_df(df)

# %%
#fix column name by deleting "\n" in it.
df.rename(columns=lambda x: x.replace("\n",""),inplace=True)

# %%
pd.options.display.max_columns = 600
pd.options.display.max_rows = 6
df.head(2)
# Out:
#                                                  url make_model  \
# 0  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 1  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
#
#                              short_description body_type  price  \
# 0  Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                               1.8 TFSI sport    Sedans  14500
#
#                 vat         km registration         prev_owner  kW      hp  \
# 0    VAT deductible  56,013 km      01/2016  2 previous owners NaN   66 kW
# 1  Price negotiable  80,000 km      03/2017               None NaN  141 kW
#
#                                       Type Previous Owners  \
# 0  [, Used, , Diesel (Particulate Filter)]           \n2\n
# 1                     [, Used, , Gasoline]             NaN
#
#                          Next Inspection         Inspection new  \
# 0  [\n06/2021\n, \n99 g CO2/km (comb)\n]  [\nYes\n, \nEuro 6\n]
# 1                                    NaN                    NaN
#
#                   Warranty Full Service Non-smoking Vehicle null      Make  \
# 0  [\n, \n, \n4 (Green)\n]     [\n, \n]            [\n, \n]   []  \nAudi\n
# 1                      NaN          NaN                 NaN   []  \nAudi\n
#
#           Model     Offer Number First Registration       Body Color  \
# 0  [\n, A1, \n]  [\nLR-062483\n]     [\n, 2016, \n]  [\n, Black, \n]
# 1  [\n, A1, \n]              NaN     [\n, 2017, \n]    [\n, Red, \n]
#
#        Paint Type  Body Color Original          Upholstery              Body  \
# 0  [\nMetallic\n]  [\nMythosschwarz\n]  [\nCloth, Black\n]  [\n, Sedans, \n]
# 1             NaN                  NaN   [\nCloth, Grey\n]  [\n, Sedans, \n]
#
#   Nr. of Doors Nr. of Seats      Model Code         Gearing Type  \
# 0      [\n5\n]      [\n5\n]  [\n0588/BDF\n]  [\n, Automatic, \n]
# 1      [\n3\n]      [\n4\n]  [\n0588/BCY\n]  [\n, Automatic, \n]
#
#      Displacement Cylinders          Weight  Drive chain  \
# 0  [\n1,422 cc\n]   [\n3\n]  [\n1,220 kg\n]  [\nfront\n]
# 1  [\n1,798 cc\n]   [\n4\n]  [\n1,255 kg\n]  [\nfront\n]
#
#                                     Fuel  \
# 0  [\n, Diesel (Particulate Filter), \n]
# 1                     [\n, Gasoline, \n]
#
#                                          Consumption  \
# 0  [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1  [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
#
#                 CO2 Emission Emission Class  \
# 0   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]
# 1  [\n129 g CO2/km (comb)\n]   [\nEuro 6\n]
#
#                                Comfort & Convenience  \
# 0  [Air conditioning, Armrest, Automatic climate ...
# 1  [Air conditioning, Automatic climate control, ...
#
#                                Entertainment & Media  \
# 0  [Bluetooth, Hands-free equipment, On-board com...
# 1  [Bluetooth, Hands-free equipment, On-board com...
#
#                                               Extras  \
# 0  [Alloy wheels, Catalytic Converter, Voice Cont...
# 1  [Alloy wheels, Sport seats, Sport suspension, ...
#
#                                    Safety & Security  \
# 0  [ABS, Central door lock, Daytime running light...
# 1  [ABS, Central door lock, Central door lock wit...
#
#                                          description   Emission Label  \
# 0  [\n, Sicherheit:,  , Deaktivierung für Beifahr...              NaN
# 1  [\nLangstreckenfahrzeug daher die hohe Kilomet...  [\n4 (Green)\n]
#
#      Gears Country version Electricity consumption Last Service Date  \
# 0      NaN             NaN                     NaN               NaN
# 1  [\n7\n]             NaN                     NaN               NaN
#
#   Other Fuel Types Availability Last Timing Belt Service Date Available from
# 0              NaN          NaN                           NaN            NaN
# 1              NaN          NaN                           NaN            NaN

# %%
#drop unnecessary columns #subjectif decision

#no need = 'url', 'description','Offer Number'
#same info already exist = "Make","Model","Body2", "prev_owner" ("make_model" we will use this)
unnecassary_columns = ['url', 'description', 'Offer Number',"prev_owner","Model Code","Weight","Make","Model"]
for i in unnecassary_columns:
    try:
        df.drop(i,axis=1,inplace=True)
    except:
        pass

# %%
df.head(2)
# Out:
#   make_model                            short_description body_type  price  \
# 0    Audi A1  Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1    Audi A1                               1.8 TFSI sport    Sedans  14500
#
#                 vat         km registration  kW      hp  \
# 0    VAT deductible  56,013 km      01/2016 NaN   66 kW
# 1  Price negotiable  80,000 km      03/2017 NaN  141 kW
#
#                                       Type Previous Owners  \
# 0  [, Used, , Diesel (Particulate Filter)]           \n2\n
# 1                     [, Used, , Gasoline]             NaN
#
#                          Next Inspection         Inspection new  \
# 0  [\n06/2021\n, \n99 g CO2/km (comb)\n]  [\nYes\n, \nEuro 6\n]
# 1                                    NaN                    NaN
#
#                   Warranty Full Service Non-smoking Vehicle null  \
# 0  [\n, \n, \n4 (Green)\n]     [\n, \n]            [\n, \n]   []
# 1                      NaN          NaN                 NaN   []
#
#   First Registration       Body Color      Paint Type  Body Color Original  \
# 0     [\n, 2016, \n]  [\n, Black, \n]  [\nMetallic\n]  [\nMythosschwarz\n]
# 1     [\n, 2017, \n]    [\n, Red, \n]             NaN                  NaN
#
#            Upholstery              Body Nr. of Doors Nr. of Seats  \
# 0  [\nCloth, Black\n]  [\n, Sedans, \n]      [\n5\n]      [\n5\n]
# 1   [\nCloth, Grey\n]  [\n, Sedans, \n]      [\n3\n]      [\n4\n]
#
#           Gearing Type    Displacement Cylinders  Drive chain  \
# 0  [\n, Automatic, \n]  [\n1,422 cc\n]   [\n3\n]  [\nfront\n]
# 1  [\n, Automatic, \n]  [\n1,798 cc\n]   [\n4\n]  [\nfront\n]
#
#                                     Fuel  \
# 0  [\n, Diesel (Particulate Filter), \n]
# 1                     [\n, Gasoline, \n]
#
#                                          Consumption  \
# 0  [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1  [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
#
#                 CO2 Emission Emission Class  \
# 0   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]
# 1  [\n129 g CO2/km (comb)\n]   [\nEuro 6\n]
#
#                                Comfort & Convenience  \
# 0  [Air conditioning, Armrest, Automatic climate ...
# 1  [Air conditioning, Automatic climate control, ...
#
#                                Entertainment & Media  \
# 0  [Bluetooth, Hands-free equipment, On-board com...
# 1  [Bluetooth, Hands-free equipment, On-board com...
#
#                                               Extras  \
# 0  [Alloy wheels, Catalytic Converter, Voice Cont...
# 1  [Alloy wheels, Sport seats, Sport suspension, ...
#
#                                    Safety & Security   Emission Label  \
# 0  [ABS, Central door lock, Daytime running light...              NaN
# 1  [ABS, Central door lock, Central door lock wit...  [\n4 (Green)\n]
#
#      Gears Country version Electricity consumption Last Service Date  \
# 0      NaN             NaN                     NaN               NaN
# 1  [\n7\n]             NaN                     NaN               NaN
#
#   Other Fuel Types Availability Last Timing Belt Service Date Available from
# 0              NaN          NaN                           NaN            NaN
# 1              NaN          NaN                           NaN            NaN

# %% [markdown]
# # Convert lists to columns and common clean up for [ ],"" etc

# %%
#below columns are presents car features which affect the car price, we get Yes or No for the specific car Feature.
car_acc_list = ['Comfort & Convenience',"Safety & Security","Extras","Entertainment & Media"]
df = list_to_feat_cols(df,car_acc_list)

# %%
df.head(2)
# Out:
#   make_model                            short_description body_type  price  \
# 0    Audi A1  Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1    Audi A1                               1.8 TFSI sport    Sedans  14500
#
#                 vat         km registration  kW      hp  \
# 0    VAT deductible  56,013 km      01/2016 NaN   66 kW
# 1  Price negotiable  80,000 km      03/2017 NaN  141 kW
#
#                                       Type Previous Owners  \
# 0  [, Used, , Diesel (Particulate Filter)]           \n2\n
# 1                     [, Used, , Gasoline]             NaN
#
#                          Next Inspection         Inspection new  \
# 0  [\n06/2021\n, \n99 g CO2/km (comb)\n]  [\nYes\n, \nEuro 6\n]
# 1                                    NaN                    NaN
#
#                   Warranty Full Service Non-smoking Vehicle null  \
# 0  [\n, \n, \n4 (Green)\n]     [\n, \n]            [\n, \n]   []
# 1                      NaN          NaN                 NaN   []
#
#   First Registration       Body Color      Paint Type  Body Color Original  \
# 0     [\n, 2016, \n]  [\n, Black, \n]  [\nMetallic\n]  [\nMythosschwarz\n]
# 1     [\n, 2017, \n]    [\n, Red, \n]             NaN                  NaN
#
#            Upholstery              Body Nr. of Doors Nr. of Seats  \
# 0  [\nCloth, Black\n]  [\n, Sedans, \n]      [\n5\n]      [\n5\n]
# 1   [\nCloth, Grey\n]  [\n, Sedans, \n]      [\n3\n]      [\n4\n]
#
#           Gearing Type    Displacement Cylinders  Drive chain  \
# 0  [\n, Automatic, \n]  [\n1,422 cc\n]   [\n3\n]  [\nfront\n]
# 1  [\n, Automatic, \n]  [\n1,798 cc\n]   [\n4\n]  [\nfront\n]
#
#                                     Fuel  \
# 0  [\n, Diesel (Particulate Filter), \n]
# 1                     [\n, Gasoline, \n]
#
#                                          Consumption  \
# 0  [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1  [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
#
#                 CO2 Emission Emission Class   Emission Label    Gears  \
# 0   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]              NaN      NaN
# 1  [\n129 g CO2/km (comb)\n]   [\nEuro 6\n]  [\n4 (Green)\n]  [\n7\n]
#
#   Country version Electricity consumption Last Service Date Other Fuel Types  \
# 0             NaN                     NaN               NaN              NaN
# 1             NaN                     NaN               NaN              NaN
#
#   Availability Last Timing Belt Service Date Available from  \
# 0          NaN                           NaN            NaN
# 1          NaN                           NaN            NaN
#
#   Comfort & Convenience 1 Air conditioning  \
# 0                                     True
# 1                                     True
#
#   Comfort & Convenience 2 Air suspension Comfort & Convenience 3 Armrest  \
# 0                                  False                            True
# 1                                  False                           False
#
#   Comfort & Convenience 4 Automatic climate control  \
# 0                                              True
# 1                                              True
#
#   Comfort & Convenience 5 Auxiliary heating  \
# 0                                     False
# 1                                     False
#
#   Comfort & Convenience 6 Cruise control  \
# 0                                   True
# 1                                  False
#
#   Comfort & Convenience 7 Electric Starter  \
# 0                                    False
# 1                                    False
#
#   Comfort & Convenience 8 Electric tailgate  \
# 0                                     False
# 1                                     False
#
#   Comfort & Convenience 9 Electrical side mirrors  \
# 0                                            True
# 1                                           False
#
#   Comfort & Convenience 10 Electrically adjustable seats  \
# 0                                              False
# 1                                              False
#
#   Comfort & Convenience 11 Electrically heated windshield  \
# 0                                              False
# 1                                              False
#
#   Comfort & Convenience 12 Heads-up display  \
# 0                                     False
# 1                                     False
#
#   Comfort & Convenience 13 Heated steering wheel  \
# 0                                          False
# 1                                          False
#
#   Comfort & Convenience 14 Hill Holder  \
# 0                                 True
# 1                                 True
#
#   Comfort & Convenience 15 Keyless central door lock  \
# 0                                              False
# 1                                              False
#
#   Comfort & Convenience 16 Leather seats  \
# 0                                  False
# 1                                  False
#
#   Comfort & Convenience 17 Leather steering wheel  \
# 0                                            True
# 1                                            True
#
#   Comfort & Convenience 18 Light sensor  \
# 0                                  True
# 1                                 False
#
#   Comfort & Convenience 19 Lumbar support  \
# 0                                   False
# 1                                    True
#
#   Comfort & Convenience 20 Massage seats  \
# 0                                  False
# 1                                  False
#
#   Comfort & Convenience 21 Multi-function steering wheel  \
# 0                                               True
# 1                                              False
#
#   Comfort & Convenience 22 Navigation system  \
# 0                                       True
# 1                                      False
#
#   Comfort & Convenience 23 Panorama roof  \
# 0                                  False
# 1                                  False
#
#   Comfort & Convenience 24 Park Distance Control  \
# 0                                           True
# 1                                          False
#
#   Comfort & Convenience 25 Parking assist system camera  \
# 0                                              False
# 1                                              False
#
#   Comfort & Convenience 26 Parking assist system self-steering  \
# 0                                              False
# 1                                              False
#
#   Comfort & Convenience 27 Parking assist system sensors front  \
# 0                                              False
# 1                                              False
#
#   Comfort & Convenience 28 Parking assist system sensors rear  \
# 0                                               True
# 1                                               True
#
#   Comfort & Convenience 29 Power windows Comfort & Convenience 30 Rain sensor  \
# 0                                   True                                 True
# 1                                   True                                False
#
#   Comfort & Convenience 31 Seat heating  \
# 0                                  True
# 1                                 False
#
#   Comfort & Convenience 32 Seat ventilation  \
# 0                                     False
# 1                                     False
#
#   Comfort & Convenience 33 Split rear seats  \
# 0                                     False
# 1                                     False
#
#   Comfort & Convenience 34 Start-stop system Comfort & Convenience 35 Sunroof  \
# 0                                       True                            False
# 1                                       True                            False
#
#   Comfort & Convenience 36 Tinted windows  \
# 0                                   False
# 1                                    True
#
#   Comfort & Convenience 37 Wind deflector Comfort & Convenience 38 Windshield  \
# 0                                   False                               False
# 1                                   False                               False
#
#   Safety & Security 1 ABS Safety & Security 2 Adaptive Cruise Control  \
# 0                    True                                       False
# 1                    True                                       False
#
#   Safety & Security 3 Adaptive headlights Safety & Security 4 Alarm system  \
# 0                                   False                            False
# 1                                   False                            False
#
#   Safety & Security 5 Blind spot monitor  \
# 0                                  False
# 1                                  False
#
#   Safety & Security 6 Central door lock  \
# 0                                  True
# 1                                  True
#
#   Safety & Security 7 Central door lock with remote control  \
# 0                                              False
# 1                                               True
#
#   Safety & Security 8 Daytime running lights  \
# 0                                       True
# 1                                       True
#
#   Safety & Security 9 Driver drowsiness detection  \
# 0                                           False
# 1                                           False
#
#   Safety & Security 10 Driver-side airbag  \
# 0                                    True
# 1                                    True
#
#   Safety & Security 11 Electronic stability control  \
# 0                                              True
# 1                                              True
#
#   Safety & Security 12 Emergency brake assistant  \
# 0                                          False
# 1                                          False
#
#   Safety & Security 13 Emergency system Safety & Security 14 Fog lights  \
# 0                                 False                            True
# 1                                 False                           False
#
#   Safety & Security 15 Head airbag Safety & Security 16 Immobilizer  \
# 0                            False                             True
# 1                             True                             True
#
#   Safety & Security 17 Isofix Safety & Security 18 LED Daytime Running Lights  \
# 0                        True                                           False
# 1                        True                                           False
#
#   Safety & Security 19 LED Headlights  \
# 0                               False
# 1                               False
#
#   Safety & Security 20 Lane departure warning system  \
# 0                                              False
# 1                                              False
#
#   Safety & Security 21 Night view assist  \
# 0                                  False
# 1                                  False
#
#   Safety & Security 22 Passenger-side airbag  \
# 0                                       True
# 1                                       True
#
#   Safety & Security 23 Power steering Safety & Security 24 Rear airbag  \
# 0                                True                            False
# 1                                True                            False
#
#   Safety & Security 25 Side airbag  \
# 0                             True
# 1                             True
#
#   Safety & Security 26 Tire pressure monitoring system  \
# 0                                               True
# 1                                               True
#
#   Safety & Security 27 Traction control  \
# 0                                  True
# 1                                  True
#
#   Safety & Security 28 Traffic sign recognition  \
# 0                                         False
# 1                                         False
#
#   Safety & Security 29 Xenon headlights Extras 1 Alloy wheels  \
# 0                                  True                  True
# 1                                  True                  True
#
#   Extras 2 Cab or rented Car Extras 3 Catalytic Converter  \
# 0                      False                         True
# 1                      False                        False
#
#   Extras 4 Handicapped enabled Extras 5 Right hand drive Extras 6 Roof rack  \
# 0                        False                     False              False
# 1                        False                     False              False
#
#   Extras 7 Shift paddles Extras 8 Ski bag Extras 9 Sliding door  \
# 0                  False            False                 False
# 1                  False            False                 False
#
#   Extras 10 Sport package Extras 11 Sport seats Extras 12 Sport suspension  \
# 0                   False                 False                      False
# 1                   False                  True                       True
#
#   Extras 13 Touch screen Extras 14 Trailer hitch Extras 15 Tuned car  \
# 0                  False                   False               False
# 1                  False                   False               False
#
#   Extras 16 Voice Control Extras 17 Winter tyres  \
# 0                    True                  False
# 1                    True                  False
#
#   Entertainment & Media 1 Bluetooth Entertainment & Media 2 CD player  \
# 0                              True                             False
# 1                              True                             False
#
#   Entertainment & Media 3 Digital radio  \
# 0                                 False
# 1                                 False
#
#   Entertainment & Media 4 Hands-free equipment Entertainment & Media 5 MP3  \
# 0                                         True                       False
# 1                                         True                       False
#
#   Entertainment & Media 6 On-board computer Entertainment & Media 7 Radio  \
# 0                                      True                          True
# 1                                      True                          True
#
#   Entertainment & Media 8 Sound system Entertainment & Media 9 Television  \
# 0                                False                              False
# 1                                 True                              False
#
#   Entertainment & Media 10 USB
# 0                        False
# 1                        False

# %%
#here we figure out which column has values as a list and which not.
list_columns, nonlist_columns = check_is_list(df)

# %%
# now we will convert lists to columns, after removing "description" since its just a comment for car and does not affect the price.
for i in list_columns:
    df = list_to_columns(df,i)

# %%
#replace all "", [], \n, values to np.Nan or delete if possible in df
for i in df.columns:
    df[i] = df[i].replace("",np.NaN)
    df[i] = df[i].apply(lambda x: np.nan if (type(x) == list and len(x) == 0) else x) # convert [] to np.NAN
    try:
        df[i] = df[i].apply(lambda x: list(map(lambda x: x.strip(), x)) if type(x)==list else x)
    except:
        continue
    df[i] = df[i].apply(lambda x : np.NaN if x=='\n' else x)
    df[i] = df[i].apply(lambda x: (("".join(x.replace("\n",""))) if (type(x)==str and type(x) != float) else x) if x!=np.nan else x)

#repeat same steps 2nd time for check if there list in list at df if yes apply methods.
list_columns, nonlist_columns = check_is_list(df)
for i in list_columns:
    df = list_to_columns(df,i)

#replace all "", [], \n, values to np.Nan or delete if possible in df
for i in df.columns:
    df[i] = df[i].replace("",np.NaN)
    df[i] = df[i].apply(lambda x: np.nan if (type(x) == list and len(x) == 0) else x) # convert [] to np.NAN
    try:
        df[i] = df[i].apply(lambda x: list(map(lambda x: x.strip(), x)) if type(x)==list else x)
    except:
        continue
    df[i] = df[i].apply(lambda x : np.NaN if x=='\n' else x)
    df[i] = df[i].apply(lambda x: (("".join(x.replace("\n",""))) if (type(x)==str and type(x) != float) else x) if x!=np.nan else x)

# %%
#get_all_df(df)

# %%
pd.options.display.max_columns = 600
pd.options.display.max_rows = 6
df.head()
# Out:
#   make_model                                  short_description body_type  \
# 0    Audi A1        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans
# 1    Audi A1                                     1.8 TFSI sport    Sedans
# 2    Audi A1  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans
# 3    Audi A1                            1.4 TDi Design S tronic    Sedans
# 4    Audi A1  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans
#
#    price               vat         km registration  kW      hp Availability  \
# 0  15770    VAT deductible  56,013 km      01/2016 NaN   66 kW          NaN
# 1  14500  Price negotiable  80,000 km      03/2017 NaN  141 kW          NaN
# 2  14640    VAT deductible  83,450 km      02/2016 NaN   85 kW          NaN
# 3  14500              None  73,000 km      08/2016 NaN   66 kW          NaN
# 4  16790              None  16,200 km      05/2016 NaN   66 kW          NaN
#
#   Available from Comfort & Convenience 1 Air conditioning  \
# 0            NaN                                     True
# 1            NaN                                     True
# 2            NaN                                     True
# 3            NaN                                    False
# 4            NaN                                     True
#
#   Comfort & Convenience 2 Air suspension Comfort & Convenience 3 Armrest  \
# 0                                  False                            True
# 1                                  False                           False
# 2                                  False                           False
# 3                                   True                            True
# 4                                  False                            True
#
#   Comfort & Convenience 4 Automatic climate control  \
# 0                                              True
# 1                                              True
# 2                                             False
# 3                                             False
# 4                                              True
#
#   Comfort & Convenience 5 Auxiliary heating  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                      True
# 4                                     False
#
#   Comfort & Convenience 6 Cruise control  \
# 0                                   True
# 1                                  False
# 2                                   True
# 3                                  False
# 4                                  False
#
#   Comfort & Convenience 7 Electric Starter  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#   Comfort & Convenience 8 Electric tailgate  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#   Comfort & Convenience 9 Electrical side mirrors  \
# 0                                            True
# 1                                           False
# 2                                            True
# 3                                            True
# 4                                            True
#
#   Comfort & Convenience 10 Electrically adjustable seats  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 11 Electrically heated windshield  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 12 Heads-up display  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                      True
# 4                                     False
#
#   Comfort & Convenience 13 Heated steering wheel  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#   Comfort & Convenience 14 Hill Holder  \
# 0                                 True
# 1                                 True
# 2                                 True
# 3                                 True
# 4                                 True
#
#   Comfort & Convenience 15 Keyless central door lock  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 16 Leather seats  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Comfort & Convenience 17 Leather steering wheel  \
# 0                                            True
# 1                                            True
# 2                                            True
# 3                                            True
# 4                                            True
#
#   Comfort & Convenience 18 Light sensor  \
# 0                                  True
# 1                                 False
# 2                                 False
# 3                                  True
# 4                                  True
#
#   Comfort & Convenience 19 Lumbar support  \
# 0                                   False
# 1                                    True
# 2                                   False
# 3                                    True
# 4                                   False
#
#   Comfort & Convenience 20 Massage seats  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Comfort & Convenience 21 Multi-function steering wheel  \
# 0                                               True
# 1                                              False
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Comfort & Convenience 22 Navigation system  \
# 0                                       True
# 1                                      False
# 2                                       True
# 3                                       True
# 4                                      False
#
#   Comfort & Convenience 23 Panorama roof  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Comfort & Convenience 24 Park Distance Control  \
# 0                                           True
# 1                                          False
# 2                                           True
# 3                                          False
# 4                                           True
#
#   Comfort & Convenience 25 Parking assist system camera  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 26 Parking assist system self-steering  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 27 Parking assist system sensors front  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 28 Parking assist system sensors rear  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                              False
# 4                                               True
#
#   Comfort & Convenience 29 Power windows Comfort & Convenience 30 Rain sensor  \
# 0                                   True                                 True
# 1                                   True                                False
# 2                                   True                                False
# 3                                   True                                 True
# 4                                   True                                 True
#
#   Comfort & Convenience 31 Seat heating  \
# 0                                  True
# 1                                 False
# 2                                  True
# 3                                  True
# 4                                 False
#
#   Comfort & Convenience 32 Seat ventilation  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#   Comfort & Convenience 33 Split rear seats  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                      True
# 4                                     False
#
#   Comfort & Convenience 34 Start-stop system Comfort & Convenience 35 Sunroof  \
# 0                                       True                            False
# 1                                       True                            False
# 2                                       True                            False
# 3                                       True                            False
# 4                                       True                            False
#
#   Comfort & Convenience 36 Tinted windows  \
# 0                                   False
# 1                                    True
# 2                                   False
# 3                                   False
# 4                                   False
#
#   Comfort & Convenience 37 Wind deflector Comfort & Convenience 38 Windshield  \
# 0                                   False                               False
# 1                                   False                               False
# 2                                   False                               False
# 3                                   False                               False
# 4                                   False                               False
#
#   Safety & Security 1 ABS Safety & Security 2 Adaptive Cruise Control  \
# 0                    True                                       False
# 1                    True                                       False
# 2                    True                                       False
# 3                    True                                       False
# 4                    True                                       False
#
#   Safety & Security 3 Adaptive headlights Safety & Security 4 Alarm system  \
# 0                                   False                            False
# 1                                   False                            False
# 2                                   False                            False
# 3                                   False                             True
# 4                                   False                            False
#
#   Safety & Security 5 Blind spot monitor  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Safety & Security 6 Central door lock  \
# 0                                  True
# 1                                  True
# 2                                  True
# 3                                 False
# 4                                  True
#
#   Safety & Security 7 Central door lock with remote control  \
# 0                                              False
# 1                                               True
# 2                                              False
# 3                                               True
# 4                                              False
#
#   Safety & Security 8 Daytime running lights  \
# 0                                       True
# 1                                       True
# 2                                       True
# 3                                      False
# 4                                      False
#
#   Safety & Security 9 Driver drowsiness detection  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                            True
# 4                                           False
#
#   Safety & Security 10 Driver-side airbag  \
# 0                                    True
# 1                                    True
# 2                                    True
# 3                                    True
# 4                                    True
#
#   Safety & Security 11 Electronic stability control  \
# 0                                              True
# 1                                              True
# 2                                              True
# 3                                              True
# 4                                              True
#
#   Safety & Security 12 Emergency brake assistant  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#   Safety & Security 13 Emergency system Safety & Security 14 Fog lights  \
# 0                                 False                            True
# 1                                 False                           False
# 2                                 False                           False
# 3                                  True                           False
# 4                                 False                            True
#
#   Safety & Security 15 Head airbag Safety & Security 16 Immobilizer  \
# 0                            False                             True
# 1                             True                             True
# 2                            False                             True
# 3                             True                             True
# 4                            False                             True
#
#   Safety & Security 17 Isofix Safety & Security 18 LED Daytime Running Lights  \
# 0                        True                                           False
# 1                        True                                           False
# 2                        True                                           False
# 3                        True                                           False
# 4                        True                                           False
#
#   Safety & Security 19 LED Headlights  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
#
#   Safety & Security 20 Lane departure warning system  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Safety & Security 21 Night view assist  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Safety & Security 22 Passenger-side airbag  \
# 0                                       True
# 1                                       True
# 2                                       True
# 3                                       True
# 4                                       True
#
#   Safety & Security 23 Power steering Safety & Security 24 Rear airbag  \
# 0                                True                            False
# 1                                True                            False
# 2                                True                            False
# 3                                True                            False
# 4                                True                            False
#
#   Safety & Security 25 Side airbag  \
# 0                             True
# 1                             True
# 2                             True
# 3                             True
# 4                             True
#
#   Safety & Security 26 Tire pressure monitoring system  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Safety & Security 27 Traction control  \
# 0                                  True
# 1                                  True
# 2                                  True
# 3                                 False
# 4                                  True
#
#   Safety & Security 28 Traffic sign recognition  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#   Safety & Security 29 Xenon headlights Extras 1 Alloy wheels  \
# 0                                  True                  True
# 1                                  True                  True
# 2                                 False                  True
# 3                                 False                  True
# 4                                  True                  True
#
#   Extras 2 Cab or rented Car Extras 3 Catalytic Converter  \
# 0                      False                         True
# 1                      False                        False
# 2                      False                        False
# 3                      False                        False
# 4                      False                        False
#
#   Extras 4 Handicapped enabled Extras 5 Right hand drive Extras 6 Roof rack  \
# 0                        False                     False              False
# 1                        False                     False              False
# 2                        False                     False              False
# 3                        False                     False              False
# 4                        False                     False              False
#
#   Extras 7 Shift paddles Extras 8 Ski bag Extras 9 Sliding door  \
# 0                  False            False                 False
# 1                  False            False                 False
# 2                  False            False                 False
# 3                  False            False                 False
# 4                  False            False                 False
#
#   Extras 10 Sport package Extras 11 Sport seats Extras 12 Sport suspension  \
# 0                   False                 False                      False
# 1                   False                  True                       True
# 2                   False                 False                      False
# 3                   False                  True                      False
# 4                    True                 False                       True
#
#   Extras 13 Touch screen Extras 14 Trailer hitch Extras 15 Tuned car  \
# 0                  False                   False               False
# 1                  False                   False               False
# 2                  False                   False               False
# 3                  False                   False               False
# 4                  False                   False               False
#
#   Extras 16 Voice Control Extras 17 Winter tyres  \
# 0                    True                  False
# 1                    True                  False
# 2                    True                  False
# 3                    True                  False
# 4                    True                  False
#
#   Entertainment & Media 1 Bluetooth Entertainment & Media 2 CD player  \
# 0                              True                             False
# 1                              True                             False
# 2                             False                             False
# 3                              True                              True
# 4                              True                              True
#
#   Entertainment & Media 3 Digital radio  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#   Entertainment & Media 4 Hands-free equipment Entertainment & Media 5 MP3  \
# 0                                         True                       False
# 1                                         True                       False
# 2                                        False                        True
# 3                                         True                        True
# 4                                         True                        True
#
#   Entertainment & Media 6 On-board computer Entertainment & Media 7 Radio  \
# 0                                      True                          True
# 1                                      True                          True
# 2                                      True                         False
# 3                                      True                          True
# 4                                      True                          True
#
#   Entertainment & Media 8 Sound system Entertainment & Media 9 Television  \
# 0                                False                              False
# 1                                 True                              False
# 2                                False                              False
# 3                                 True                              False
# 4                                False                              False
#
#   Entertainment & Media 10 USB  Type1 Type2  Type3  \
# 0                        False    NaN  Used    NaN
# 1                        False    NaN  Used    NaN
# 2                        False    NaN  Used    NaN
# 3                         True    NaN  Used    NaN
# 4                         True    NaN  Used    NaN
#
#                          Type4 Previous Owners1 Previous Owners2  \
# 0  Diesel (Particulate Filter)                2              NaN
# 1                     Gasoline              NaN              NaN
# 2  Diesel (Particulate Filter)                1              NaN
# 3  Diesel (Particulate Filter)                1              NaN
# 4  Diesel (Particulate Filter)                1              NaN
#
#   Previous Owners3  Previous Owners4 Previous Owners5  Previous Owners6  \
# 0              NaN               NaN              NaN               NaN
# 1              NaN               NaN              NaN               NaN
# 2              NaN               NaN              NaN               NaN
# 3              NaN               NaN              NaN               NaN
# 4              NaN               NaN              NaN               NaN
#
#   Previous Owners7  Previous Owners8 Next Inspection1    Next Inspection2  \
# 0              NaN               NaN          06/2021  99 g CO2/km (comb)
# 1              NaN               NaN              NaN                 NaN
# 2              NaN               NaN              NaN                 NaN
# 3              NaN               NaN              NaN                 NaN
# 4              NaN               NaN              NaN                 NaN
#
#   Next Inspection3  Next Inspection4 Next Inspection5  Next Inspection6  \
# 0              NaN               NaN              NaN               NaN
# 1              NaN               NaN              NaN               NaN
# 2              NaN               NaN              NaN               NaN
# 3              NaN               NaN              NaN               NaN
# 4              NaN               NaN              NaN               NaN
#
#   Next Inspection7  Next Inspection8 Inspection new1      Inspection new2  \
# 0              NaN               NaN             Yes               Euro 6
# 1              NaN               NaN             NaN                  NaN
# 2              NaN               NaN             NaN                  NaN
# 3              NaN               NaN             NaN                  NaN
# 4              NaN               NaN             Yes  109 g CO2/km (comb)
#
#   Inspection new3  Inspection new4 Inspection new5  Inspection new6  \
# 0             NaN              NaN             NaN              NaN
# 1             NaN              NaN             NaN              NaN
# 2             NaN              NaN             NaN              NaN
# 3             NaN              NaN             NaN              NaN
# 4             NaN              NaN             NaN              NaN
#
#   Inspection new7  Inspection new8 Warranty1 Warranty2           Warranty3  \
# 0             NaN              NaN       NaN       NaN           4 (Green)
# 1             NaN              NaN       NaN       NaN                 NaN
# 2             NaN              NaN       NaN       NaN  99 g CO2/km (comb)
# 3             NaN              NaN       NaN       NaN                 NaN
# 4             NaN              NaN       NaN       NaN              Euro 6
#
#   Warranty4 Warranty5 Warranty6 Warranty7 Warranty8  Warranty9  Full Service1  \
# 0       NaN       NaN       NaN       NaN       NaN        NaN            NaN
# 1       NaN       NaN       NaN       NaN       NaN        NaN            NaN
# 2       NaN       NaN       NaN       NaN       NaN        NaN            NaN
# 3       NaN       NaN       NaN       NaN       NaN        NaN            NaN
# 4       NaN       NaN       NaN       NaN       NaN        NaN            NaN
#
#    Full Service2       Full Service3 Full Service4  Full Service5  \
# 0            NaN                 NaN           NaN            NaN
# 1            NaN                 NaN           NaN            NaN
# 2            NaN                 NaN           NaN            NaN
# 3            NaN  99 g CO2/km (comb)           NaN            NaN
# 4            NaN           4 (Green)           NaN            NaN
#
#   Full Service6  Full Service7 Full Service8  Full Service9  \
# 0           NaN            NaN           NaN            NaN
# 1           NaN            NaN           NaN            NaN
# 2           NaN            NaN           NaN            NaN
# 3           NaN            NaN           NaN            NaN
# 4           NaN            NaN           NaN            NaN
#
#    Non-smoking Vehicle1  Non-smoking Vehicle2 Non-smoking Vehicle3  \
# 0                   NaN                   NaN                  NaN
# 1                   NaN                   NaN                  NaN
# 2                   NaN                   NaN                  NaN
# 3                   NaN                   NaN               Euro 6
# 4                   NaN                   NaN                  NaN
#
#   Non-smoking Vehicle4  Non-smoking Vehicle5 Non-smoking Vehicle6  \
# 0                  NaN                   NaN                  NaN
# 1                  NaN                   NaN                  NaN
# 2                  NaN                   NaN                  NaN
# 3                  NaN                   NaN                  NaN
# 4                  NaN                   NaN                  NaN
#
#    Non-smoking Vehicle7 Non-smoking Vehicle8  Non-smoking Vehicle9  \
# 0                   NaN                  NaN                   NaN
# 1                   NaN                  NaN                   NaN
# 2                   NaN                  NaN                   NaN
# 3                   NaN                  NaN                   NaN
# 4                   NaN                  NaN                   NaN
#
#    First Registration1 First Registration2  First Registration3  Body Color1  \
# 0                  NaN                2016                  NaN          NaN
# 1                  NaN                2017                  NaN          NaN
# 2                  NaN                2016                  NaN          NaN
# 3                  NaN                2016                  NaN          NaN
# 4                  NaN                2016                  NaN          NaN
#
#   Body Color2  Body Color3 Paint Type     Body Color Original    Upholstery  \
# 0       Black          NaN   Metallic           Mythosschwarz  Cloth, Black
# 1         Red          NaN        NaN                     NaN   Cloth, Grey
# 2       Black          NaN   Metallic  mythosschwarz metallic  Cloth, Black
# 3       Brown          NaN   Metallic                     NaN           NaN
# 4       Black          NaN   Metallic  Mythosschwarz Metallic  Cloth, Black
#
#    Body1   Body2  Body3 Nr. of Doors Nr. of Seats  Gearing Type1  \
# 0    NaN  Sedans    NaN            5            5            NaN
# 1    NaN  Sedans    NaN            3            4            NaN
# 2    NaN  Sedans    NaN            4            4            NaN
# 3    NaN  Sedans    NaN            3            4            NaN
# 4    NaN  Sedans    NaN            5            5            NaN
#
#   Gearing Type2  Gearing Type3 Displacement Cylinders Drive chain  Fuel1  \
# 0     Automatic            NaN     1,422 cc         3       front    NaN
# 1     Automatic            NaN     1,798 cc         4       front    NaN
# 2     Automatic            NaN     1,598 cc       NaN       front    NaN
# 3     Automatic            NaN     1,422 cc         3         NaN    NaN
# 4     Automatic            NaN     1,422 cc         3       front    NaN
#
#                          Fuel2  Fuel3 Consumption4  Consumption5 Consumption6  \
# 0  Diesel (Particulate Filter)    NaN          NaN           NaN          NaN
# 1                     Gasoline    NaN          NaN           NaN          NaN
# 2  Diesel (Particulate Filter)    NaN          NaN           NaN          NaN
# 3  Diesel (Particulate Filter)    NaN          NaN           NaN          NaN
# 4  Diesel (Particulate Filter)    NaN          NaN           NaN          NaN
#
#    Consumption7        CO2 Emission1  CO2 Emission2  CO2 Emission3  \
# 0           NaN   99 g CO2/km (comb)            NaN            NaN
# 1           NaN  129 g CO2/km (comb)            NaN            NaN
# 2           NaN   99 g CO2/km (comb)            NaN            NaN
# 3           NaN   99 g CO2/km (comb)            NaN            NaN
# 4           NaN  109 g CO2/km (comb)            NaN            NaN
#
#   Emission Class1  Emission Class2  Emission Class3 Emission Label1  \
# 0          Euro 6              NaN              NaN             NaN
# 1          Euro 6              NaN              NaN       4 (Green)
# 2          Euro 6              NaN              NaN       4 (Green)
# 3          Euro 6              NaN              NaN             NaN
# 4          Euro 6              NaN              NaN             NaN
#
#    Emission Label2  Emission Label3 Gears Country version  \
# 0              NaN              NaN   NaN             NaN
# 1              NaN              NaN     7             NaN
# 2              NaN              NaN   NaN             NaN
# 3              NaN              NaN     6             NaN
# 4              NaN              NaN   NaN         Germany
#
#   Electricity consumption Last Service Date1 Last Service Date2  \
# 0                     NaN                NaN                NaN
# 1                     NaN                NaN                NaN
# 2                     NaN                NaN                NaN
# 3                     NaN                NaN                NaN
# 4                     NaN                NaN                NaN
#
#   Last Service Date3  Last Service Date4 Last Service Date5  \
# 0                NaN                 NaN                NaN
# 1                NaN                 NaN                NaN
# 2                NaN                 NaN                NaN
# 3                NaN                 NaN                NaN
# 4                NaN                 NaN                NaN
#
#    Last Service Date6 Last Service Date7  Last Service Date8  \
# 0                 NaN                NaN                 NaN
# 1                 NaN                NaN                 NaN
# 2                 NaN                NaN                 NaN
# 3                 NaN                NaN                 NaN
# 4                 NaN                NaN                 NaN
#
#    Other Fuel Types1  Other Fuel Types2  Other Fuel Types3  \
# 0                NaN                NaN                NaN
# 1                NaN                NaN                NaN
# 2                NaN                NaN                NaN
# 3                NaN                NaN                NaN
# 4                NaN                NaN                NaN
#
#   Last Timing Belt Service Date1 Last Timing Belt Service Date2  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#           Consumption1         Consumption2            Consumption3
# 0  3.8 l/100 km (comb)  4.3 l/100 km (city)  3.5 l/100 km (country)
# 1  5.6 l/100 km (comb)  7.1 l/100 km (city)  4.7 l/100 km (country)
# 2  3.8 l/100 km (comb)  4.4 l/100 km (city)  3.4 l/100 km (country)
# 3  3.8 l/100 km (comb)  4.3 l/100 km (city)  3.5 l/100 km (country)
# 4  4.1 l/100 km (comb)  4.6 l/100 km (city)  3.8 l/100 km (country)

# %% [markdown]
# # Drop Columns

# %%
#drop columns that has lower than 30 percent valid value in it.
drop_30Perc = [i for i in df.columns if round(df[i].notna().mean()*100,2) < 30]
drop_30Perc
# Out:
# ['kW',
#  'Availability',
#  'Available from',
#  'Type1',
#  'Type3',
#  'Previous Owners2',
#  'Previous Owners3',
#  'Previous Owners4',
#  'Previous Owners5',
#  'Previous Owners6',
#  'Previous Owners7',
#  'Previous Owners8',
#  'Next Inspection1',
#  'Next Inspection2',
#  'Next Inspection3',
#  'Next Inspection4',
#  'Next Inspection5',
#  'Next Inspection6',
#  'Next Inspection7',
#  'Next Inspection8',
#  'Inspection new1',
#  'Inspection new2',
#  'Inspection new3',
#  'Inspection new4',
#  'Inspection new5',
#  'Inspection new6',
#  'Inspection new7',
#  'Inspection new8',
#  'Warranty2',
#  'Warranty3',
#  'Warranty4',
#  'Warranty5',
#  'Warranty6',
#  'Warranty7',
#  'Warranty8',
#  'Warranty9',
#  'Full Service1',
#  'Full Service2',
#  'Full Service4',
#  'Full Service5',
#  'Full Service6',
#  'Full Service7',
#  'Full Service8',
#  'Full Service9',
#  'Non-smoking Vehicle1',
#  'Non-smoking Vehicle2',
#  'Non-smoking Vehicle3',
#  'Non-smoking Vehicle4',
#  'Non-smoking Vehicle5',
#  'Non-smoking Vehicle6',
#  'Non-smoking Vehicle7',
#  'Non-smoking Vehicle8',
#  'Non-smoking Vehicle9',
#  'First Registration1',
#  'First Registration3',
#  'Body Color1',
#  'Body Color3',
#  'Body1',
#  'Body3',
#  'Gearing Type1',
#  'Gearing Type3',
#  'Fuel1',
#  'Fuel3',
#  'Consumption4',
#  'Consumption5',
#  'Consumption6',
#  'Consumption7',
#  'CO2 Emission2',
#  'CO2 Emission3',
#  'Emission Class2',
#  'Emission Class3',
#  'Emission Label1',
#  'Emission Label2',
#  'Emission Label3',
#  'Electricity consumption',
#  'Last Service Date1',
#  'Last Service Date2',
#  'Last Service Date3',
#  'Last Service Date4',
#  'Last Service Date5',
#  'Last Service Date6',
#  'Last Service Date7',
#  'Last Service Date8',
#  'Other Fuel Types1',
#  'Other Fuel Types2',
#  'Other Fuel Types3',
#  'Last Timing Belt Service Date1',
#  'Last Timing Belt Service Date2']

# %%
df.drop(drop_30Perc,axis=1,inplace=True)

# %%
df.head()
# Out:
#   make_model                                  short_description body_type  \
# 0    Audi A1        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans
# 1    Audi A1                                     1.8 TFSI sport    Sedans
# 2    Audi A1  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans
# 3    Audi A1                            1.4 TDi Design S tronic    Sedans
# 4    Audi A1  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans
#
#    price               vat         km registration      hp  \
# 0  15770    VAT deductible  56,013 km      01/2016   66 kW
# 1  14500  Price negotiable  80,000 km      03/2017  141 kW
# 2  14640    VAT deductible  83,450 km      02/2016   85 kW
# 3  14500              None  73,000 km      08/2016   66 kW
# 4  16790              None  16,200 km      05/2016   66 kW
#
#   Comfort & Convenience 1 Air conditioning  \
# 0                                     True
# 1                                     True
# 2                                     True
# 3                                    False
# 4                                     True
#
#   Comfort & Convenience 2 Air suspension Comfort & Convenience 3 Armrest  \
# 0                                  False                            True
# 1                                  False                           False
# 2                                  False                           False
# 3                                   True                            True
# 4                                  False                            True
#
#   Comfort & Convenience 4 Automatic climate control  \
# 0                                              True
# 1                                              True
# 2                                             False
# 3                                             False
# 4                                              True
#
#   Comfort & Convenience 5 Auxiliary heating  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                      True
# 4                                     False
#
#   Comfort & Convenience 6 Cruise control  \
# 0                                   True
# 1                                  False
# 2                                   True
# 3                                  False
# 4                                  False
#
#   Comfort & Convenience 7 Electric Starter  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#   Comfort & Convenience 8 Electric tailgate  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#   Comfort & Convenience 9 Electrical side mirrors  \
# 0                                            True
# 1                                           False
# 2                                            True
# 3                                            True
# 4                                            True
#
#   Comfort & Convenience 10 Electrically adjustable seats  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 11 Electrically heated windshield  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 12 Heads-up display  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                      True
# 4                                     False
#
#   Comfort & Convenience 13 Heated steering wheel  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#   Comfort & Convenience 14 Hill Holder  \
# 0                                 True
# 1                                 True
# 2                                 True
# 3                                 True
# 4                                 True
#
#   Comfort & Convenience 15 Keyless central door lock  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 16 Leather seats  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Comfort & Convenience 17 Leather steering wheel  \
# 0                                            True
# 1                                            True
# 2                                            True
# 3                                            True
# 4                                            True
#
#   Comfort & Convenience 18 Light sensor  \
# 0                                  True
# 1                                 False
# 2                                 False
# 3                                  True
# 4                                  True
#
#   Comfort & Convenience 19 Lumbar support  \
# 0                                   False
# 1                                    True
# 2                                   False
# 3                                    True
# 4                                   False
#
#   Comfort & Convenience 20 Massage seats  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Comfort & Convenience 21 Multi-function steering wheel  \
# 0                                               True
# 1                                              False
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Comfort & Convenience 22 Navigation system  \
# 0                                       True
# 1                                      False
# 2                                       True
# 3                                       True
# 4                                      False
#
#   Comfort & Convenience 23 Panorama roof  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Comfort & Convenience 24 Park Distance Control  \
# 0                                           True
# 1                                          False
# 2                                           True
# 3                                          False
# 4                                           True
#
#   Comfort & Convenience 25 Parking assist system camera  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 26 Parking assist system self-steering  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 27 Parking assist system sensors front  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 28 Parking assist system sensors rear  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                              False
# 4                                               True
#
#   Comfort & Convenience 29 Power windows Comfort & Convenience 30 Rain sensor  \
# 0                                   True                                 True
# 1                                   True                                False
# 2                                   True                                False
# 3                                   True                                 True
# 4                                   True                                 True
#
#   Comfort & Convenience 31 Seat heating  \
# 0                                  True
# 1                                 False
# 2                                  True
# 3                                  True
# 4                                 False
#
#   Comfort & Convenience 32 Seat ventilation  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#   Comfort & Convenience 33 Split rear seats  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                      True
# 4                                     False
#
#   Comfort & Convenience 34 Start-stop system Comfort & Convenience 35 Sunroof  \
# 0                                       True                            False
# 1                                       True                            False
# 2                                       True                            False
# 3                                       True                            False
# 4                                       True                            False
#
#   Comfort & Convenience 36 Tinted windows  \
# 0                                   False
# 1                                    True
# 2                                   False
# 3                                   False
# 4                                   False
#
#   Comfort & Convenience 37 Wind deflector Comfort & Convenience 38 Windshield  \
# 0                                   False                               False
# 1                                   False                               False
# 2                                   False                               False
# 3                                   False                               False
# 4                                   False                               False
#
#   Safety & Security 1 ABS Safety & Security 2 Adaptive Cruise Control  \
# 0                    True                                       False
# 1                    True                                       False
# 2                    True                                       False
# 3                    True                                       False
# 4                    True                                       False
#
#   Safety & Security 3 Adaptive headlights Safety & Security 4 Alarm system  \
# 0                                   False                            False
# 1                                   False                            False
# 2                                   False                            False
# 3                                   False                             True
# 4                                   False                            False
#
#   Safety & Security 5 Blind spot monitor  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Safety & Security 6 Central door lock  \
# 0                                  True
# 1                                  True
# 2                                  True
# 3                                 False
# 4                                  True
#
#   Safety & Security 7 Central door lock with remote control  \
# 0                                              False
# 1                                               True
# 2                                              False
# 3                                               True
# 4                                              False
#
#   Safety & Security 8 Daytime running lights  \
# 0                                       True
# 1                                       True
# 2                                       True
# 3                                      False
# 4                                      False
#
#   Safety & Security 9 Driver drowsiness detection  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                            True
# 4                                           False
#
#   Safety & Security 10 Driver-side airbag  \
# 0                                    True
# 1                                    True
# 2                                    True
# 3                                    True
# 4                                    True
#
#   Safety & Security 11 Electronic stability control  \
# 0                                              True
# 1                                              True
# 2                                              True
# 3                                              True
# 4                                              True
#
#   Safety & Security 12 Emergency brake assistant  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#   Safety & Security 13 Emergency system Safety & Security 14 Fog lights  \
# 0                                 False                            True
# 1                                 False                           False
# 2                                 False                           False
# 3                                  True                           False
# 4                                 False                            True
#
#   Safety & Security 15 Head airbag Safety & Security 16 Immobilizer  \
# 0                            False                             True
# 1                             True                             True
# 2                            False                             True
# 3                             True                             True
# 4                            False                             True
#
#   Safety & Security 17 Isofix Safety & Security 18 LED Daytime Running Lights  \
# 0                        True                                           False
# 1                        True                                           False
# 2                        True                                           False
# 3                        True                                           False
# 4                        True                                           False
#
#   Safety & Security 19 LED Headlights  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
#
#   Safety & Security 20 Lane departure warning system  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Safety & Security 21 Night view assist  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Safety & Security 22 Passenger-side airbag  \
# 0                                       True
# 1                                       True
# 2                                       True
# 3                                       True
# 4                                       True
#
#   Safety & Security 23 Power steering Safety & Security 24 Rear airbag  \
# 0                                True                            False
# 1                                True                            False
# 2                                True                            False
# 3                                True                            False
# 4                                True                            False
#
#   Safety & Security 25 Side airbag  \
# 0                             True
# 1                             True
# 2                             True
# 3                             True
# 4                             True
#
#   Safety & Security 26 Tire pressure monitoring system  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Safety & Security 27 Traction control  \
# 0                                  True
# 1                                  True
# 2                                  True
# 3                                 False
# 4                                  True
#
#   Safety & Security 28 Traffic sign recognition  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#   Safety & Security 29 Xenon headlights Extras 1 Alloy wheels  \
# 0                                  True                  True
# 1                                  True                  True
# 2                                 False                  True
# 3                                 False                  True
# 4                                  True                  True
#
#   Extras 2 Cab or rented Car Extras 3 Catalytic Converter  \
# 0                      False                         True
# 1                      False                        False
# 2                      False                        False
# 3                      False                        False
# 4                      False                        False
#
#   Extras 4 Handicapped enabled Extras 5 Right hand drive Extras 6 Roof rack  \
# 0                        False                     False              False
# 1                        False                     False              False
# 2                        False                     False              False
# 3                        False                     False              False
# 4                        False                     False              False
#
#   Extras 7 Shift paddles Extras 8 Ski bag Extras 9 Sliding door  \
# 0                  False            False                 False
# 1                  False            False                 False
# 2                  False            False                 False
# 3                  False            False                 False
# 4                  False            False                 False
#
#   Extras 10 Sport package Extras 11 Sport seats Extras 12 Sport suspension  \
# 0                   False                 False                      False
# 1                   False                  True                       True
# 2                   False                 False                      False
# 3                   False                  True                      False
# 4                    True                 False                       True
#
#   Extras 13 Touch screen Extras 14 Trailer hitch Extras 15 Tuned car  \
# 0                  False                   False               False
# 1                  False                   False               False
# 2                  False                   False               False
# 3                  False                   False               False
# 4                  False                   False               False
#
#   Extras 16 Voice Control Extras 17 Winter tyres  \
# 0                    True                  False
# 1                    True                  False
# 2                    True                  False
# 3                    True                  False
# 4                    True                  False
#
#   Entertainment & Media 1 Bluetooth Entertainment & Media 2 CD player  \
# 0                              True                             False
# 1                              True                             False
# 2                             False                             False
# 3                              True                              True
# 4                              True                              True
#
#   Entertainment & Media 3 Digital radio  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#   Entertainment & Media 4 Hands-free equipment Entertainment & Media 5 MP3  \
# 0                                         True                       False
# 1                                         True                       False
# 2                                        False                        True
# 3                                         True                        True
# 4                                         True                        True
#
#   Entertainment & Media 6 On-board computer Entertainment & Media 7 Radio  \
# 0                                      True                          True
# 1                                      True                          True
# 2                                      True                         False
# 3                                      True                          True
# 4                                      True                          True
#
#   Entertainment & Media 8 Sound system Entertainment & Media 9 Television  \
# 0                                False                              False
# 1                                 True                              False
# 2                                False                              False
# 3                                 True                              False
# 4                                False                              False
#
#   Entertainment & Media 10 USB Type2                        Type4  \
# 0                        False  Used  Diesel (Particulate Filter)
# 1                        False  Used                     Gasoline
# 2                        False  Used  Diesel (Particulate Filter)
# 3                         True  Used  Diesel (Particulate Filter)
# 4                         True  Used  Diesel (Particulate Filter)
#
#   Previous Owners1 Warranty1       Full Service3 First Registration2  \
# 0                2       NaN                 NaN                2016
# 1              NaN       NaN                 NaN                2017
# 2                1       NaN                 NaN                2016
# 3                1       NaN  99 g CO2/km (comb)                2016
# 4                1       NaN           4 (Green)                2016
#
#   Body Color2 Paint Type     Body Color Original    Upholstery   Body2  \
# 0       Black   Metallic           Mythosschwarz  Cloth, Black  Sedans
# 1         Red        NaN                     NaN   Cloth, Grey  Sedans
# 2       Black   Metallic  mythosschwarz metallic  Cloth, Black  Sedans
# 3       Brown   Metallic                     NaN           NaN  Sedans
# 4       Black   Metallic  Mythosschwarz Metallic  Cloth, Black  Sedans
#
#   Nr. of Doors Nr. of Seats Gearing Type2 Displacement Cylinders Drive chain  \
# 0            5            5     Automatic     1,422 cc         3       front
# 1            3            4     Automatic     1,798 cc         4       front
# 2            4            4     Automatic     1,598 cc       NaN       front
# 3            3            4     Automatic     1,422 cc         3         NaN
# 4            5            5     Automatic     1,422 cc         3       front
#
#                          Fuel2        CO2 Emission1 Emission Class1 Gears  \
# 0  Diesel (Particulate Filter)   99 g CO2/km (comb)          Euro 6   NaN
# 1                     Gasoline  129 g CO2/km (comb)          Euro 6     7
# 2  Diesel (Particulate Filter)   99 g CO2/km (comb)          Euro 6   NaN
# 3  Diesel (Particulate Filter)   99 g CO2/km (comb)          Euro 6     6
# 4  Diesel (Particulate Filter)  109 g CO2/km (comb)          Euro 6   NaN
#
#   Country version         Consumption1         Consumption2  \
# 0             NaN  3.8 l/100 km (comb)  4.3 l/100 km (city)
# 1             NaN  5.6 l/100 km (comb)  7.1 l/100 km (city)
# 2             NaN  3.8 l/100 km (comb)  4.4 l/100 km (city)
# 3             NaN  3.8 l/100 km (comb)  4.3 l/100 km (city)
# 4         Germany  4.1 l/100 km (comb)  4.6 l/100 km (city)
#
#              Consumption3
# 0  3.5 l/100 km (country)
# 1  4.7 l/100 km (country)
# 2  3.4 l/100 km (country)
# 3  3.5 l/100 km (country)
# 4  3.8 l/100 km (country)

# %% [markdown]
# # Crop extra info from cells

# %%
#Delete "km" from km column
df["km"] = df["km"].apply(lambda x : x.replace(",","").replace("-","0") if type(x)==str else x)
df['km'] = df['km'].apply(lambda x : x.split("km")[0].strip())

#Delete "cc" from Displacement column
df['Displacement'] = df['Displacement'].apply(lambda x : x if pd.isna(x) else x.split("cc")[0].strip())
df.rename(columns={'Displacement': 'Displacement (cc)'},inplace=True)
df["Displacement (cc)"] = df["Displacement (cc)"].apply(lambda x : round(int(x.replace(",",""))/1000,1) if type(x)==str else x)

#Delete "kW" from hp column
df['hp'] = df['hp'].apply(lambda x : x if pd.isna(x) else x.split("kW")[0].strip())
df.rename(columns={'hp': 'hp (kW)'},inplace=True)

#extract 1 digit for emission class like 6 4 etc.
df['Emission Class1'] = df['Emission Class1'].str.extract('(\d)').rename(columns={0: 'Emission Class Euro'})

#extract CO2 Emission digits
df['CO2 Emission1'] = df['CO2 Emission1'].apply(lambda x : x if pd.isna(x) else x.split(" ")[0])
df.rename(columns={'CO2 Emission1': 'CO2 Emission (g CO2/km (comb))'},inplace=True)

# extract consumption columns to digits
df['Consumption1'] = df['Consumption1'].apply(lambda x : x if pd.isna(x) else x.split(" ")[0].strip())
df.rename(columns={'Consumption1': 'Consumption l/100 km (comb)'},inplace=True)
df['Consumption2'] = df['Consumption2'].apply(lambda x : x if pd.isna(x) else x.split(" ")[0].strip())
df.rename(columns={'Consumption2': 'Consumption l/100 km (city)'},inplace=True)
df['Consumption3'] = df['Consumption3'].apply(lambda x : x if pd.isna(x) else x.split(" ")[0].strip())
df.rename(columns={'Consumption3': 'Consumption l/100 km (country)'},inplace=True)

# %%
df.head(3)
# Out:
#   make_model                                  short_description body_type  \
# 0    Audi A1        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans
# 1    Audi A1                                     1.8 TFSI sport    Sedans
# 2    Audi A1  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans
#
#    price               vat     km registration hp (kW)  \
# 0  15770    VAT deductible  56013      01/2016      66
# 1  14500  Price negotiable  80000      03/2017     141
# 2  14640    VAT deductible  83450      02/2016      85
#
#   Comfort & Convenience 1 Air conditioning  \
# 0                                     True
# 1                                     True
# 2                                     True
#
#   Comfort & Convenience 2 Air suspension Comfort & Convenience 3 Armrest  \
# 0                                  False                            True
# 1                                  False                           False
# 2                                  False                           False
#
#   Comfort & Convenience 4 Automatic climate control  \
# 0                                              True
# 1                                              True
# 2                                             False
#
#   Comfort & Convenience 5 Auxiliary heating  \
# 0                                     False
# 1                                     False
# 2                                     False
#
#   Comfort & Convenience 6 Cruise control  \
# 0                                   True
# 1                                  False
# 2                                   True
#
#   Comfort & Convenience 7 Electric Starter  \
# 0                                    False
# 1                                    False
# 2                                    False
#
#   Comfort & Convenience 8 Electric tailgate  \
# 0                                     False
# 1                                     False
# 2                                     False
#
#   Comfort & Convenience 9 Electrical side mirrors  \
# 0                                            True
# 1                                           False
# 2                                            True
#
#   Comfort & Convenience 10 Electrically adjustable seats  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#   Comfort & Convenience 11 Electrically heated windshield  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#   Comfort & Convenience 12 Heads-up display  \
# 0                                     False
# 1                                     False
# 2                                     False
#
#   Comfort & Convenience 13 Heated steering wheel  \
# 0                                          False
# 1                                          False
# 2                                          False
#
#   Comfort & Convenience 14 Hill Holder  \
# 0                                 True
# 1                                 True
# 2                                 True
#
#   Comfort & Convenience 15 Keyless central door lock  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#   Comfort & Convenience 16 Leather seats  \
# 0                                  False
# 1                                  False
# 2                                  False
#
#   Comfort & Convenience 17 Leather steering wheel  \
# 0                                            True
# 1                                            True
# 2                                            True
#
#   Comfort & Convenience 18 Light sensor  \
# 0                                  True
# 1                                 False
# 2                                 False
#
#   Comfort & Convenience 19 Lumbar support  \
# 0                                   False
# 1                                    True
# 2                                   False
#
#   Comfort & Convenience 20 Massage seats  \
# 0                                  False
# 1                                  False
# 2                                  False
#
#   Comfort & Convenience 21 Multi-function steering wheel  \
# 0                                               True
# 1                                              False
# 2                                               True
#
#   Comfort & Convenience 22 Navigation system  \
# 0                                       True
# 1                                      False
# 2                                       True
#
#   Comfort & Convenience 23 Panorama roof  \
# 0                                  False
# 1                                  False
# 2                                  False
#
#   Comfort & Convenience 24 Park Distance Control  \
# 0                                           True
# 1                                          False
# 2                                           True
#
#   Comfort & Convenience 25 Parking assist system camera  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#   Comfort & Convenience 26 Parking assist system self-steering  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#   Comfort & Convenience 27 Parking assist system sensors front  \
# 0                                              False
# 1                                              False
# 2                                               True
#
#   Comfort & Convenience 28 Parking assist system sensors rear  \
# 0                                               True
# 1                                               True
# 2                                               True
#
#   Comfort & Convenience 29 Power windows Comfort & Convenience 30 Rain sensor  \
# 0                                   True                                 True
# 1                                   True                                False
# 2                                   True                                False
#
#   Comfort & Convenience 31 Seat heating  \
# 0                                  True
# 1                                 False
# 2                                  True
#
#   Comfort & Convenience 32 Seat ventilation  \
# 0                                     False
# 1                                     False
# 2                                     False
#
#   Comfort & Convenience 33 Split rear seats  \
# 0                                     False
# 1                                     False
# 2                                     False
#
#   Comfort & Convenience 34 Start-stop system Comfort & Convenience 35 Sunroof  \
# 0                                       True                            False
# 1                                       True                            False
# 2                                       True                            False
#
#   Comfort & Convenience 36 Tinted windows  \
# 0                                   False
# 1                                    True
# 2                                   False
#
#   Comfort & Convenience 37 Wind deflector Comfort & Convenience 38 Windshield  \
# 0                                   False                               False
# 1                                   False                               False
# 2                                   False                               False
#
#   Safety & Security 1 ABS Safety & Security 2 Adaptive Cruise Control  \
# 0                    True                                       False
# 1                    True                                       False
# 2                    True                                       False
#
#   Safety & Security 3 Adaptive headlights Safety & Security 4 Alarm system  \
# 0                                   False                            False
# 1                                   False                            False
# 2                                   False                            False
#
#   Safety & Security 5 Blind spot monitor  \
# 0                                  False
# 1                                  False
# 2                                  False
#
#   Safety & Security 6 Central door lock  \
# 0                                  True
# 1                                  True
# 2                                  True
#
#   Safety & Security 7 Central door lock with remote control  \
# 0                                              False
# 1                                               True
# 2                                              False
#
#   Safety & Security 8 Daytime running lights  \
# 0                                       True
# 1                                       True
# 2                                       True
#
#   Safety & Security 9 Driver drowsiness detection  \
# 0                                           False
# 1                                           False
# 2                                           False
#
#   Safety & Security 10 Driver-side airbag  \
# 0                                    True
# 1                                    True
# 2                                    True
#
#   Safety & Security 11 Electronic stability control  \
# 0                                              True
# 1                                              True
# 2                                              True
#
#   Safety & Security 12 Emergency brake assistant  \
# 0                                          False
# 1                                          False
# 2                                          False
#
#   Safety & Security 13 Emergency system Safety & Security 14 Fog lights  \
# 0                                 False                            True
# 1                                 False                           False
# 2                                 False                           False
#
#   Safety & Security 15 Head airbag Safety & Security 16 Immobilizer  \
# 0                            False                             True
# 1                             True                             True
# 2                            False                             True
#
#   Safety & Security 17 Isofix Safety & Security 18 LED Daytime Running Lights  \
# 0                        True                                           False
# 1                        True                                           False
# 2                        True                                           False
#
#   Safety & Security 19 LED Headlights  \
# 0                               False
# 1                               False
# 2                               False
#
#   Safety & Security 20 Lane departure warning system  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#   Safety & Security 21 Night view assist  \
# 0                                  False
# 1                                  False
# 2                                  False
#
#   Safety & Security 22 Passenger-side airbag  \
# 0                                       True
# 1                                       True
# 2                                       True
#
#   Safety & Security 23 Power steering Safety & Security 24 Rear airbag  \
# 0                                True                            False
# 1                                True                            False
# 2                                True                            False
#
#   Safety & Security 25 Side airbag  \
# 0                             True
# 1                             True
# 2                             True
#
#   Safety & Security 26 Tire pressure monitoring system  \
# 0                                               True
# 1                                               True
# 2                                               True
#
#   Safety & Security 27 Traction control  \
# 0                                  True
# 1                                  True
# 2                                  True
#
#   Safety & Security 28 Traffic sign recognition  \
# 0                                         False
# 1                                         False
# 2                                         False
#
#   Safety & Security 29 Xenon headlights Extras 1 Alloy wheels  \
# 0                                  True                  True
# 1                                  True                  True
# 2                                 False                  True
#
#   Extras 2 Cab or rented Car Extras 3 Catalytic Converter  \
# 0                      False                         True
# 1                      False                        False
# 2                      False                        False
#
#   Extras 4 Handicapped enabled Extras 5 Right hand drive Extras 6 Roof rack  \
# 0                        False                     False              False
# 1                        False                     False              False
# 2                        False                     False              False
#
#   Extras 7 Shift paddles Extras 8 Ski bag Extras 9 Sliding door  \
# 0                  False            False                 False
# 1                  False            False                 False
# 2                  False            False                 False
#
#   Extras 10 Sport package Extras 11 Sport seats Extras 12 Sport suspension  \
# 0                   False                 False                      False
# 1                   False                  True                       True
# 2                   False                 False                      False
#
#   Extras 13 Touch screen Extras 14 Trailer hitch Extras 15 Tuned car  \
# 0                  False                   False               False
# 1                  False                   False               False
# 2                  False                   False               False
#
#   Extras 16 Voice Control Extras 17 Winter tyres  \
# 0                    True                  False
# 1                    True                  False
# 2                    True                  False
#
#   Entertainment & Media 1 Bluetooth Entertainment & Media 2 CD player  \
# 0                              True                             False
# 1                              True                             False
# 2                             False                             False
#
#   Entertainment & Media 3 Digital radio  \
# 0                                 False
# 1                                 False
# 2                                 False
#
#   Entertainment & Media 4 Hands-free equipment Entertainment & Media 5 MP3  \
# 0                                         True                       False
# 1                                         True                       False
# 2                                        False                        True
#
#   Entertainment & Media 6 On-board computer Entertainment & Media 7 Radio  \
# 0                                      True                          True
# 1                                      True                          True
# 2                                      True                         False
#
#   Entertainment & Media 8 Sound system Entertainment & Media 9 Television  \
# 0                                False                              False
# 1                                 True                              False
# 2                                False                              False
#
#   Entertainment & Media 10 USB Type2                        Type4  \
# 0                        False  Used  Diesel (Particulate Filter)
# 1                        False  Used                     Gasoline
# 2                        False  Used  Diesel (Particulate Filter)
#
#   Previous Owners1 Warranty1 Full Service3 First Registration2 Body Color2  \
# 0                2       NaN           NaN                2016       Black
# 1              NaN       NaN           NaN                2017         Red
# 2                1       NaN           NaN                2016       Black
#
#   Paint Type     Body Color Original    Upholstery   Body2 Nr. of Doors  \
# 0   Metallic           Mythosschwarz  Cloth, Black  Sedans            5
# 1        NaN                     NaN   Cloth, Grey  Sedans            3
# 2   Metallic  mythosschwarz metallic  Cloth, Black  Sedans            4
#
#   Nr. of Seats Gearing Type2  Displacement (cc) Cylinders Drive chain  \
# 0            5     Automatic                1.4         3       front
# 1            4     Automatic                1.8         4       front
# 2            4     Automatic                1.6       NaN       front
#
#                          Fuel2 CO2 Emission (g CO2/km (comb)) Emission Class1  \
# 0  Diesel (Particulate Filter)                             99               6
# 1                     Gasoline                            129               6
# 2  Diesel (Particulate Filter)                             99               6
#
#   Gears Country version Consumption l/100 km (comb)  \
# 0   NaN             NaN                         3.8
# 1     7             NaN                         5.6
# 2   NaN             NaN                         3.8
#
#   Consumption l/100 km (city) Consumption l/100 km (country)
# 0                         4.3                            3.5
# 1                         7.1                            4.7
# 2                         4.4                            3.4

# %% [markdown]
# # Fill Missing Values and Move cell info to title

# %%
# Fill drive chain with other 3 columns
#fill_priority_perm(df,"Drive chain","make_model","Gearing Type2","Fuel2")

# %% [markdown]
# # Convert Column types to Numeric, if Categorical get_dummies()

# %%
#df["Comfort&Convenience"].str.get_dummies(sep = ",")

# %% [markdown]
# # Feature Engineering (Column addition within)

# %%
##registration ile now arasi icin age olarak yeni bir column ekleyelim

# %% [markdown]
# # TEST

# %%
for i in df.columns:
    if df[i].notna().mean()*100 > 90:
        print(i, df[i].notna().mean()*100)
# Out:
# make_model 100.0
# short_description 99.71103712544758
# body_type 99.62309190275771
# price 100.0
# km 100.0
# registration 100.0
# hp (kW) 100.0
# Comfort & Convenience 1 Air conditioning 94.22074250895157
# Comfort & Convenience 2 Air suspension 94.22074250895157
# Comfort & Convenience 3 Armrest 94.22074250895157
# Comfort & Convenience 4 Automatic climate control 94.22074250895157
# Comfort & Convenience 5 Auxiliary heating 94.22074250895157
# Comfort & Convenience 6 Cruise control 94.22074250895157
# Comfort & Convenience 7 Electric Starter 94.22074250895157
# Comfort & Convenience 8 Electric tailgate 94.22074250895157
# Comfort & Convenience 9 Electrical side mirrors 94.22074250895157
# Comfort & Convenience 10 Electrically adjustable seats 94.22074250895157
# Comfort & Convenience 11 Electrically heated windshield 94.22074250895157
# Comfort & Convenience 12 Heads-up display 94.22074250895157
# Comfort & Convenience 13 Heated steering wheel 94.22074250895157
# Comfort & Convenience 14 Hill Holder 94.22074250895157
# Comfort & Convenience 15 Keyless central door lock 94.22074250895157
# Comfort & Convenience 16 Leather seats 94.22074250895157
# Comfort & Convenience 17 Leather steering wheel 94.22074250895157
# Comfort & Convenience 18 Light sensor 94.22074250895157
# Comfort & Convenience 19 Lumbar support 94.22074250895157
# Comfort & Convenience 20 Massage seats 94.22074250895157
# Comfort & Convenience 21 Multi-function steering wheel 94.22074250895157
# Comfort & Convenience 22 Navigation system 94.22074250895157
# Comfort & Convenience 23 Panorama roof 94.22074250895157
# Comfort & Convenience 24 Park Distance Control 94.22074250895157
# Comfort & Convenience 25 Parking assist system camera 94.22074250895157
# Comfort & Convenience 26 Parking assist system self-steering 94.22074250895157
# Comfort & Convenience 27 Parking assist system sensors front 94.22074250895157
# Comfort & Convenience 28 Parking assist system sensors rear 94.22074250895157
# Comfort & Convenience 29 Power windows 94.22074250895157
# Comfort & Convenience 30 Rain sensor 94.22074250895157
# Comfort & Convenience 31 Seat heating 94.22074250895157
# Comfort & Convenience 32 Seat ventilation 94.22074250895157
# Comfort & Convenience 33 Split rear seats 94.22074250895157
# Comfort & Convenience 34 Start-stop system 94.22074250895157
# Comfort & Convenience 35 Sunroof 94.22074250895157
# Comfort & Convenience 36 Tinted windows 94.22074250895157
# Comfort & Convenience 37 Wind deflector 94.22074250895157
# Comfort & Convenience 38 Windshield 94.22074250895157
# Safety & Security 1 ABS 93.83127080846788
# Safety & Security 2 Adaptive Cruise Control 93.83127080846788
# Safety & Security 3 Adaptive headlights 93.83127080846788
# Safety & Security 4 Alarm system 93.83127080846788
# Safety & Security 5 Blind spot monitor 93.83127080846788
# Safety & Security 6 Central door lock 93.83127080846788
# Safety & Security 7 Central door lock with remote control 93.83127080846788
# Safety & Security 8 Daytime running lights 93.83127080846788
# Safety & Security 9 Driver drowsiness detection 93.83127080846788
# Safety & Security 10 Driver-side airbag 93.83127080846788
# Safety & Security 11 Electronic stability control 93.83127080846788
# Safety & Security 12 Emergency brake assistant 93.83127080846788
# Safety & Security 13 Emergency system 93.83127080846788
# Safety & Security 14 Fog lights 93.83127080846788
# Safety & Security 15 Head airbag 93.83127080846788
# Safety & Security 16 Immobilizer 93.83127080846788
# Safety & Security 17 Isofix 93.83127080846788
# Safety & Security 18 LED Daytime Running Lights 93.83127080846788
# Safety & Security 19 LED Headlights 93.83127080846788
# Safety & Security 20 Lane departure warning system 93.83127080846788
# Safety & Security 21 Night view assist 93.83127080846788
# Safety & Security 22 Passenger-side airbag 93.83127080846788
# Safety & Security 23 Power steering 93.83127080846788
# Safety & Security 24 Rear airbag 93.83127080846788
# Safety & Security 25 Side airbag 93.83127080846788
# Safety & Security 26 Tire pressure monitoring system 93.83127080846788
# Safety & Security 27 Traction control 93.83127080846788
# Safety & Security 28 Traffic sign recognition 93.83127080846788
# Safety & Security 29 Xenon headlights 93.83127080846788
# Entertainment & Media 1 Bluetooth 91.36880457315158
# Entertainment & Media 2 CD player 91.36880457315158
# Entertainment & Media 3 Digital radio 91.36880457315158
# Entertainment & Media 4 Hands-free equipment 91.36880457315158
# Entertainment & Media 5 MP3 91.36880457315158
# Entertainment & Media 6 On-board computer 91.36880457315158
# Entertainment & Media 7 Radio 91.36880457315158
# Entertainment & Media 8 Sound system 91.36880457315158
# Entertainment & Media 9 Television 91.36880457315158
# Entertainment & Media 10 USB 91.36880457315158
# Type2 100.0
# Type4 99.98743639675858
# Body Color2 96.24976443243922
# Body2 99.62309190275771
# Nr. of Doors 98.66825805641058
# Nr. of Seats 93.86267981657139
# Gearing Type2 100.0
# Displacement (cc) 96.88422639613042
# Fuel2 100.0

# %%
df.head(2)
# Out:
#   make_model                            short_description body_type  price  \
# 0    Audi A1  Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1    Audi A1                               1.8 TFSI sport    Sedans  14500
#
#                 vat     km registration hp (kW)  \
# 0    VAT deductible  56013      01/2016      66
# 1  Price negotiable  80000      03/2017     141
#
#   Comfort & Convenience 1 Air conditioning  \
# 0                                     True
# 1                                     True
#
#   Comfort & Convenience 2 Air suspension Comfort & Convenience 3 Armrest  \
# 0                                  False                            True
# 1                                  False                           False
#
#   Comfort & Convenience 4 Automatic climate control  \
# 0                                              True
# 1                                              True
#
#   Comfort & Convenience 5 Auxiliary heating  \
# 0                                     False
# 1                                     False
#
#   Comfort & Convenience 6 Cruise control  \
# 0                                   True
# 1                                  False
#
#   Comfort & Convenience 7 Electric Starter  \
# 0                                    False
# 1                                    False
#
#   Comfort & Convenience 8 Electric tailgate  \
# 0                                     False
# 1                                     False
#
#   Comfort & Convenience 9 Electrical side mirrors  \
# 0                                            True
# 1                                           False
#
#   Comfort & Convenience 10 Electrically adjustable seats  \
# 0                                              False
# 1                                              False
#
#   Comfort & Convenience 11 Electrically heated windshield  \
# 0                                              False
# 1                                              False
#
#   Comfort & Convenience 12 Heads-up display  \
# 0                                     False
# 1                                     False
#
#   Comfort & Convenience 13 Heated steering wheel  \
# 0                                          False
# 1                                          False
#
#   Comfort & Convenience 14 Hill Holder  \
# 0                                 True
# 1                                 True
#
#   Comfort & Convenience 15 Keyless central door lock  \
# 0                                              False
# 1                                              False
#
#   Comfort & Convenience 16 Leather seats  \
# 0                                  False
# 1                                  False
#
#   Comfort & Convenience 17 Leather steering wheel  \
# 0                                            True
# 1                                            True
#
#   Comfort & Convenience 18 Light sensor  \
# 0                                  True
# 1                                 False
#
#   Comfort & Convenience 19 Lumbar support  \
# 0                                   False
# 1                                    True
#
#   Comfort & Convenience 20 Massage seats  \
# 0                                  False
# 1                                  False
#
#   Comfort & Convenience 21 Multi-function steering wheel  \
# 0                                               True
# 1                                              False
#
#   Comfort & Convenience 22 Navigation system  \
# 0                                       True
# 1                                      False
#
#   Comfort & Convenience 23 Panorama roof  \
# 0                                  False
# 1                                  False
#
#   Comfort & Convenience 24 Park Distance Control  \
# 0                                           True
# 1                                          False
#
#   Comfort & Convenience 25 Parking assist system camera  \
# 0                                              False
# 1                                              False
#
#   Comfort & Convenience 26 Parking assist system self-steering  \
# 0                                              False
# 1                                              False
#
#   Comfort & Convenience 27 Parking assist system sensors front  \
# 0                                              False
# 1                                              False
#
#   Comfort & Convenience 28 Parking assist system sensors rear  \
# 0                                               True
# 1                                               True
#
#   Comfort & Convenience 29 Power windows Comfort & Convenience 30 Rain sensor  \
# 0                                   True                                 True
# 1                                   True                                False
#
#   Comfort & Convenience 31 Seat heating  \
# 0                                  True
# 1                                 False
#
#   Comfort & Convenience 32 Seat ventilation  \
# 0                                     False
# 1                                     False
#
#   Comfort & Convenience 33 Split rear seats  \
# 0                                     False
# 1                                     False
#
#   Comfort & Convenience 34 Start-stop system Comfort & Convenience 35 Sunroof  \
# 0                                       True                            False
# 1                                       True                            False
#
#   Comfort & Convenience 36 Tinted windows  \
# 0                                   False
# 1                                    True
#
#   Comfort & Convenience 37 Wind deflector Comfort & Convenience 38 Windshield  \
# 0                                   False                               False
# 1                                   False                               False
#
#   Safety & Security 1 ABS Safety & Security 2 Adaptive Cruise Control  \
# 0                    True                                       False
# 1                    True                                       False
#
#   Safety & Security 3 Adaptive headlights Safety & Security 4 Alarm system  \
# 0                                   False                            False
# 1                                   False                            False
#
#   Safety & Security 5 Blind spot monitor  \
# 0                                  False
# 1                                  False
#
#   Safety & Security 6 Central door lock  \
# 0                                  True
# 1                                  True
#
#   Safety & Security 7 Central door lock with remote control  \
# 0                                              False
# 1                                               True
#
#   Safety & Security 8 Daytime running lights  \
# 0                                       True
# 1                                       True
#
#   Safety & Security 9 Driver drowsiness detection  \
# 0                                           False
# 1                                           False
#
#   Safety & Security 10 Driver-side airbag  \
# 0                                    True
# 1                                    True
#
#   Safety & Security 11 Electronic stability control  \
# 0                                              True
# 1                                              True
#
#   Safety & Security 12 Emergency brake assistant  \
# 0                                          False
# 1                                          False
#
#   Safety & Security 13 Emergency system Safety & Security 14 Fog lights  \
# 0                                 False                            True
# 1                                 False                           False
#
#   Safety & Security 15 Head airbag Safety & Security 16 Immobilizer  \
# 0                            False                             True
# 1                             True                             True
#
#   Safety & Security 17 Isofix Safety & Security 18 LED Daytime Running Lights  \
# 0                        True                                           False
# 1                        True                                           False
#
#   Safety & Security 19 LED Headlights  \
# 0                               False
# 1                               False
#
#   Safety & Security 20 Lane departure warning system  \
# 0                                              False
# 1                                              False
#
#   Safety & Security 21 Night view assist  \
# 0                                  False
# 1                                  False
#
#   Safety & Security 22 Passenger-side airbag  \
# 0                                       True
# 1                                       True
#
#   Safety & Security 23 Power steering Safety & Security 24 Rear airbag  \
# 0                                True                            False
# 1                                True                            False
#
#   Safety & Security 25 Side airbag  \
# 0                             True
# 1                             True
#
#   Safety & Security 26 Tire pressure monitoring system  \
# 0                                               True
# 1                                               True
#
#   Safety & Security 27 Traction control  \
# 0                                  True
# 1                                  True
#
#   Safety & Security 28 Traffic sign recognition  \
# 0                                         False
# 1                                         False
#
#   Safety & Security 29 Xenon headlights Extras 1 Alloy wheels  \
# 0                                  True                  True
# 1                                  True                  True
#
#   Extras 2 Cab or rented Car Extras 3 Catalytic Converter  \
# 0                      False                         True
# 1                      False                        False
#
#   Extras 4 Handicapped enabled Extras 5 Right hand drive Extras 6 Roof rack  \
# 0                        False                     False              False
# 1                        False                     False              False
#
#   Extras 7 Shift paddles Extras 8 Ski bag Extras 9 Sliding door  \
# 0                  False            False                 False
# 1                  False            False                 False
#
#   Extras 10 Sport package Extras 11 Sport seats Extras 12 Sport suspension  \
# 0                   False                 False                      False
# 1                   False                  True                       True
#
#   Extras 13 Touch screen Extras 14 Trailer hitch Extras 15 Tuned car  \
# 0                  False                   False               False
# 1                  False                   False               False
#
#   Extras 16 Voice Control Extras 17 Winter tyres  \
# 0                    True                  False
# 1                    True                  False
#
#   Entertainment & Media 1 Bluetooth Entertainment & Media 2 CD player  \
# 0                              True                             False
# 1                              True                             False
#
#   Entertainment & Media 3 Digital radio  \
# 0                                 False
# 1                                 False
#
#   Entertainment & Media 4 Hands-free equipment Entertainment & Media 5 MP3  \
# 0                                         True                       False
# 1                                         True                       False
#
#   Entertainment & Media 6 On-board computer Entertainment & Media 7 Radio  \
# 0                                      True                          True
# 1                                      True                          True
#
#   Entertainment & Media 8 Sound system Entertainment & Media 9 Television  \
# 0                                False                              False
# 1                                 True                              False
#
#   Entertainment & Media 10 USB Type2                        Type4  \
# 0                        False  Used  Diesel (Particulate Filter)
# 1                        False  Used                     Gasoline
#
#   Previous Owners1 Warranty1 Full Service3 First Registration2 Body Color2  \
# 0                2       NaN           NaN                2016       Black
# 1              NaN       NaN           NaN                2017         Red
#
#   Paint Type Body Color Original    Upholstery   Body2 Nr. of Doors  \
# 0   Metallic       Mythosschwarz  Cloth, Black  Sedans            5
# 1        NaN                 NaN   Cloth, Grey  Sedans            3
#
#   Nr. of Seats Gearing Type2  Displacement (cc) Cylinders Drive chain  \
# 0            5     Automatic                1.4         3       front
# 1            4     Automatic                1.8         4       front
#
#                          Fuel2 CO2 Emission (g CO2/km (comb)) Emission Class1  \
# 0  Diesel (Particulate Filter)                             99               6
# 1                     Gasoline                            129               6
#
#   Gears Country version Consumption l/100 km (comb)  \
# 0   NaN             NaN                         3.8
# 1     7             NaN                         5.6
#
#   Consumption l/100 km (city) Consumption l/100 km (country)
# 0                         4.3                            3.5
# 1                         7.1                            4.7

# %%
#put to "make_model", "Displacement (cc)", "Cylinders"
make_model_FirstRegistration2_Countryversion_list = ['Comfort & Convenience 1 Air conditioning',
 'Comfort & Convenience 2 Air suspension',
 'Comfort & Convenience 3 Armrest',
 'Comfort & Convenience 4 Automatic climate control',
 'Comfort & Convenience 5 Auxiliary heating',
 'Comfort & Convenience 6 Cruise control',
 'Comfort & Convenience 7 Electric Starter',
 'Comfort & Convenience 8 Electric tailgate',
 'Comfort & Convenience 9 Electrical side mirrors',
 'Comfort & Convenience 10 Electrically adjustable seats',
 'Comfort & Convenience 11 Electrically heated windshield',
 'Comfort & Convenience 12 Heads-up display',
 'Comfort & Convenience 13 Heated steering wheel',
 'Comfort & Convenience 14 Hill Holder',
 'Comfort & Convenience 15 Keyless central door lock',
 'Comfort & Convenience 16 Leather seats',
 'Comfort & Convenience 17 Leather steering wheel',
 'Comfort & Convenience 18 Light sensor',
 'Comfort & Convenience 19 Lumbar support',
 'Comfort & Convenience 20 Massage seats',
 'Comfort & Convenience 21 Multi-function steering wheel',
 'Comfort & Convenience 22 Navigation system',
 'Comfort & Convenience 23 Panorama roof',
 'Comfort & Convenience 24 Park Distance Control',
 'Comfort & Convenience 25 Parking assist system camera',
 'Comfort & Convenience 26 Parking assist system self-steering',
 'Comfort & Convenience 27 Parking assist system sensors front',
 'Comfort & Convenience 28 Parking assist system sensors rear',
 'Comfort & Convenience 29 Power windows',
 'Comfort & Convenience 30 Rain sensor',
 'Comfort & Convenience 31 Seat heating',
 'Comfort & Convenience 32 Seat ventilation',
 'Comfort & Convenience 33 Split rear seats',
 'Comfort & Convenience 34 Start-stop system',
 'Comfort & Convenience 35 Sunroof',
 'Comfort & Convenience 36 Tinted windows',
 'Comfort & Convenience 37 Wind deflector',
 'Comfort & Convenience 38 Windshield',
 'Safety & Security 1 ABS',
 'Safety & Security 2 Adaptive Cruise Control',
 'Safety & Security 3 Adaptive headlights',
 'Safety & Security 4 Alarm system',
 'Safety & Security 5 Blind spot monitor',
 'Safety & Security 6 Central door lock',
 'Safety & Security 7 Central door lock with remote control',
 'Safety & Security 8 Daytime running lights',
 'Safety & Security 9 Driver drowsiness detection',
 'Safety & Security 10 Driver-side airbag',
 'Safety & Security 11 Electronic stability control',
 'Safety & Security 12 Emergency brake assistant',
 'Safety & Security 13 Emergency system',
 'Safety & Security 14 Fog lights',
 'Safety & Security 15 Head airbag',
 'Safety & Security 16 Immobilizer',
 'Safety & Security 17 Isofix',
 'Safety & Security 18 LED Daytime Running Lights',
 'Safety & Security 19 LED Headlights',
 'Safety & Security 20 Lane departure warning system',
 'Safety & Security 21 Night view assist',
 'Safety & Security 22 Passenger-side airbag',
 'Safety & Security 23 Power steering',
 'Safety & Security 24 Rear airbag',
 'Safety & Security 25 Side airbag',
 'Safety & Security 26 Tire pressure monitoring system',
 'Safety & Security 27 Traction control',
 'Safety & Security 28 Traffic sign recognition',
 'Safety & Security 29 Xenon headlights',
 'Extras 1 Alloy wheels',
 'Extras 2 Cab or rented Car',
 'Extras 3 Catalytic Converter',
 'Extras 4 Handicapped enabled',
 'Extras 5 Right hand drive',
 'Extras 6 Roof rack',
 'Extras 7 Shift paddles',
 'Extras 8 Ski bag',
 'Extras 9 Sliding door',
 'Extras 10 Sport package',
 'Extras 11 Sport seats',
 'Extras 12 Sport suspension',
 'Extras 13 Touch screen',
 'Extras 14 Trailer hitch',
 'Extras 15 Tuned car',
 'Extras 16 Voice Control',
 'Extras 17 Winter tyres',
 'Entertainment & Media 1 Bluetooth',
 'Entertainment & Media 2 CD player',
 'Entertainment & Media 3 Digital radio',
 'Entertainment & Media 4 Hands-free equipment',
 'Entertainment & Media 5 MP3',
 'Entertainment & Media 6 On-board computer',
 'Entertainment & Media 7 Radio',
 'Entertainment & Media 8 Sound system',
 'Entertainment & Media 9 Television',
 'Entertainment & Media 10 USB',
 'Consumption l/100 km (comb)',
 'Consumption l/100 km (city)',
 'Consumption l/100 km (country)']


make_model_Displacement_Cylinders_list = ["Drive chain"]
make_model_body_type_NrofSeats_list = ['body_type','Body Color2', 'Paint Type', 'Body Color Original',\
    'Upholstery', 'Body2','Nr. of Doors','Nr. of Seats',]
make_model_body_type_FirstRegistration2_list =  ['CO2 Emission (g CO2/km (comb))','Displacement (cc)',\
    'Cylinders','Emission Class1','Gears','Country version' ]
make_model_km_FirstRegistration2_list= []
PreviousOwners1_km_registration_list= []
registration_Type2_PreviousOwners1_list = ['vat','Warranty1', 'First Registration2',]
km_registration_Type2_list = ['Previous Owners1']
bfill_list = ["Type2", 'Type4' ]

# make_model 100.0
# price 100.0
# km 100.0
# registration 100.0
# hp (kW) 100.0
# Gearing Type2 100.0
# Fuel2 100.0

# %%
df.head(2)
# Out:
#   make_model                            short_description body_type  price  \
# 0    Audi A1  Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1    Audi A1                               1.8 TFSI sport    Sedans  14500
#
#                 vat     km registration hp (kW)  \
# 0    VAT deductible  56013      01/2016      66
# 1  Price negotiable  80000      03/2017     141
#
#   Comfort & Convenience 1 Air conditioning  \
# 0                                     True
# 1                                     True
#
#   Comfort & Convenience 2 Air suspension Comfort & Convenience 3 Armrest  \
# 0                                  False                            True
# 1                                  False                           False
#
#   Comfort & Convenience 4 Automatic climate control  \
# 0                                              True
# 1                                              True
#
#   Comfort & Convenience 5 Auxiliary heating  \
# 0                                     False
# 1                                     False
#
#   Comfort & Convenience 6 Cruise control  \
# 0                                   True
# 1                                  False
#
#   Comfort & Convenience 7 Electric Starter  \
# 0                                    False
# 1                                    False
#
#   Comfort & Convenience 8 Electric tailgate  \
# 0                                     False
# 1                                     False
#
#   Comfort & Convenience 9 Electrical side mirrors  \
# 0                                            True
# 1                                           False
#
#   Comfort & Convenience 10 Electrically adjustable seats  \
# 0                                              False
# 1                                              False
#
#   Comfort & Convenience 11 Electrically heated windshield  \
# 0                                              False
# 1                                              False
#
#   Comfort & Convenience 12 Heads-up display  \
# 0                                     False
# 1                                     False
#
#   Comfort & Convenience 13 Heated steering wheel  \
# 0                                          False
# 1                                          False
#
#   Comfort & Convenience 14 Hill Holder  \
# 0                                 True
# 1                                 True
#
#   Comfort & Convenience 15 Keyless central door lock  \
# 0                                              False
# 1                                              False
#
#   Comfort & Convenience 16 Leather seats  \
# 0                                  False
# 1                                  False
#
#   Comfort & Convenience 17 Leather steering wheel  \
# 0                                            True
# 1                                            True
#
#   Comfort & Convenience 18 Light sensor  \
# 0                                  True
# 1                                 False
#
#   Comfort & Convenience 19 Lumbar support  \
# 0                                   False
# 1                                    True
#
#   Comfort & Convenience 20 Massage seats  \
# 0                                  False
# 1                                  False
#
#   Comfort & Convenience 21 Multi-function steering wheel  \
# 0                                               True
# 1                                              False
#
#   Comfort & Convenience 22 Navigation system  \
# 0                                       True
# 1                                      False
#
#   Comfort & Convenience 23 Panorama roof  \
# 0                                  False
# 1                                  False
#
#   Comfort & Convenience 24 Park Distance Control  \
# 0                                           True
# 1                                          False
#
#   Comfort & Convenience 25 Parking assist system camera  \
# 0                                              False
# 1                                              False
#
#   Comfort & Convenience 26 Parking assist system self-steering  \
# 0                                              False
# 1                                              False
#
#   Comfort & Convenience 27 Parking assist system sensors front  \
# 0                                              False
# 1                                              False
#
#   Comfort & Convenience 28 Parking assist system sensors rear  \
# 0                                               True
# 1                                               True
#
#   Comfort & Convenience 29 Power windows Comfort & Convenience 30 Rain sensor  \
# 0                                   True                                 True
# 1                                   True                                False
#
#   Comfort & Convenience 31 Seat heating  \
# 0                                  True
# 1                                 False
#
#   Comfort & Convenience 32 Seat ventilation  \
# 0                                     False
# 1                                     False
#
#   Comfort & Convenience 33 Split rear seats  \
# 0                                     False
# 1                                     False
#
#   Comfort & Convenience 34 Start-stop system Comfort & Convenience 35 Sunroof  \
# 0                                       True                            False
# 1                                       True                            False
#
#   Comfort & Convenience 36 Tinted windows  \
# 0                                   False
# 1                                    True
#
#   Comfort & Convenience 37 Wind deflector Comfort & Convenience 38 Windshield  \
# 0                                   False                               False
# 1                                   False                               False
#
#   Safety & Security 1 ABS Safety & Security 2 Adaptive Cruise Control  \
# 0                    True                                       False
# 1                    True                                       False
#
#   Safety & Security 3 Adaptive headlights Safety & Security 4 Alarm system  \
# 0                                   False                            False
# 1                                   False                            False
#
#   Safety & Security 5 Blind spot monitor  \
# 0                                  False
# 1                                  False
#
#   Safety & Security 6 Central door lock  \
# 0                                  True
# 1                                  True
#
#   Safety & Security 7 Central door lock with remote control  \
# 0                                              False
# 1                                               True
#
#   Safety & Security 8 Daytime running lights  \
# 0                                       True
# 1                                       True
#
#   Safety & Security 9 Driver drowsiness detection  \
# 0                                           False
# 1                                           False
#
#   Safety & Security 10 Driver-side airbag  \
# 0                                    True
# 1                                    True
#
#   Safety & Security 11 Electronic stability control  \
# 0                                              True
# 1                                              True
#
#   Safety & Security 12 Emergency brake assistant  \
# 0                                          False
# 1                                          False
#
#   Safety & Security 13 Emergency system Safety & Security 14 Fog lights  \
# 0                                 False                            True
# 1                                 False                           False
#
#   Safety & Security 15 Head airbag Safety & Security 16 Immobilizer  \
# 0                            False                             True
# 1                             True                             True
#
#   Safety & Security 17 Isofix Safety & Security 18 LED Daytime Running Lights  \
# 0                        True                                           False
# 1                        True                                           False
#
#   Safety & Security 19 LED Headlights  \
# 0                               False
# 1                               False
#
#   Safety & Security 20 Lane departure warning system  \
# 0                                              False
# 1                                              False
#
#   Safety & Security 21 Night view assist  \
# 0                                  False
# 1                                  False
#
#   Safety & Security 22 Passenger-side airbag  \
# 0                                       True
# 1                                       True
#
#   Safety & Security 23 Power steering Safety & Security 24 Rear airbag  \
# 0                                True                            False
# 1                                True                            False
#
#   Safety & Security 25 Side airbag  \
# 0                             True
# 1                             True
#
#   Safety & Security 26 Tire pressure monitoring system  \
# 0                                               True
# 1                                               True
#
#   Safety & Security 27 Traction control  \
# 0                                  True
# 1                                  True
#
#   Safety & Security 28 Traffic sign recognition  \
# 0                                         False
# 1                                         False
#
#   Safety & Security 29 Xenon headlights Extras 1 Alloy wheels  \
# 0                                  True                  True
# 1                                  True                  True
#
#   Extras 2 Cab or rented Car Extras 3 Catalytic Converter  \
# 0                      False                         True
# 1                      False                        False
#
#   Extras 4 Handicapped enabled Extras 5 Right hand drive Extras 6 Roof rack  \
# 0                        False                     False              False
# 1                        False                     False              False
#
#   Extras 7 Shift paddles Extras 8 Ski bag Extras 9 Sliding door  \
# 0                  False            False                 False
# 1                  False            False                 False
#
#   Extras 10 Sport package Extras 11 Sport seats Extras 12 Sport suspension  \
# 0                   False                 False                      False
# 1                   False                  True                       True
#
#   Extras 13 Touch screen Extras 14 Trailer hitch Extras 15 Tuned car  \
# 0                  False                   False               False
# 1                  False                   False               False
#
#   Extras 16 Voice Control Extras 17 Winter tyres  \
# 0                    True                  False
# 1                    True                  False
#
#   Entertainment & Media 1 Bluetooth Entertainment & Media 2 CD player  \
# 0                              True                             False
# 1                              True                             False
#
#   Entertainment & Media 3 Digital radio  \
# 0                                 False
# 1                                 False
#
#   Entertainment & Media 4 Hands-free equipment Entertainment & Media 5 MP3  \
# 0                                         True                       False
# 1                                         True                       False
#
#   Entertainment & Media 6 On-board computer Entertainment & Media 7 Radio  \
# 0                                      True                          True
# 1                                      True                          True
#
#   Entertainment & Media 8 Sound system Entertainment & Media 9 Television  \
# 0                                False                              False
# 1                                 True                              False
#
#   Entertainment & Media 10 USB Type2                        Type4  \
# 0                        False  Used  Diesel (Particulate Filter)
# 1                        False  Used                     Gasoline
#
#   Previous Owners1 Warranty1 Full Service3 First Registration2 Body Color2  \
# 0                2       NaN           NaN                2016       Black
# 1              NaN       NaN           NaN                2017         Red
#
#   Paint Type Body Color Original    Upholstery   Body2 Nr. of Doors  \
# 0   Metallic       Mythosschwarz  Cloth, Black  Sedans            5
# 1        NaN                 NaN   Cloth, Grey  Sedans            3
#
#   Nr. of Seats Gearing Type2  Displacement (cc) Cylinders Drive chain  \
# 0            5     Automatic                1.4         3       front
# 1            4     Automatic                1.8         4       front
#
#                          Fuel2 CO2 Emission (g CO2/km (comb)) Emission Class1  \
# 0  Diesel (Particulate Filter)                             99               6
# 1                     Gasoline                            129               6
#
#   Gears Country version Consumption l/100 km (comb)  \
# 0   NaN             NaN                         3.8
# 1     7             NaN                         5.6
#
#   Consumption l/100 km (city) Consumption l/100 km (country)
# 0                         4.3                            3.5
# 1                         7.1                            4.7

# %%
tempsem = fill_priority_temp(df,"Type2","Previous Owners1", "km", "registration")

# %%
col=  'Body2'
print(df[[col]].isnull().sum())
print("___________________________________________________")
print(df[col].value_counts(dropna = False))
print("___________________________________________________")
print(tempsem[[col]].isnull().sum())
print("___________________________________________________")
print(tempsem.head(5))
# Out:
# Body2    60
# dtype: int64
# ___________________________________________________
# Sedans           7903
# Station wagon    3553
# Compact          3153
#                  ...
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: Body2, Length: 10, dtype: int64
# ___________________________________________________
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-4ec2a158870e> in <module>
#       4 print(df[col].value_counts(dropna = False))
#       5 print("___________________________________________________")
# ----> 6 print(tempsem[[col]].isnull().sum())
#       7 print("___________________________________________________")
#       8 print(tempsem.head(5))
#
# /usr/local/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1551
# -> 1552         self._validate_read_indexer(
#    1553             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1554         )
#
# /usr/local/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1638             if missing == len(indexer):
#    1639                 axis_name = self.obj._get_axis_name(axis)
# -> 1640                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1641
#    1642             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['Body2'], dtype='object')] are in the [columns]"

# %%
for i in make_model_FirstRegistration2_Countryversion_list:
    tempsem = fill_priority_temp(df,i,"make_model", "First Registration2", "Country version")
    col= i
    print(df[[col]].isnull().sum())
    print("___________________________________________________")
    print(df[col].value_counts(dropna = False))
    print("___________________________________________________")
    print(tempsem[[col]].isnull().sum())
    print("___________________________________________________")
    print(tempsem.head(5))
# Out:
# Comfort & Convenience 1 Air conditioning    920
# dtype: int64
# ___________________________________________________
# True     14315
# NaN        920
# False      684
# Name: Comfort & Convenience 1 Air conditioning, dtype: int64
# ___________________________________________________
# Comfort & Convenience 1 Air conditioning    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 1 Air conditioning
# 0    Audi A1                                     True
# 1    Audi A1                                     True
# 2    Audi A1                                     True
# 3    Audi A1                                    False
# 4    Audi A1                                     True
# Comfort & Convenience 2 Air suspension    920
# dtype: int64
# ___________________________________________________
# False    14937
# NaN        920
# True        62
# Name: Comfort & Convenience 2 Air suspension, dtype: int64
# ___________________________________________________
# Comfort & Convenience 2 Air suspension    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 2 Air suspension
# 0    Audi A1                                  False
# 1    Audi A1                                  False
# 2    Audi A1                                  False
# 3    Audi A1                                   True
# 4    Audi A1                                  False
# Comfort & Convenience 3 Armrest    920
# dtype: int64
# ___________________________________________________
# False    7774
# True     7225
# NaN       920
# Name: Comfort & Convenience 3 Armrest, dtype: int64
# ___________________________________________________
# Comfort & Convenience 3 Armrest    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 3 Armrest
# 0    Audi A1                            True
# 1    Audi A1                           False
# 2    Audi A1                           False
# 3    Audi A1                            True
# 4    Audi A1                            True
# Comfort & Convenience 4 Automatic climate control    920
# dtype: int64
# ___________________________________________________
# True     8747
# False    6252
# NaN       920
# Name: Comfort & Convenience 4 Automatic climate control, dtype: int64
# ___________________________________________________
# Comfort & Convenience 4 Automatic climate control    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 4 Automatic climate control
# 0    Audi A1                                              True
# 1    Audi A1                                              True
# 2    Audi A1                                             False
# 3    Audi A1                                             False
# 4    Audi A1                                              True
# Comfort & Convenience 5 Auxiliary heating    920
# dtype: int64
# ___________________________________________________
# False    14733
# NaN        920
# True       266
# Name: Comfort & Convenience 5 Auxiliary heating, dtype: int64
# ___________________________________________________
# Comfort & Convenience 5 Auxiliary heating    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 5 Auxiliary heating
# 0    Audi A1                                     False
# 1    Audi A1                                     False
# 2    Audi A1                                     False
# 3    Audi A1                                      True
# 4    Audi A1                                     False
# Comfort & Convenience 6 Cruise control    920
# dtype: int64
# ___________________________________________________
# True     10881
# False     4118
# NaN        920
# Name: Comfort & Convenience 6 Cruise control, dtype: int64
# ___________________________________________________
# Comfort & Convenience 6 Cruise control    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 6 Cruise control
# 0    Audi A1                                   True
# 1    Audi A1                                  False
# 2    Audi A1                                   True
# 3    Audi A1                                  False
# 4    Audi A1                                  False
# Comfort & Convenience 7 Electric Starter    920
# dtype: int64
# ___________________________________________________
# False    14998
# NaN        920
# True         1
# Name: Comfort & Convenience 7 Electric Starter, dtype: int64
# ___________________________________________________
# Comfort & Convenience 7 Electric Starter    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 7 Electric Starter
# 0    Audi A1                                    False
# 1    Audi A1                                    False
# 2    Audi A1                                    False
# 3    Audi A1                                    False
# 4    Audi A1                                    False
# Comfort & Convenience 8 Electric tailgate    920
# dtype: int64
# ___________________________________________________
# False    13996
# True      1003
# NaN        920
# Name: Comfort & Convenience 8 Electric tailgate, dtype: int64
# ___________________________________________________
# Comfort & Convenience 8 Electric tailgate    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 8 Electric tailgate
# 0    Audi A1                                     False
# 1    Audi A1                                     False
# 2    Audi A1                                     False
# 3    Audi A1                                     False
# 4    Audi A1                                     False
# Comfort & Convenience 9 Electrical side mirrors    920
# dtype: int64
# ___________________________________________________
# True     11881
# False     3118
# NaN        920
# Name: Comfort & Convenience 9 Electrical side mirrors, dtype: int64
# ___________________________________________________
# Comfort & Convenience 9 Electrical side mirrors    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 9 Electrical side mirrors
# 0    Audi A1                                            True
# 1    Audi A1                                           False
# 2    Audi A1                                            True
# 3    Audi A1                                            True
# 4    Audi A1                                            True
# Comfort & Convenience 10 Electrically adjustable seats    920
# dtype: int64
# ___________________________________________________
# False    13133
# True      1866
# NaN        920
# Name: Comfort & Convenience 10 Electrically adjustable seats, dtype: int64
# ___________________________________________________
# Comfort & Convenience 10 Electrically adjustable seats    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 10 Electrically adjustable seats
# 0    Audi A1                                              False
# 1    Audi A1                                              False
# 2    Audi A1                                              False
# 3    Audi A1                                              False
# 4    Audi A1                                              False
# Comfort & Convenience 11 Electrically heated windshield    920
# dtype: int64
# ___________________________________________________
# False    14062
# True       937
# NaN        920
# Name: Comfort & Convenience 11 Electrically heated windshield, dtype: int64
# ___________________________________________________
# Comfort & Convenience 11 Electrically heated windshield    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 11 Electrically heated windshield
# 0    Audi A1                                              False
# 1    Audi A1                                              False
# 2    Audi A1                                              False
# 3    Audi A1                                              False
# 4    Audi A1                                              False
# Comfort & Convenience 12 Heads-up display    920
# dtype: int64
# ___________________________________________________
# False    14393
# NaN        920
# True       606
# Name: Comfort & Convenience 12 Heads-up display, dtype: int64
# ___________________________________________________
# Comfort & Convenience 12 Heads-up display    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 12 Heads-up display
# 0    Audi A1                                     False
# 1    Audi A1                                     False
# 2    Audi A1                                     False
# 3    Audi A1                                      True
# 4    Audi A1                                     False
# Comfort & Convenience 13 Heated steering wheel    920
# dtype: int64
# ___________________________________________________
# False    11982
# True      3017
# NaN        920
# Name: Comfort & Convenience 13 Heated steering wheel, dtype: int64
# ___________________________________________________
# Comfort & Convenience 13 Heated steering wheel    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 13 Heated steering wheel
# 0    Audi A1                                          False
# 1    Audi A1                                          False
# 2    Audi A1                                          False
# 3    Audi A1                                          False
# 4    Audi A1                                          False
# Comfort & Convenience 14 Hill Holder    920
# dtype: int64
# ___________________________________________________
# False    8254
# True     6745
# NaN       920
# Name: Comfort & Convenience 14 Hill Holder, dtype: int64
# ___________________________________________________
# Comfort & Convenience 14 Hill Holder    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 14 Hill Holder
# 0    Audi A1                                 True
# 1    Audi A1                                 True
# 2    Audi A1                                 True
# 3    Audi A1                                 True
# 4    Audi A1                                 True
# Comfort & Convenience 15 Keyless central door lock    920
# dtype: int64
# ___________________________________________________
# False    12386
# True      2613
# NaN        920
# Name: Comfort & Convenience 15 Keyless central door lock, dtype: int64
# ___________________________________________________
# Comfort & Convenience 15 Keyless central door lock    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 15 Keyless central door lock
# 0    Audi A1                                              False
# 1    Audi A1                                              False
# 2    Audi A1                                              False
# 3    Audi A1                                              False
# 4    Audi A1                                              False
# Comfort & Convenience 16 Leather seats    920
# dtype: int64
# ___________________________________________________
# False    14951
# NaN        920
# True        48
# Name: Comfort & Convenience 16 Leather seats, dtype: int64
# ___________________________________________________
# Comfort & Convenience 16 Leather seats    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 16 Leather seats
# 0    Audi A1                                  False
# 1    Audi A1                                  False
# 2    Audi A1                                  False
# 3    Audi A1                                  False
# 4    Audi A1                                  False
# Comfort & Convenience 17 Leather steering wheel    920
# dtype: int64
# ___________________________________________________
# True     9386
# False    5613
# NaN       920
# Name: Comfort & Convenience 17 Leather steering wheel, dtype: int64
# ___________________________________________________
# Comfort & Convenience 17 Leather steering wheel    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 17 Leather steering wheel
# 0    Audi A1                                            True
# 1    Audi A1                                            True
# 2    Audi A1                                            True
# 3    Audi A1                                            True
# 4    Audi A1                                            True
# Comfort & Convenience 18 Light sensor    920
# dtype: int64
# ___________________________________________________
# True     7672
# False    7327
# NaN       920
# Name: Comfort & Convenience 18 Light sensor, dtype: int64
# ___________________________________________________
# Comfort & Convenience 18 Light sensor    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 18 Light sensor
# 0    Audi A1                                  True
# 1    Audi A1                                 False
# 2    Audi A1                                 False
# 3    Audi A1                                  True
# 4    Audi A1                                  True
# Comfort & Convenience 19 Lumbar support    920
# dtype: int64
# ___________________________________________________
# False    11773
# True      3226
# NaN        920
# Name: Comfort & Convenience 19 Lumbar support, dtype: int64
# ___________________________________________________
# Comfort & Convenience 19 Lumbar support    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 19 Lumbar support
# 0    Audi A1                                   False
# 1    Audi A1                                    True
# 2    Audi A1                                   False
# 3    Audi A1                                    True
# 4    Audi A1                                   False
# Comfort & Convenience 20 Massage seats    920
# dtype: int64
# ___________________________________________________
# False    14639
# NaN        920
# True       360
# Name: Comfort & Convenience 20 Massage seats, dtype: int64
# ___________________________________________________
# Comfort & Convenience 20 Massage seats    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 20 Massage seats
# 0    Audi A1                                  False
# 1    Audi A1                                  False
# 2    Audi A1                                  False
# 3    Audi A1                                  False
# 4    Audi A1                                  False
# Comfort & Convenience 21 Multi-function steering wheel    920
# dtype: int64
# ___________________________________________________
# True     11083
# False     3916
# NaN        920
# Name: Comfort & Convenience 21 Multi-function steering wheel, dtype: int64
# ___________________________________________________
# Comfort & Convenience 21 Multi-function steering wheel    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 21 Multi-function steering wheel
# 0    Audi A1                                               True
# 1    Audi A1                                              False
# 2    Audi A1                                               True
# 3    Audi A1                                               True
# 4    Audi A1                                               True
# Comfort & Convenience 22 Navigation system    920
# dtype: int64
# ___________________________________________________
# True     8166
# False    6833
# NaN       920
# Name: Comfort & Convenience 22 Navigation system, dtype: int64
# ___________________________________________________
# Comfort & Convenience 22 Navigation system    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 22 Navigation system
# 0    Audi A1                                       True
# 1    Audi A1                                      False
# 2    Audi A1                                       True
# 3    Audi A1                                       True
# 4    Audi A1                                      False
# Comfort & Convenience 23 Panorama roof    920
# dtype: int64
# ___________________________________________________
# False    14448
# NaN        920
# True       551
# Name: Comfort & Convenience 23 Panorama roof, dtype: int64
# ___________________________________________________
# Comfort & Convenience 23 Panorama roof    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 23 Panorama roof
# 0    Audi A1                                  False
# 1    Audi A1                                  False
# 2    Audi A1                                  False
# 3    Audi A1                                  False
# 4    Audi A1                                  False
# Comfort & Convenience 24 Park Distance Control    920
# dtype: int64
# ___________________________________________________
# True     10190
# False     4809
# NaN        920
# Name: Comfort & Convenience 24 Park Distance Control, dtype: int64
# ___________________________________________________
# Comfort & Convenience 24 Park Distance Control    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 24 Park Distance Control
# 0    Audi A1                                           True
# 1    Audi A1                                          False
# 2    Audi A1                                           True
# 3    Audi A1                                          False
# 4    Audi A1                                           True
# Comfort & Convenience 25 Parking assist system camera    920
# dtype: int64
# ___________________________________________________
# False    11578
# True      3421
# NaN        920
# Name: Comfort & Convenience 25 Parking assist system camera, dtype: int64
# ___________________________________________________
# Comfort & Convenience 25 Parking assist system camera    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 25 Parking assist system camera
# 0    Audi A1                                              False
# 1    Audi A1                                              False
# 2    Audi A1                                              False
# 3    Audi A1                                              False
# 4    Audi A1                                              False
# Comfort & Convenience 26 Parking assist system self-steering    920
# dtype: int64
# ___________________________________________________
# False    14231
# NaN        920
# True       768
# Name: Comfort & Convenience 26 Parking assist system self-steering, dtype: int64
# ___________________________________________________
# Comfort & Convenience 26 Parking assist system self-steering    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 26 Parking assist system self-steering
# 0    Audi A1                                              False
# 1    Audi A1                                              False
# 2    Audi A1                                              False
# 3    Audi A1                                              False
# 4    Audi A1                                              False
# Comfort & Convenience 27 Parking assist system sensors front    920
# dtype: int64
# ___________________________________________________
# False    9161
# True     5838
# NaN       920
# Name: Comfort & Convenience 27 Parking assist system sensors front, dtype: int64
# ___________________________________________________
# Comfort & Convenience 27 Parking assist system sensors front    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 27 Parking assist system sensors front
# 0    Audi A1                                              False
# 1    Audi A1                                              False
# 2    Audi A1                                               True
# 3    Audi A1                                              False
# 4    Audi A1                                              False
# Comfort & Convenience 28 Parking assist system sensors rear    920
# dtype: int64
# ___________________________________________________
# True     9694
# False    5305
# NaN       920
# Name: Comfort & Convenience 28 Parking assist system sensors rear, dtype: int64
# ___________________________________________________
# Comfort & Convenience 28 Parking assist system sensors rear    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 28 Parking assist system sensors rear
# 0    Audi A1                                               True
# 1    Audi A1                                               True
# 2    Audi A1                                               True
# 3    Audi A1                                              False
# 4    Audi A1                                               True
# Comfort & Convenience 29 Power windows    920
# dtype: int64
# ___________________________________________________
# True     13914
# False     1085
# NaN        920
# Name: Comfort & Convenience 29 Power windows, dtype: int64
# ___________________________________________________
# Comfort & Convenience 29 Power windows    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 29 Power windows
# 0    Audi A1                                   True
# 1    Audi A1                                   True
# 2    Audi A1                                   True
# 3    Audi A1                                   True
# 4    Audi A1                                   True
# Comfort & Convenience 30 Rain sensor    920
# dtype: int64
# ___________________________________________________
# True     8615
# False    6384
# NaN       920
# Name: Comfort & Convenience 30 Rain sensor, dtype: int64
# ___________________________________________________
# Comfort & Convenience 30 Rain sensor    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 30 Rain sensor
# 0    Audi A1                                 True
# 1    Audi A1                                False
# 2    Audi A1                                False
# 3    Audi A1                                 True
# 4    Audi A1                                 True
# Comfort & Convenience 31 Seat heating    920
# dtype: int64
# ___________________________________________________
# False    7921
# True     7078
# NaN       920
# Name: Comfort & Convenience 31 Seat heating, dtype: int64
# ___________________________________________________
# Comfort & Convenience 31 Seat heating    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 31 Seat heating
# 0    Audi A1                                  True
# 1    Audi A1                                 False
# 2    Audi A1                                  True
# 3    Audi A1                                  True
# 4    Audi A1                                 False
# Comfort & Convenience 32 Seat ventilation    920
# dtype: int64
# ___________________________________________________
# False    14165
# NaN        920
# True       834
# Name: Comfort & Convenience 32 Seat ventilation, dtype: int64
# ___________________________________________________
# Comfort & Convenience 32 Seat ventilation    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 32 Seat ventilation
# 0    Audi A1                                     False
# 1    Audi A1                                     False
# 2    Audi A1                                     False
# 3    Audi A1                                     False
# 4    Audi A1                                     False
# Comfort & Convenience 33 Split rear seats    920
# dtype: int64
# ___________________________________________________
# False    12612
# True      2387
# NaN        920
# Name: Comfort & Convenience 33 Split rear seats, dtype: int64
# ___________________________________________________
# Comfort & Convenience 33 Split rear seats    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 33 Split rear seats
# 0    Audi A1                                     False
# 1    Audi A1                                     False
# 2    Audi A1                                     False
# 3    Audi A1                                      True
# 4    Audi A1                                     False
# Comfort & Convenience 34 Start-stop system    920
# dtype: int64
# ___________________________________________________
# True     8881
# False    6118
# NaN       920
# Name: Comfort & Convenience 34 Start-stop system, dtype: int64
# ___________________________________________________
# Comfort & Convenience 34 Start-stop system    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 34 Start-stop system
# 0    Audi A1                                       True
# 1    Audi A1                                       True
# 2    Audi A1                                       True
# 3    Audi A1                                       True
# 4    Audi A1                                       True
# Comfort & Convenience 35 Sunroof    920
# dtype: int64
# ___________________________________________________
# False    14627
# NaN        920
# True       372
# Name: Comfort & Convenience 35 Sunroof, dtype: int64
# ___________________________________________________
# Comfort & Convenience 35 Sunroof    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 35 Sunroof
# 0    Audi A1                            False
# 1    Audi A1                            False
# 2    Audi A1                            False
# 3    Audi A1                            False
# 4    Audi A1                            False
# Comfort & Convenience 36 Tinted windows    920
# dtype: int64
# ___________________________________________________
# False    13555
# True      1444
# NaN        920
# Name: Comfort & Convenience 36 Tinted windows, dtype: int64
# ___________________________________________________
# Comfort & Convenience 36 Tinted windows    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 36 Tinted windows
# 0    Audi A1                                   False
# 1    Audi A1                                    True
# 2    Audi A1                                   False
# 3    Audi A1                                   False
# 4    Audi A1                                   False
# Comfort & Convenience 37 Wind deflector    920
# dtype: int64
# ___________________________________________________
# False    14958
# NaN        920
# True        41
# Name: Comfort & Convenience 37 Wind deflector, dtype: int64
# ___________________________________________________
# Comfort & Convenience 37 Wind deflector    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 37 Wind deflector
# 0    Audi A1                                   False
# 1    Audi A1                                   False
# 2    Audi A1                                   False
# 3    Audi A1                                   False
# 4    Audi A1                                   False
# Comfort & Convenience 38 Windshield    920
# dtype: int64
# ___________________________________________________
# False    14987
# NaN        920
# True        12
# Name: Comfort & Convenience 38 Windshield, dtype: int64
# ___________________________________________________
# Comfort & Convenience 38 Windshield    0
# dtype: int64
# ___________________________________________________
#   make_model Comfort & Convenience 38 Windshield
# 0    Audi A1                               False
# 1    Audi A1                               False
# 2    Audi A1                               False
# 3    Audi A1                               False
# 4    Audi A1                               False
# Safety & Security 1 ABS    982
# dtype: int64
# ___________________________________________________
# True     14130
# NaN        982
# False      807
# Name: Safety & Security 1 ABS, dtype: int64
# ___________________________________________________
# Safety & Security 1 ABS    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 1 ABS
# 0    Audi A1                    True
# 1    Audi A1                    True
# 2    Audi A1                    True
# 3    Audi A1                    True
# 4    Audi A1                    True
# Safety & Security 2 Adaptive Cruise Control    982
# dtype: int64
# ___________________________________________________
# False    13634
# True      1303
# NaN        982
# Name: Safety & Security 2 Adaptive Cruise Control, dtype: int64
# ___________________________________________________
# Safety & Security 2 Adaptive Cruise Control    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 2 Adaptive Cruise Control
# 0    Audi A1                                       False
# 1    Audi A1                                       False
# 2    Audi A1                                       False
# 3    Audi A1                                       False
# 4    Audi A1                                       False
# Safety & Security 3 Adaptive headlights    982
# dtype: int64
# ___________________________________________________
# False    12896
# True      2041
# NaN        982
# Name: Safety & Security 3 Adaptive headlights, dtype: int64
# ___________________________________________________
# Safety & Security 3 Adaptive headlights    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 3 Adaptive headlights
# 0    Audi A1                                   False
# 1    Audi A1                                   False
# 2    Audi A1                                   False
# 3    Audi A1                                   False
# 4    Audi A1                                   False
# Safety & Security 4 Alarm system    982
# dtype: int64
# ___________________________________________________
# False    13015
# True      1922
# NaN        982
# Name: Safety & Security 4 Alarm system, dtype: int64
# ___________________________________________________
# Safety & Security 4 Alarm system    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 4 Alarm system
# 0    Audi A1                            False
# 1    Audi A1                            False
# 2    Audi A1                            False
# 3    Audi A1                             True
# 4    Audi A1                            False
# Safety & Security 5 Blind spot monitor    982
# dtype: int64
# ___________________________________________________
# False    13646
# True      1291
# NaN        982
# Name: Safety & Security 5 Blind spot monitor, dtype: int64
# ___________________________________________________
# Safety & Security 5 Blind spot monitor    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 5 Blind spot monitor
# 0    Audi A1                                  False
# 1    Audi A1                                  False
# 2    Audi A1                                  False
# 3    Audi A1                                  False
# 4    Audi A1                                  False
# Safety & Security 6 Central door lock    982
# dtype: int64
# ___________________________________________________
# True     12707
# False     2230
# NaN        982
# Name: Safety & Security 6 Central door lock, dtype: int64
# ___________________________________________________
# Safety & Security 6 Central door lock    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 6 Central door lock
# 0    Audi A1                                  True
# 1    Audi A1                                  True
# 2    Audi A1                                  True
# 3    Audi A1                                 False
# 4    Audi A1                                  True
# Safety & Security 7 Central door lock with remote control    982
# dtype: int64
# ___________________________________________________
# False    12540
# True      2397
# NaN        982
# Name: Safety & Security 7 Central door lock with remote control, dtype: int64
# ___________________________________________________
# Safety & Security 7 Central door lock with remote control    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 7 Central door lock with remote control
# 0    Audi A1                                              False
# 1    Audi A1                                               True
# 2    Audi A1                                              False
# 3    Audi A1                                               True
# 4    Audi A1                                              False
# Safety & Security 8 Daytime running lights    982
# dtype: int64
# ___________________________________________________
# True     10412
# False     4525
# NaN        982
# Name: Safety & Security 8 Daytime running lights, dtype: int64
# ___________________________________________________
# Safety & Security 8 Daytime running lights    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 8 Daytime running lights
# 0    Audi A1                                       True
# 1    Audi A1                                       True
# 2    Audi A1                                       True
# 3    Audi A1                                      False
# 4    Audi A1                                      False
# Safety & Security 9 Driver drowsiness detection    982
# dtype: int64
# ___________________________________________________
# False    14431
# NaN        982
# True       506
# Name: Safety & Security 9 Driver drowsiness detection, dtype: int64
# ___________________________________________________
# Safety & Security 9 Driver drowsiness detection    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 9 Driver drowsiness detection
# 0    Audi A1                                           False
# 1    Audi A1                                           False
# 2    Audi A1                                           False
# 3    Audi A1                                            True
# 4    Audi A1                                           False
# Safety & Security 10 Driver-side airbag    982
# dtype: int64
# ___________________________________________________
# True     13902
# False     1035
# NaN        982
# Name: Safety & Security 10 Driver-side airbag, dtype: int64
# ___________________________________________________
# Safety & Security 10 Driver-side airbag    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 10 Driver-side airbag
# 0    Audi A1                                    True
# 1    Audi A1                                    True
# 2    Audi A1                                    True
# 3    Audi A1                                    True
# 4    Audi A1                                    True
# Safety & Security 11 Electronic stability control    982
# dtype: int64
# ___________________________________________________
# True     13187
# False     1750
# NaN        982
# Name: Safety & Security 11 Electronic stability control, dtype: int64
# ___________________________________________________
# Safety & Security 11 Electronic stability control    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 11 Electronic stability control
# 0    Audi A1                                              True
# 1    Audi A1                                              True
# 2    Audi A1                                              True
# 3    Audi A1                                              True
# 4    Audi A1                                              True
# Safety & Security 12 Emergency brake assistant    982
# dtype: int64
# ___________________________________________________
# False    11786
# True      3151
# NaN        982
# Name: Safety & Security 12 Emergency brake assistant, dtype: int64
# ___________________________________________________
# Safety & Security 12 Emergency brake assistant    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 12 Emergency brake assistant
# 0    Audi A1                                          False
# 1    Audi A1                                          False
# 2    Audi A1                                          False
# 3    Audi A1                                          False
# 4    Audi A1                                          False
# Safety & Security 13 Emergency system    982
# dtype: int64
# ___________________________________________________
# False    13361
# True      1576
# NaN        982
# Name: Safety & Security 13 Emergency system, dtype: int64
# ___________________________________________________
# Safety & Security 13 Emergency system    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 13 Emergency system
# 0    Audi A1                                 False
# 1    Audi A1                                 False
# 2    Audi A1                                 False
# 3    Audi A1                                  True
# 4    Audi A1                                 False
# Safety & Security 14 Fog lights    982
# dtype: int64
# ___________________________________________________
# True     8212
# False    6725
# NaN       982
# Name: Safety & Security 14 Fog lights, dtype: int64
# ___________________________________________________
# Safety & Security 14 Fog lights    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 14 Fog lights
# 0    Audi A1                            True
# 1    Audi A1                           False
# 2    Audi A1                           False
# 3    Audi A1                           False
# 4    Audi A1                            True
# Safety & Security 15 Head airbag    982
# dtype: int64
# ___________________________________________________
# False    12751
# True      2186
# NaN        982
# Name: Safety & Security 15 Head airbag, dtype: int64
# ___________________________________________________
# Safety & Security 15 Head airbag    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 15 Head airbag
# 0    Audi A1                            False
# 1    Audi A1                             True
# 2    Audi A1                            False
# 3    Audi A1                             True
# 4    Audi A1                            False
# Safety & Security 16 Immobilizer    982
# dtype: int64
# ___________________________________________________
# True     10499
# False     4438
# NaN        982
# Name: Safety & Security 16 Immobilizer, dtype: int64
# ___________________________________________________
# Safety & Security 16 Immobilizer    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 16 Immobilizer
# 0    Audi A1                             True
# 1    Audi A1                             True
# 2    Audi A1                             True
# 3    Audi A1                             True
# 4    Audi A1                             True
# Safety & Security 17 Isofix    982
# dtype: int64
# ___________________________________________________
# True     11744
# False     3193
# NaN        982
# Name: Safety & Security 17 Isofix, dtype: int64
# ___________________________________________________
# Safety & Security 17 Isofix    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 17 Isofix
# 0    Audi A1                        True
# 1    Audi A1                        True
# 2    Audi A1                        True
# 3    Audi A1                        True
# 4    Audi A1                        True
# Safety & Security 18 LED Daytime Running Lights    982
# dtype: int64
# ___________________________________________________
# False    9431
# True     5506
# NaN       982
# Name: Safety & Security 18 LED Daytime Running Lights, dtype: int64
# ___________________________________________________
# Safety & Security 18 LED Daytime Running Lights    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 18 LED Daytime Running Lights
# 0    Audi A1                                           False
# 1    Audi A1                                           False
# 2    Audi A1                                           False
# 3    Audi A1                                           False
# 4    Audi A1                                           False
# Safety & Security 19 LED Headlights    982
# dtype: int64
# ___________________________________________________
# False    11872
# True      3065
# NaN        982
# Name: Safety & Security 19 LED Headlights, dtype: int64
# ___________________________________________________
# Safety & Security 19 LED Headlights    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 19 LED Headlights
# 0    Audi A1                               False
# 1    Audi A1                               False
# 2    Audi A1                               False
# 3    Audi A1                               False
# 4    Audi A1                               False
# Safety & Security 20 Lane departure warning system    982
# dtype: int64
# ___________________________________________________
# False    11883
# True      3054
# NaN        982
# Name: Safety & Security 20 Lane departure warning system, dtype: int64
# ___________________________________________________
# Safety & Security 20 Lane departure warning system    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 20 Lane departure warning system
# 0    Audi A1                                              False
# 1    Audi A1                                              False
# 2    Audi A1                                              False
# 3    Audi A1                                              False
# 4    Audi A1                                              False
# Safety & Security 21 Night view assist    982
# dtype: int64
# ___________________________________________________
# False    14862
# NaN        982
# True        75
# Name: Safety & Security 21 Night view assist, dtype: int64
# ___________________________________________________
# Safety & Security 21 Night view assist    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 21 Night view assist
# 0    Audi A1                                  False
# 1    Audi A1                                  False
# 2    Audi A1                                  False
# 3    Audi A1                                  False
# 4    Audi A1                                  False
# Safety & Security 22 Passenger-side airbag    982
# dtype: int64
# ___________________________________________________
# True     13435
# False     1502
# NaN        982
# Name: Safety & Security 22 Passenger-side airbag, dtype: int64
# ___________________________________________________
# Safety & Security 22 Passenger-side airbag    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 22 Passenger-side airbag
# 0    Audi A1                                       True
# 1    Audi A1                                       True
# 2    Audi A1                                       True
# 3    Audi A1                                       True
# 4    Audi A1                                       True
# Safety & Security 23 Power steering    982
# dtype: int64
# ___________________________________________________
# True     13599
# False     1338
# NaN        982
# Name: Safety & Security 23 Power steering, dtype: int64
# ___________________________________________________
# Safety & Security 23 Power steering    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 23 Power steering
# 0    Audi A1                                True
# 1    Audi A1                                True
# 2    Audi A1                                True
# 3    Audi A1                                True
# 4    Audi A1                                True
# Safety & Security 24 Rear airbag    982
# dtype: int64
# ___________________________________________________
# False    14071
# NaN        982
# True       866
# Name: Safety & Security 24 Rear airbag, dtype: int64
# ___________________________________________________
# Safety & Security 24 Rear airbag    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 24 Rear airbag
# 0    Audi A1                            False
# 1    Audi A1                            False
# 2    Audi A1                            False
# 3    Audi A1                            False
# 4    Audi A1                            False
# Safety & Security 25 Side airbag    982
# dtype: int64
# ___________________________________________________
# True     13203
# False     1734
# NaN        982
# Name: Safety & Security 25 Side airbag, dtype: int64
# ___________________________________________________
# Safety & Security 25 Side airbag    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 25 Side airbag
# 0    Audi A1                             True
# 1    Audi A1                             True
# 2    Audi A1                             True
# 3    Audi A1                             True
# 4    Audi A1                             True
# Safety & Security 26 Tire pressure monitoring system    982
# dtype: int64
# ___________________________________________________
# True     10604
# False     4333
# NaN        982
# Name: Safety & Security 26 Tire pressure monitoring system, dtype: int64
# ___________________________________________________
# Safety & Security 26 Tire pressure monitoring system    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 26 Tire pressure monitoring system
# 0    Audi A1                                               True
# 1    Audi A1                                               True
# 2    Audi A1                                               True
# 3    Audi A1                                               True
# 4    Audi A1                                               True
# Safety & Security 27 Traction control    982
# dtype: int64
# ___________________________________________________
# True     11004
# False     3933
# NaN        982
# Name: Safety & Security 27 Traction control, dtype: int64
# ___________________________________________________
# Safety & Security 27 Traction control    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 27 Traction control
# 0    Audi A1                                  True
# 1    Audi A1                                  True
# 2    Audi A1                                  True
# 3    Audi A1                                 False
# 4    Audi A1                                  True
# Safety & Security 28 Traffic sign recognition    982
# dtype: int64
# ___________________________________________________
# False    12961
# True      1976
# NaN        982
# Name: Safety & Security 28 Traffic sign recognition, dtype: int64
# ___________________________________________________
# Safety & Security 28 Traffic sign recognition    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 28 Traffic sign recognition
# 0    Audi A1                                         False
# 1    Audi A1                                         False
# 2    Audi A1                                         False
# 3    Audi A1                                         False
# 4    Audi A1                                         False
# Safety & Security 29 Xenon headlights    982
# dtype: int64
# ___________________________________________________
# False    11398
# True      3539
# NaN        982
# Name: Safety & Security 29 Xenon headlights, dtype: int64
# ___________________________________________________
# Safety & Security 29 Xenon headlights    0
# dtype: int64
# ___________________________________________________
#   make_model Safety & Security 29 Xenon headlights
# 0    Audi A1                                  True
# 1    Audi A1                                  True
# 2    Audi A1                                 False
# ...
# True        52
# Name: Extras 4 Handicapped enabled, dtype: int64
# ___________________________________________________
# Extras 4 Handicapped enabled    0
# dtype: int64
# ___________________________________________________
#   make_model Extras 4 Handicapped enabled
# 0    Audi A1                        False
# 1    Audi A1                        False
# 2    Audi A1                        False
# 3    Audi A1                        False
# 4    Audi A1                        False
# Extras 5 Right hand drive    2962
# dtype: int64
# ___________________________________________________
# False    12954
# NaN       2962
# True         3
# Name: Extras 5 Right hand drive, dtype: int64
# ___________________________________________________
# Extras 5 Right hand drive    0
# dtype: int64
# ___________________________________________________
#   make_model Extras 5 Right hand drive
# 0    Audi A1                     False
# 1    Audi A1                     False
# 2    Audi A1                     False
# 3    Audi A1                     False
# 4    Audi A1                     False
# Extras 6 Roof rack    2962
# dtype: int64
# ___________________________________________________
# False    10310
# NaN       2962
# True      2647
# Name: Extras 6 Roof rack, dtype: int64
# ___________________________________________________
# Extras 6 Roof rack    0
# dtype: int64
# ___________________________________________________
#   make_model Extras 6 Roof rack
# 0    Audi A1              False
# 1    Audi A1              False
# 2    Audi A1              False
# 3    Audi A1              False
# 4    Audi A1              False
# Extras 7 Shift paddles    2962
# dtype: int64
# ___________________________________________________
# False    12449
# NaN       2962
# True       508
# Name: Extras 7 Shift paddles, dtype: int64
# ___________________________________________________
# Extras 7 Shift paddles    0
# dtype: int64
# ___________________________________________________
#   make_model Extras 7 Shift paddles
# 0    Audi A1                  False
# 1    Audi A1                  False
# 2    Audi A1                  False
# 3    Audi A1                  False
# 4    Audi A1                  False
# Extras 8 Ski bag    2962
# dtype: int64
# ___________________________________________________
# False    12710
# NaN       2962
# True       247
# Name: Extras 8 Ski bag, dtype: int64
# ___________________________________________________
# Extras 8 Ski bag    0
# dtype: int64
# ___________________________________________________
#   make_model Extras 8 Ski bag
# 0    Audi A1            False
# 1    Audi A1            False
# 2    Audi A1            False
# 3    Audi A1            False
# 4    Audi A1            False
# Extras 9 Sliding door    2962
# dtype: int64
# ___________________________________________________
# False    12954
# NaN       2962
# True         3
# Name: Extras 9 Sliding door, dtype: int64
# ___________________________________________________
# Extras 9 Sliding door    0
# dtype: int64
# ___________________________________________________
#   make_model Extras 9 Sliding door
# 0    Audi A1                 False
# 1    Audi A1                 False
# 2    Audi A1                 False
# 3    Audi A1                 False
# 4    Audi A1                 False
# Extras 10 Sport package    2962
# dtype: int64
# ___________________________________________________
# False    11759
# NaN       2962
# True      1198
# Name: Extras 10 Sport package, dtype: int64
# ___________________________________________________
# Extras 10 Sport package    0
# dtype: int64
# ___________________________________________________
#   make_model Extras 10 Sport package
# 0    Audi A1                   False
# 1    Audi A1                   False
# 2    Audi A1                   False
# 3    Audi A1                   False
# 4    Audi A1                    True
# Extras 11 Sport seats    2962
# dtype: int64
# ___________________________________________________
# False    9859
# True     3098
# NaN      2962
# Name: Extras 11 Sport seats, dtype: int64
# ___________________________________________________
# Extras 11 Sport seats    0
# dtype: int64
# ___________________________________________________
#   make_model Extras 11 Sport seats
# 0    Audi A1                 False
# 1    Audi A1                  True
# 2    Audi A1                 False
# 3    Audi A1                  True
# 4    Audi A1                 False
# Extras 12 Sport suspension    2962
# dtype: int64
# ___________________________________________________
# False    11338
# NaN       2962
# True      1619
# Name: Extras 12 Sport suspension, dtype: int64
# ___________________________________________________
# Extras 12 Sport suspension    0
# dtype: int64
# ___________________________________________________
#   make_model Extras 12 Sport suspension
# 0    Audi A1                      False
# 1    Audi A1                       True
# 2    Audi A1                      False
# 3    Audi A1                      False
# 4    Audi A1                       True
# Extras 13 Touch screen    2962
# dtype: int64
# ___________________________________________________
# False    8914
# True     4043
# NaN      2962
# Name: Extras 13 Touch screen, dtype: int64
# ___________________________________________________
# Extras 13 Touch screen    0
# dtype: int64
# ___________________________________________________
#   make_model Extras 13 Touch screen
# 0    Audi A1                  False
# 1    Audi A1                  False
# 2    Audi A1                  False
# 3    Audi A1                  False
# 4    Audi A1                  False
# Extras 14 Trailer hitch    2962
# dtype: int64
# ___________________________________________________
# False    12303
# NaN       2962
# True       654
# Name: Extras 14 Trailer hitch, dtype: int64
# ___________________________________________________
# Extras 14 Trailer hitch    0
# dtype: int64
# ___________________________________________________
#   make_model Extras 14 Trailer hitch
# 0    Audi A1                   False
# 1    Audi A1                   False
# 2    Audi A1                   False
# 3    Audi A1                   False
# 4    Audi A1                   False
# Extras 15 Tuned car    2962
# dtype: int64
# ___________________________________________________
# False    12944
# NaN       2962
# True        13
# Name: Extras 15 Tuned car, dtype: int64
# ___________________________________________________
# Extras 15 Tuned car    0
# dtype: int64
# ___________________________________________________
#   make_model Extras 15 Tuned car
# 0    Audi A1               False
# 1    Audi A1               False
# 2    Audi A1               False
# 3    Audi A1               False
# 4    Audi A1               False
# Extras 16 Voice Control    2962
# dtype: int64
# ___________________________________________________
# False    8631
# True     4326
# NaN      2962
# Name: Extras 16 Voice Control, dtype: int64
# ___________________________________________________
# Extras 16 Voice Control    0
# dtype: int64
# ___________________________________________________
#   make_model Extras 16 Voice Control
# 0    Audi A1                    True
# 1    Audi A1                    True
# 2    Audi A1                    True
# 3    Audi A1                    True
# 4    Audi A1                    True
# Extras 17 Winter tyres    2962
# dtype: int64
# ___________________________________________________
# False    12711
# NaN       2962
# True       246
# Name: Extras 17 Winter tyres, dtype: int64
# ___________________________________________________
# Extras 17 Winter tyres    0
# dtype: int64
# ___________________________________________________
#   make_model Extras 17 Winter tyres
# 0    Audi A1                  False
# 1    Audi A1                  False
# 2    Audi A1                  False
# 3    Audi A1                  False
# 4    Audi A1                  False
# Entertainment & Media 1 Bluetooth    1374
# dtype: int64
# ___________________________________________________
# True     11650
# False     2895
# NaN       1374
# Name: Entertainment & Media 1 Bluetooth, dtype: int64
# ___________________________________________________
# Entertainment & Media 1 Bluetooth    0
# dtype: int64
# ___________________________________________________
#   make_model Entertainment & Media 1 Bluetooth
# 0    Audi A1                              True
# 1    Audi A1                              True
# 2    Audi A1                             False
# 3    Audi A1                              True
# 4    Audi A1                              True
# Entertainment & Media 2 CD player    1374
# dtype: int64
# ___________________________________________________
# False    9754
# True     4791
# NaN      1374
# Name: Entertainment & Media 2 CD player, dtype: int64
# ___________________________________________________
# Entertainment & Media 2 CD player    0
# dtype: int64
# ___________________________________________________
#   make_model Entertainment & Media 2 CD player
# 0    Audi A1                             False
# 1    Audi A1                             False
# 2    Audi A1                             False
# 3    Audi A1                              True
# 4    Audi A1                              True
# Entertainment & Media 3 Digital radio    1374
# dtype: int64
# ___________________________________________________
# False    12316
# True      2229
# NaN       1374
# Name: Entertainment & Media 3 Digital radio, dtype: int64
# ___________________________________________________
# Entertainment & Media 3 Digital radio    0
# dtype: int64
# ___________________________________________________
#   make_model Entertainment & Media 3 Digital radio
# 0    Audi A1                                 False
# 1    Audi A1                                 False
# 2    Audi A1                                 False
# 3    Audi A1                                 False
# 4    Audi A1                                 False
# Entertainment & Media 4 Hands-free equipment    1374
# dtype: int64
# ___________________________________________________
# True     9305
# False    5240
# NaN      1374
# Name: Entertainment & Media 4 Hands-free equipment, dtype: int64
# ___________________________________________________
# Entertainment & Media 4 Hands-free equipment    0
# dtype: int64
# ___________________________________________________
#   make_model Entertainment & Media 4 Hands-free equipment
# 0    Audi A1                                         True
# 1    Audi A1                                         True
# 2    Audi A1                                        False
# 3    Audi A1                                         True
# 4    Audi A1                                         True
# Entertainment & Media 5 MP3    1374
# dtype: int64
# ___________________________________________________
# False    8692
# True     5853
# NaN      1374
# Name: Entertainment & Media 5 MP3, dtype: int64
# ___________________________________________________
# Entertainment & Media 5 MP3    0
# dtype: int64
# ___________________________________________________
#   make_model Entertainment & Media 5 MP3
# 0    Audi A1                       False
# 1    Audi A1                       False
# 2    Audi A1                        True
# 3    Audi A1                        True
# 4    Audi A1                        True
# Entertainment & Media 6 On-board computer    1374
# dtype: int64
# ___________________________________________________
# True     11938
# False     2607
# NaN       1374
# Name: Entertainment & Media 6 On-board computer, dtype: int64
# ___________________________________________________
# Entertainment & Media 6 On-board computer    0
# dtype: int64
# ___________________________________________________
#   make_model Entertainment & Media 6 On-board computer
# 0    Audi A1                                      True
# 1    Audi A1                                      True
# 2    Audi A1                                      True
# 3    Audi A1                                      True
# 4    Audi A1                                      True
# Entertainment & Media 7 Radio    1374
# dtype: int64
# ___________________________________________________
# True     11989
# False     2556
# NaN       1374
# Name: Entertainment & Media 7 Radio, dtype: int64
# ___________________________________________________
# Entertainment & Media 7 Radio    0
# dtype: int64
# ___________________________________________________
#   make_model Entertainment & Media 7 Radio
# 0    Audi A1                          True
# 1    Audi A1                          True
# 2    Audi A1                         False
# 3    Audi A1                          True
# 4    Audi A1                          True
# Entertainment & Media 8 Sound system    1374
# dtype: int64
# ___________________________________________________
# False    12305
# True      2240
# NaN       1374
# Name: Entertainment & Media 8 Sound system, dtype: int64
# ___________________________________________________
# Entertainment & Media 8 Sound system    0
# dtype: int64
# ___________________________________________________
#   make_model Entertainment & Media 8 Sound system
# 0    Audi A1                                False
# 1    Audi A1                                 True
# 2    Audi A1                                False
# 3    Audi A1                                 True
# 4    Audi A1                                False
# Entertainment & Media 9 Television    1374
# dtype: int64
# ___________________________________________________
# False    14510
# NaN       1374
# True        35
# Name: Entertainment & Media 9 Television, dtype: int64
# ___________________________________________________
# Entertainment & Media 9 Television    0
# dtype: int64
# ___________________________________________________
#   make_model Entertainment & Media 9 Television
# 0    Audi A1                              False
# 1    Audi A1                              False
# 2    Audi A1                              False
# 3    Audi A1                              False
# 4    Audi A1                              False
# Entertainment & Media 10 USB    1374
# dtype: int64
# ___________________________________________________
# True     8158
# False    6387
# NaN      1374
# Name: Entertainment & Media 10 USB, dtype: int64
# ___________________________________________________
# Entertainment & Media 10 USB    0
# dtype: int64
# ___________________________________________________
#   make_model Entertainment & Media 10 USB
# 0    Audi A1                        False
# 1    Audi A1                        False
# 2    Audi A1                        False
# 3    Audi A1                         True
# 4    Audi A1                         True
# Consumption l/100 km (comb)    2883
# dtype: int64
# ___________________________________________________
# NaN    2883
# 3.9     732
# 4       712
#        ...
# 55        1
# 50        1
# 54        1
# Name: Consumption l/100 km (comb), Length: 72, dtype: int64
# ___________________________________________________
# Consumption l/100 km (comb)    0
# dtype: int64
# ___________________________________________________
#   make_model Consumption l/100 km (comb)
# 0    Audi A1                         3.8
# 1    Audi A1                         5.6
# 2    Audi A1                         3.8
# 3    Audi A1                         3.8
# 4    Audi A1                         4.1
# Consumption l/100 km (city)    2422
# dtype: int64
# ___________________________________________________
# NaN     2422
# 5        674
# 5.8      622
#         ...
# 19.9       1
# 9.7        1
# 10.4       1
# Name: Consumption l/100 km (city), Length: 88, dtype: int64
# ___________________________________________________
# Consumption l/100 km (city)    0
# dtype: int64
# ___________________________________________________
#   make_model Consumption l/100 km (city)
# 0    Audi A1                         4.3
# 1    Audi A1                         7.1
# 2    Audi A1                         4.4
# 3    Audi A1                         4.3
# 4    Audi A1                         4.6
# Consumption l/100 km (country)    3212
# dtype: int64
# ___________________________________________________
# NaN    3212
# 4.2    1101
# 3.7    1059
#        ...
# 1         1
# 6.1       1
# 8         1
# Name: Consumption l/100 km (country), Length: 58, dtype: int64
# ___________________________________________________
# Consumption l/100 km (country)    0
# dtype: int64
# ___________________________________________________
#   make_model Consumption l/100 km (country)
# 0    Audi A1                            3.5
# 1    Audi A1                            4.7
# 2    Audi A1                            3.4
# 3    Audi A1                            3.5
# 4    Audi A1                            3.8
