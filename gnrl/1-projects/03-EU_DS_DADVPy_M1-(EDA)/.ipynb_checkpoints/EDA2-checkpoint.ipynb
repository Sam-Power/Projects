# %%
### Comment Lines and useful info, commands

#grp_inx = list(df[df['make_model'] == 'Audi A3']['Body'].index)
#df[df["make_model"] == "Audi A3"]["body_type"].mode() ### Audi a3 lerdeki en cok body type.
#oto[col_name].iloc[grp_inx] = oto[col_name].iloc[grp_inx].fillna()
##############################################################################################
#[i for i in df.columns if df[i].notna().mean() < 0.5]

##############################################################################################

# in future i will update here to drop columns
# for i in df.columns:
#     if df.index.stop == df[i].isnull().sum():
#         print("------------------------->",i,df[i].isnull().sum())
#     print(i,df[i].isnull().sum())
##############################################################################################
# to see data in desired counts 
#pd.options.display.max_columns = 15
#pd.options.display.max_rows = 6
#############################################################################################
#df[["price"]].sort_values(by="price",axis=0)
#############################################################################################
#Delete rows that price is lower than 500Euros
#df.drop(df[df["price"]<500].index,inplace=True)
#############################################################################################
#df[["price"]].dropna()
#############################################################################################
#sns.boxplot(x='price',data = df)
#############################################################################################
#get_df_wo_outlier(df,"price")
#############################################################################################
#df.columns
#############################################################################################
#fix values at rows by deleting "\n" in it.
#dfdeneme  = df.replace("\n","")
#############################################################################################
#to have a quick look at data, which columns contain what and how many.
#for i in df.columns:
    #print(df[i].value_counts().rename_axis(i +' unique_values').reset_index(name=i +' counts'))
#############################################################################################    
# important_columns = ['make_model',
# 'km',
# 'registration',
# 'Type',
# 'Body',
# 'Gearing Type',
# 'Drive chain',
# 'Fuel',
# 'Consumption',
# 'Comfort & Convenience',
# 'Entertainment & Media',
# 'Extras',
# 'Safety & Security',
# 'Gears',
# 'Country version',
# 'Last Service Date']
#df[important_columns]
#############################################################################################
# if str(df.at[2765, 'Type'] == 'nan'):
#     print("sss")
# else:
#     print("aaa")
#############################################################################################
#get_all_df(df)
#df = df.astype({"Country version" : "str"})
#############################################################################################
#Convert list type columns to new column with list`s elements
# df = list_to_columns_add2(df,"Full Service") #### NO need to convert NAN to List..
# df = list_to_columns_add2(df,"Consumption") #### NO need to convert NAN to List..
# df = list_to_columns_add2(df,"Type") #### NO need to convert NAN to List..
#df  = list_to_columns_add2(df,"Country version")
#############################################################################################
#Nan_to_list(df,"Country version")
#df  = list_to_columns_add2(df,"Country version")
#df[["Country version"]]
#df[["Country version"]] = df[["Country version"]].replace('\\n',np.NaN, regex=True)
#df[["Country version"]]
#############################################################################################
#for i in df.columns:
    #print(i)
#############################################################################################
#print( [i for i in df["Body"][0] if i!='\n'] )
#############################################################################################
#list_of_columns
#non_list_of_columns
#############################################################################################
#pd.options.display.max_columns = 14
#pd.options.display.max_rows = 5
#df.columns.to_list()

# %% [markdown]
# # Functions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy.stats import zscore
import numpy as np
import itertools
import warnings
warnings.filterwarnings("ignore")

# %%
#Functions :
#convert lists values to new columns with this no need to change column type to string or NAN to [] values normally requires before applying below.
def list_to_columns(df,col): 
    dftemp = pd.DataFrame([pd.Series(x) for x in df[col]]) # that is better and quicker. no need to run NAN_to_list.?
    column_names= []
    max_element = len(max(df.loc[df[col].apply(lambda x : isinstance(x, list))][col], key=len))
    #max_element = len(max(df.loc[df[col].notna()][col], key=len))
    for i in range(max_element):
        column_names.append(col + str(i+1))
    dftemp.columns = column_names
    df = df.drop(col,axis=1)
    if max_element == 1:
        dftemp.rename(columns={col+'1': col},inplace = True)
    df_added = pd.concat([df, dftemp], axis=1, sort=False)
    return df_added

#Convert list of features as new columns and check if that feature exist on that car or not.
def list_to_feat_cols(df,col_list):
    dftemp = pd.DataFrame()
    for col in col_list:
        #max_list = max(df.loc[df[col].apply(lambda x : isinstance(x, list))][col], key=len)
        a = df[col].explode().unique()
        max_list = sorted([i for i in a if not pd.isnull(list(a)[list(a).index(i)])])
        for i in range(len(max_list)):
            dftemp[f"{col} {str(i+1)} {max_list[i]}"] = df[col].apply(lambda x : True if (type(x) == list and max_list[i] in x) \
               else (False if (type(x) == list and max_list[i] not in x) else x ))
        df = df.drop(col,axis=1)
    df_added = pd.concat([df, dftemp], axis=1, sort=False)
    return df_added


# check a column if it contains list of values. returns 2 list that we need to define
def check_is_list(df):
    list_of_columns = []
    non_list_of_columns = []
    for i in df.columns:
        counter_list=0
        counter_non_list=0
        for j in df[i].values:
            if isinstance(j, list):
                counter_list+=1
            else:
                counter_non_list+=1
        if counter_list > 0:
            list_of_columns.append(i)
        else :
            non_list_of_columns.append(i)
    return list_of_columns,non_list_of_columns
#changes a phrase in a list to another value
def del_str_phrase(phrase,liste):
    while(phrase in liste) : 
        liste.remove(phrase)
        
#get the df colon without outliers specified
def get_df_wo_outlier(df,col,range=1.5):
    Q1 = df[col].quantile(q=0.25)
    Q3 = df[col].quantile(q=0.75)
    IQR = Q3-Q1
    return df[col][~((df[col] <  Q1-(range*IQR)) |(df[col] > Q3+(range*IQR))) ]

#to have a look at data, which columns contain what and how many.
def get_all_df(df):
    for i in df.columns:
        print(df[i].value_counts(dropna = False).rename_axis(i +' unique_values').reset_index(name=i +' counts'))

#quick look on a column        
def get_col_details(df,col):
    print("VALUE COUNTS")
    print(df[col].value_counts(dropna=False))
    print("-----------------------\n","UNIQUE VALUES")
    print(df[col].unique())
    print("-----------------------\n","NULL SUM")
    print(df[col].isnull().sum())
    print("-----------------------\n","NULL Percentage")
    print(df[col].isnull().sum()*100 /df[col].index.stop )
    print("-----------------------\n","COLUMN with NONE-NULL-NAN")
    print(df.query(f'{col} != {col}')[col])
    
#updates values NAN to empty list : []
def Nan_to_list(df,col):
    Nan_rows = df[col].isnull()
    df.loc[Nan_rows,col] = df.loc[Nan_rows,col].apply(lambda x : [])
    
def outlier_zscore(df, col, min_z=1, max_z = 5, step = 0.1, print_list = False):
    z_scores = zscore(df[col].dropna())
    threshold_list = []
    for threshold in np.arange(min_z, max_z, step):
        threshold_list.append((threshold, len(np.where(z_scores > threshold)[0])))
        df_outlier = pd.DataFrame(threshold_list, columns = ['threshold', 'outlier_count'])
        df_outlier['pct'] = (df_outlier.outlier_count - df_outlier.outlier_count.shift(-1))/df_outlier.outlier_count*100
    plt.plot(df_outlier.threshold, df_outlier.outlier_count)
    best_treshold = round(df_outlier.iloc[df_outlier.pct.argmax(), 0],2)
    outlier_limit = int(df[col].dropna().mean() + (df[col].dropna().std()) * df_outlier.iloc[df_outlier.pct.argmax(), 0])
    percentile_threshold = stats.percentileofscore(df[col].dropna(), outlier_limit)
    plt.vlines(best_treshold, 0, df_outlier.outlier_count.max(), 
               colors="r", ls = ":"
              )
    plt.annotate("Zscore : {}\nValue : {}\nPercentile : {}".format(best_treshold, outlier_limit, 
                                                                   (np.round(percentile_threshold, 3), 
                                                                    np.round(100-percentile_threshold, 3))), 
                 (best_treshold, df_outlier.outlier_count.max()/2))
    #plt.show()
    if print_list:
        print(df_outlier)
    return (plt, df_outlier, best_treshold, outlier_limit, percentile)

def outlier_inspect(df, col, min_z=1, max_z = 5, step = 0.5, max_hist = None, bins = 50):
    fig = plt.figure(figsize=(20, 6))
    fig.suptitle(col, fontsize=16)
    plt.subplot(1,3,1)
    if max_hist == None:
        sns.distplot(df[col], kde=False, bins = 50)
    else :
        sns.distplot(df[df[col]<=max_hist][col], kde=False, bins = 50)
    plt.subplot(1,3,2)
    sns.boxplot(df[col])
    plt.subplot(1,3,3)
    z_score_inspect = outlier_zscore(df, col, min_z=min_z, max_z = max_z, step = step)
    plt.show()

# %%
# Fills missing values with combination of columns, Follows priority 
#firstly tries 3 column combination and fills nulls and applies remaining nulls with 2 colum combination and so on.
def fill_most_with1_temp(df,target_col,ref_col1):
    df_temp = df[[ref_col1,target_col]]
    for group1 in list(df_temp[ref_col1].unique()):
        grp_inx = list(df_temp[(df_temp[ref_col1]==group1)][target_col].index)
        try:
            fill_value = df_temp[(df_temp[ref_col1] == group1)][target_col].mode()[0]
        except:
            fill_value = 'NaN'
            continue
        df_temp[target_col].iloc[grp_inx] = df_temp[target_col].iloc[grp_inx].fillna(fill_value)
    return df_temp
def fill_most_with1_perm(df,target_col,ref_col1):
    for group1 in list(df[ref_col1].unique()):
        grp_inx = list(df[(df[ref_col1]==group1)][target_col].index)
        try:
            fill_value = df[(df[ref_col1] == group1)][target_col].mode()[0]
        except:
            fill_value = 'NaN'
            continue
        df[target_col].iloc[grp_inx] = df[target_col].iloc[grp_inx].fillna(fill_value)
    return df
def fill_most_with2_temp(df,target_col,col1, col2):
    df_temp = df[[col1,col2,target_col]]
    for group1 in list(df_temp[col1].unique()):
        for group2 in list(df_temp[df_temp[col1]==group1][col2].unique()):
            grp_inx = list(df_temp[(df_temp[col1]==group1) & (df_temp[col2] == group2)][target_col].index)
            try:
                fill_value = df_temp[(df_temp[col1] == group1) & (df_temp[col2] == group2)][target_col].mode()[0]
            except:
                fill_value = 'NaN'
                continue
            df_temp[target_col].iloc[grp_inx] = df_temp[target_col].iloc[grp_inx].fillna(fill_value)  
    return df_temp
def fill_most_with2_perm(df,target_col, col1, col2):
    for group1 in list(df[col1].unique()):
        for group2 in list(df[df[col1]==group1][col2].unique()):
            grp_inx = list(df[(df[col1]==group1) & (df[col2] == group2)][target_col].index)
            try:
                fill_value = df[(df[col1] == group1) & (df[col2] == group2)][target_col].mode()[0]
            except:
                fill_value = 'NaN'
                continue
            df[target_col].iloc[grp_inx] = df[target_col].iloc[grp_inx].fillna(fill_value)  
    return df
#df[(df["Make"] == "Audi") & (df["Model2"] == "A3")  & (df["Displacement (cc)"] == 1.5)]["body_type"].mode()[0]
def fill_most_with3_temp(df,target_col,col1, col2, col3):
    df_temp = df[[col1,col2,col3,target_col]]
    for group1 in list(df_temp[col1].unique()):
        for group2 in list(df_temp[df_temp[col1]==group1][col2].unique()):
            for group3 in list(df_temp[(df_temp[col1]==group1) & (df_temp[col2]==group2)][col3].unique()):
                grp_inx = list(df_temp[(df_temp[col1]==group1) & (df_temp[col2] == group2)& (df_temp[col3]==group3)][target_col].index)
                try:
                    fill_value = df_temp[(df_temp[col1] == group1) & (df_temp[col2] == group2) & (df_temp[col3] == group3)][target_col].mode()[0]
                except:
                    fill_value = 'NaN'
                    continue
                df_temp[target_col].iloc[grp_inx] = df_temp[target_col].iloc[grp_inx].fillna(fill_value)  
    return df_temp



def fill_most_with3_perm(df,target_col,col1, col2, col3):
    for group1 in list(df[col1].unique()):
        for group2 in list(df[df[col1]==group1][col2].unique()):
            for group3 in list(df[(df[col1]==group1) & (df[col2] == group2)][col3].unique()):
                grp_inx = list(df[(df[col1]==group1) & (df[col2] == group2)& (df[col3]==group3)][target_col].index)
                try:
                    fill_value = df[(df[col1] == group1) & (df[col2] == group2) & (df[col3] == group3)][target_col].mode()[0]
                except:
                    fill_value = 'NaN'
                    continue
                df[target_col].iloc[grp_inx] = df[target_col].iloc[grp_inx].fillna(fill_value)  
    return df

def fill_priority_perm(df,target_col,col1, col2, col3):
    fill_most_with3_perm(df,target_col,col1, col2, col3)
    fill_most_with2_perm(df,target_col,col1, col2)
    fill_most_with1_perm(df,target_col,col1)
    return df

# %% [markdown]
# # Entrance

# %%
# read json file with lines method.
df = pd.read_json("scout_car.json", lines=True)

# %%
#lets see all column and value_counts
#get_all_df(df)

# %%
#fix column name by deleting "\n" in it.
df.rename(columns=lambda x: x.replace("\n",""),inplace=True)

# %%
pd.options.display.max_columns = 600
pd.options.display.max_rows = 6
df.head(2)
# Out:
#                                                  url make_model  \
# 0  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 1  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
#
#                              short_description body_type  price  \
# 0  Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                               1.8 TFSI sport    Sedans  14500
#
#                 vat         km registration         prev_owner  kW      hp  \
# 0    VAT deductible  56,013 km      01/2016  2 previous owners NaN   66 kW
# 1  Price negotiable  80,000 km      03/2017               None NaN  141 kW
#
#                                       Type Previous Owners  \
# 0  [, Used, , Diesel (Particulate Filter)]           \n2\n
# 1                     [, Used, , Gasoline]             NaN
#
#                          Next Inspection         Inspection new  \
# 0  [\n06/2021\n, \n99 g CO2/km (comb)\n]  [\nYes\n, \nEuro 6\n]
# 1                                    NaN                    NaN
#
#                   Warranty Full Service Non-smoking Vehicle null      Make  \
# 0  [\n, \n, \n4 (Green)\n]     [\n, \n]            [\n, \n]   []  \nAudi\n
# 1                      NaN          NaN                 NaN   []  \nAudi\n
#
#           Model     Offer Number First Registration       Body Color  \
# 0  [\n, A1, \n]  [\nLR-062483\n]     [\n, 2016, \n]  [\n, Black, \n]
# 1  [\n, A1, \n]              NaN     [\n, 2017, \n]    [\n, Red, \n]
#
#        Paint Type  Body Color Original          Upholstery              Body  \
# 0  [\nMetallic\n]  [\nMythosschwarz\n]  [\nCloth, Black\n]  [\n, Sedans, \n]
# 1             NaN                  NaN   [\nCloth, Grey\n]  [\n, Sedans, \n]
#
#   Nr. of Doors Nr. of Seats      Model Code         Gearing Type  \
# 0      [\n5\n]      [\n5\n]  [\n0588/BDF\n]  [\n, Automatic, \n]
# 1      [\n3\n]      [\n4\n]  [\n0588/BCY\n]  [\n, Automatic, \n]
#
#      Displacement Cylinders          Weight  Drive chain  \
# 0  [\n1,422 cc\n]   [\n3\n]  [\n1,220 kg\n]  [\nfront\n]
# 1  [\n1,798 cc\n]   [\n4\n]  [\n1,255 kg\n]  [\nfront\n]
#
#                                     Fuel  \
# 0  [\n, Diesel (Particulate Filter), \n]
# 1                     [\n, Gasoline, \n]
#
#                                          Consumption  \
# 0  [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1  [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
#
#                 CO2 Emission Emission Class  \
# 0   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]
# 1  [\n129 g CO2/km (comb)\n]   [\nEuro 6\n]
#
#                                Comfort & Convenience  \
# 0  [Air conditioning, Armrest, Automatic climate ...
# 1  [Air conditioning, Automatic climate control, ...
#
#                                Entertainment & Media  \
# 0  [Bluetooth, Hands-free equipment, On-board com...
# 1  [Bluetooth, Hands-free equipment, On-board com...
#
#                                               Extras  \
# 0  [Alloy wheels, Catalytic Converter, Voice Cont...
# 1  [Alloy wheels, Sport seats, Sport suspension, ...
#
#                                    Safety & Security  \
# 0  [ABS, Central door lock, Daytime running light...
# 1  [ABS, Central door lock, Central door lock wit...
#
#                                          description   Emission Label  \
# 0  [\n, Sicherheit:,  , Deaktivierung für Beifahr...              NaN
# 1  [\nLangstreckenfahrzeug daher die hohe Kilomet...  [\n4 (Green)\n]
#
#      Gears Country version Electricity consumption Last Service Date  \
# 0      NaN             NaN                     NaN               NaN
# 1  [\n7\n]             NaN                     NaN               NaN
#
#   Other Fuel Types Availability Last Timing Belt Service Date Available from
# 0              NaN          NaN                           NaN            NaN
# 1              NaN          NaN                           NaN            NaN

# %%
#drop unnecessary columns #subjectif decision

#no need = 'url', 'description','Offer Number'
#same info already exist = "Make","Model","Body2", "prev_owner" ("make_model" we will use this)
unnecassary_columns = ['url', 'description', 'Offer Number',"prev_owner","Model Code","Weight","Make","Model"]
for i in unnecassary_columns:
    try:
        df.drop(i,axis=1,inplace=True)
    except:
        pass

# %%
df.head(2)
# Out:
#                              short_description body_type  price  \
# 0  Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                               1.8 TFSI sport    Sedans  14500
#
#                 vat         km registration  kW      hp  \
# 0    VAT deductible  56,013 km      01/2016 NaN   66 kW
# 1  Price negotiable  80,000 km      03/2017 NaN  141 kW
#
#                                       Type Previous Owners  \
# 0  [, Used, , Diesel (Particulate Filter)]           \n2\n
# 1                     [, Used, , Gasoline]             NaN
#
#                          Next Inspection         Inspection new  \
# 0  [\n06/2021\n, \n99 g CO2/km (comb)\n]  [\nYes\n, \nEuro 6\n]
# 1                                    NaN                    NaN
#
#                   Warranty Full Service Non-smoking Vehicle null      Make  \
# 0  [\n, \n, \n4 (Green)\n]     [\n, \n]            [\n, \n]   []  \nAudi\n
# 1                      NaN          NaN                 NaN   []  \nAudi\n
#
#           Model First Registration       Body Color      Paint Type  \
# 0  [\n, A1, \n]     [\n, 2016, \n]  [\n, Black, \n]  [\nMetallic\n]
# 1  [\n, A1, \n]     [\n, 2017, \n]    [\n, Red, \n]             NaN
#
#    Body Color Original          Upholstery              Body Nr. of Doors  \
# 0  [\nMythosschwarz\n]  [\nCloth, Black\n]  [\n, Sedans, \n]      [\n5\n]
# 1                  NaN   [\nCloth, Grey\n]  [\n, Sedans, \n]      [\n3\n]
#
#   Nr. of Seats         Gearing Type    Displacement Cylinders  Drive chain  \
# 0      [\n5\n]  [\n, Automatic, \n]  [\n1,422 cc\n]   [\n3\n]  [\nfront\n]
# 1      [\n4\n]  [\n, Automatic, \n]  [\n1,798 cc\n]   [\n4\n]  [\nfront\n]
#
#                                     Fuel  \
# 0  [\n, Diesel (Particulate Filter), \n]
# 1                     [\n, Gasoline, \n]
#
#                                          Consumption  \
# 0  [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1  [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
#
#                 CO2 Emission Emission Class  \
# 0   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]
# 1  [\n129 g CO2/km (comb)\n]   [\nEuro 6\n]
#
#                                Comfort & Convenience  \
# 0  [Air conditioning, Armrest, Automatic climate ...
# 1  [Air conditioning, Automatic climate control, ...
#
#                                Entertainment & Media  \
# 0  [Bluetooth, Hands-free equipment, On-board com...
# 1  [Bluetooth, Hands-free equipment, On-board com...
#
#                                               Extras  \
# 0  [Alloy wheels, Catalytic Converter, Voice Cont...
# 1  [Alloy wheels, Sport seats, Sport suspension, ...
#
#                                    Safety & Security   Emission Label  \
# 0  [ABS, Central door lock, Daytime running light...              NaN
# 1  [ABS, Central door lock, Central door lock wit...  [\n4 (Green)\n]
#
#      Gears Country version Electricity consumption Last Service Date  \
# 0      NaN             NaN                     NaN               NaN
# 1  [\n7\n]             NaN                     NaN               NaN
#
#   Other Fuel Types Availability Last Timing Belt Service Date Available from
# 0              NaN          NaN                           NaN            NaN
# 1              NaN          NaN                           NaN            NaN

# %% [markdown]
# # Convert lists to columns and common clean up for [ ],"" etc

# %%
#below columns are presents car features which affect the car price, we get Yes or No for the specific car Feature.
car_acc_list = ['Comfort & Convenience',"Safety & Security","Extras","Entertainment & Media"]
df = list_to_feat_cols(df,car_acc_list)

# %%
df.head(2)
# Out:
#                              short_description body_type  price  \
# 0  Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                               1.8 TFSI sport    Sedans  14500
#
#                 vat         km registration  kW      hp  \
# 0    VAT deductible  56,013 km      01/2016 NaN   66 kW
# 1  Price negotiable  80,000 km      03/2017 NaN  141 kW
#
#                                       Type Previous Owners  \
# 0  [, Used, , Diesel (Particulate Filter)]           \n2\n
# 1                     [, Used, , Gasoline]             NaN
#
#                          Next Inspection         Inspection new  \
# 0  [\n06/2021\n, \n99 g CO2/km (comb)\n]  [\nYes\n, \nEuro 6\n]
# 1                                    NaN                    NaN
#
#                   Warranty Full Service Non-smoking Vehicle null      Make  \
# 0  [\n, \n, \n4 (Green)\n]     [\n, \n]            [\n, \n]   []  \nAudi\n
# 1                      NaN          NaN                 NaN   []  \nAudi\n
#
#           Model First Registration       Body Color      Paint Type  \
# 0  [\n, A1, \n]     [\n, 2016, \n]  [\n, Black, \n]  [\nMetallic\n]
# 1  [\n, A1, \n]     [\n, 2017, \n]    [\n, Red, \n]             NaN
#
#    Body Color Original          Upholstery              Body Nr. of Doors  \
# 0  [\nMythosschwarz\n]  [\nCloth, Black\n]  [\n, Sedans, \n]      [\n5\n]
# 1                  NaN   [\nCloth, Grey\n]  [\n, Sedans, \n]      [\n3\n]
#
#   Nr. of Seats         Gearing Type    Displacement Cylinders  Drive chain  \
# 0      [\n5\n]  [\n, Automatic, \n]  [\n1,422 cc\n]   [\n3\n]  [\nfront\n]
# 1      [\n4\n]  [\n, Automatic, \n]  [\n1,798 cc\n]   [\n4\n]  [\nfront\n]
#
#                                     Fuel  \
# 0  [\n, Diesel (Particulate Filter), \n]
# 1                     [\n, Gasoline, \n]
#
#                                          Consumption  \
# 0  [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1  [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
#
#                 CO2 Emission Emission Class   Emission Label    Gears  \
# 0   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]              NaN      NaN
# 1  [\n129 g CO2/km (comb)\n]   [\nEuro 6\n]  [\n4 (Green)\n]  [\n7\n]
#
#   Country version Electricity consumption Last Service Date Other Fuel Types  \
# 0             NaN                     NaN               NaN              NaN
# 1             NaN                     NaN               NaN              NaN
#
#   Availability Last Timing Belt Service Date Available from  \
# 0          NaN                           NaN            NaN
# 1          NaN                           NaN            NaN
#
#   Comfort & Convenience 1 Air conditioning  \
# 0                                     True
# 1                                     True
#
#   Comfort & Convenience 2 Air suspension Comfort & Convenience 3 Armrest  \
# 0                                  False                            True
# 1                                  False                           False
#
#   Comfort & Convenience 4 Automatic climate control  \
# 0                                              True
# 1                                              True
#
#   Comfort & Convenience 5 Auxiliary heating  \
# 0                                     False
# 1                                     False
#
#   Comfort & Convenience 6 Cruise control  \
# 0                                   True
# 1                                  False
#
#   Comfort & Convenience 7 Electric Starter  \
# 0                                    False
# 1                                    False
#
#   Comfort & Convenience 8 Electric tailgate  \
# 0                                     False
# 1                                     False
#
#   Comfort & Convenience 9 Electrical side mirrors  \
# 0                                            True
# 1                                           False
#
#   Comfort & Convenience 10 Electrically adjustable seats  \
# 0                                              False
# 1                                              False
#
#   Comfort & Convenience 11 Electrically heated windshield  \
# 0                                              False
# 1                                              False
#
#   Comfort & Convenience 12 Heads-up display  \
# 0                                     False
# 1                                     False
#
#   Comfort & Convenience 13 Heated steering wheel  \
# 0                                          False
# 1                                          False
#
#   Comfort & Convenience 14 Hill Holder  \
# 0                                 True
# 1                                 True
#
#   Comfort & Convenience 15 Keyless central door lock  \
# 0                                              False
# 1                                              False
#
#   Comfort & Convenience 16 Leather seats  \
# 0                                  False
# 1                                  False
#
#   Comfort & Convenience 17 Leather steering wheel  \
# 0                                            True
# 1                                            True
#
#   Comfort & Convenience 18 Light sensor  \
# 0                                  True
# 1                                 False
#
#   Comfort & Convenience 19 Lumbar support  \
# 0                                   False
# 1                                    True
#
#   Comfort & Convenience 20 Massage seats  \
# 0                                  False
# 1                                  False
#
#   Comfort & Convenience 21 Multi-function steering wheel  \
# 0                                               True
# 1                                              False
#
#   Comfort & Convenience 22 Navigation system  \
# 0                                       True
# 1                                      False
#
#   Comfort & Convenience 23 Panorama roof  \
# 0                                  False
# 1                                  False
#
#   Comfort & Convenience 24 Park Distance Control  \
# 0                                           True
# 1                                          False
#
#   Comfort & Convenience 25 Parking assist system camera  \
# 0                                              False
# 1                                              False
#
#   Comfort & Convenience 26 Parking assist system self-steering  \
# 0                                              False
# 1                                              False
#
#   Comfort & Convenience 27 Parking assist system sensors front  \
# 0                                              False
# 1                                              False
#
#   Comfort & Convenience 28 Parking assist system sensors rear  \
# 0                                               True
# 1                                               True
#
#   Comfort & Convenience 29 Power windows Comfort & Convenience 30 Rain sensor  \
# 0                                   True                                 True
# 1                                   True                                False
#
#   Comfort & Convenience 31 Seat heating  \
# 0                                  True
# 1                                 False
#
#   Comfort & Convenience 32 Seat ventilation  \
# 0                                     False
# 1                                     False
#
#   Comfort & Convenience 33 Split rear seats  \
# 0                                     False
# 1                                     False
#
#   Comfort & Convenience 34 Start-stop system Comfort & Convenience 35 Sunroof  \
# 0                                       True                            False
# 1                                       True                            False
#
#   Comfort & Convenience 36 Tinted windows  \
# 0                                   False
# 1                                    True
#
#   Comfort & Convenience 37 Wind deflector Comfort & Convenience 38 Windshield  \
# 0                                   False                               False
# 1                                   False                               False
#
#   Safety & Security 1 ABS Safety & Security 2 Adaptive Cruise Control  \
# 0                    True                                       False
# 1                    True                                       False
#
#   Safety & Security 3 Adaptive headlights Safety & Security 4 Alarm system  \
# 0                                   False                            False
# 1                                   False                            False
#
#   Safety & Security 5 Blind spot monitor  \
# 0                                  False
# 1                                  False
#
#   Safety & Security 6 Central door lock  \
# 0                                  True
# 1                                  True
#
#   Safety & Security 7 Central door lock with remote control  \
# 0                                              False
# 1                                               True
#
#   Safety & Security 8 Daytime running lights  \
# 0                                       True
# 1                                       True
#
#   Safety & Security 9 Driver drowsiness detection  \
# 0                                           False
# 1                                           False
#
#   Safety & Security 10 Driver-side airbag  \
# 0                                    True
# 1                                    True
#
#   Safety & Security 11 Electronic stability control  \
# 0                                              True
# 1                                              True
#
#   Safety & Security 12 Emergency brake assistant  \
# 0                                          False
# 1                                          False
#
#   Safety & Security 13 Emergency system Safety & Security 14 Fog lights  \
# 0                                 False                            True
# 1                                 False                           False
#
#   Safety & Security 15 Head airbag Safety & Security 16 Immobilizer  \
# 0                            False                             True
# 1                             True                             True
#
#   Safety & Security 17 Isofix Safety & Security 18 LED Daytime Running Lights  \
# 0                        True                                           False
# 1                        True                                           False
#
#   Safety & Security 19 LED Headlights  \
# 0                               False
# 1                               False
#
#   Safety & Security 20 Lane departure warning system  \
# 0                                              False
# 1                                              False
#
#   Safety & Security 21 Night view assist  \
# 0                                  False
# 1                                  False
#
#   Safety & Security 22 Passenger-side airbag  \
# 0                                       True
# 1                                       True
#
#   Safety & Security 23 Power steering Safety & Security 24 Rear airbag  \
# 0                                True                            False
# 1                                True                            False
#
#   Safety & Security 25 Side airbag  \
# 0                             True
# 1                             True
#
#   Safety & Security 26 Tire pressure monitoring system  \
# 0                                               True
# 1                                               True
#
#   Safety & Security 27 Traction control  \
# 0                                  True
# 1                                  True
#
#   Safety & Security 28 Traffic sign recognition  \
# 0                                         False
# 1                                         False
#
#   Safety & Security 29 Xenon headlights Extras 1 Alloy wheels  \
# 0                                  True                  True
# 1                                  True                  True
#
#   Extras 2 Cab or rented Car Extras 3 Catalytic Converter  \
# 0                      False                         True
# 1                      False                        False
#
#   Extras 4 Handicapped enabled Extras 5 Right hand drive Extras 6 Roof rack  \
# 0                        False                     False              False
# 1                        False                     False              False
#
#   Extras 7 Shift paddles Extras 8 Ski bag Extras 9 Sliding door  \
# 0                  False            False                 False
# 1                  False            False                 False
#
#   Extras 10 Sport package Extras 11 Sport seats Extras 12 Sport suspension  \
# 0                   False                 False                      False
# 1                   False                  True                       True
#
#   Extras 13 Touch screen Extras 14 Trailer hitch Extras 15 Tuned car  \
# 0                  False                   False               False
# 1                  False                   False               False
#
#   Extras 16 Voice Control Extras 17 Winter tyres  \
# 0                    True                  False
# 1                    True                  False
#
#   Entertainment & Media 1 Bluetooth Entertainment & Media 2 CD player  \
# 0                              True                             False
# 1                              True                             False
#
#   Entertainment & Media 3 Digital radio  \
# 0                                 False
# 1                                 False
#
#   Entertainment & Media 4 Hands-free equipment Entertainment & Media 5 MP3  \
# 0                                         True                       False
# 1                                         True                       False
#
#   Entertainment & Media 6 On-board computer Entertainment & Media 7 Radio  \
# 0                                      True                          True
# 1                                      True                          True
#
#   Entertainment & Media 8 Sound system Entertainment & Media 9 Television  \
# 0                                False                              False
# 1                                 True                              False
#
#   Entertainment & Media 10 USB
# 0                        False
# 1                        False

# %%
#here we figure out which column has values as a list and which not.
list_columns, nonlist_columns = check_is_list(df)

# %%
# now we will convert lists to columns, after removing "description" since its just a comment for car and does not affect the price.
for i in list_columns:
    df = list_to_columns(df,i)

# %%
#replace all "", [], \n, values to np.Nan or delete if possible in df
for i in df.columns:
    df[i] = df[i].replace("",np.NaN)
    df[i] = df[i].apply(lambda x: np.nan if (type(x) == list and len(x) == 0) else x) # convert [] to np.NAN
    try:
        df[i] = df[i].apply(lambda x: list(map(lambda x: x.strip(), x)) if type(x)==list else x)
    except:
        continue
    df[i] = df[i].apply(lambda x : np.NaN if x=='\n' else x)
    df[i] = df[i].apply(lambda x: (("".join(x.replace("\n",""))) if (type(x)==str and type(x) != float) else x) if x!=np.nan else x)

#repeat same steps 2nd time for check if there list in list at df if yes apply methods.
list_columns, nonlist_columns = check_is_list(df)
for i in list_columns:
    df = list_to_columns(df,i)

#replace all "", [], \n, values to np.Nan or delete if possible in df
for i in df.columns:
    df[i] = df[i].replace("",np.NaN)
    df[i] = df[i].apply(lambda x: np.nan if (type(x) == list and len(x) == 0) else x) # convert [] to np.NAN
    try:
        df[i] = df[i].apply(lambda x: list(map(lambda x: x.strip(), x)) if type(x)==list else x)
    except:
        continue
    df[i] = df[i].apply(lambda x : np.NaN if x=='\n' else x)
    df[i] = df[i].apply(lambda x: (("".join(x.replace("\n",""))) if (type(x)==str and type(x) != float) else x) if x!=np.nan else x)

# %%
#get_all_df(df)

# %%
pd.options.display.max_columns = 600
pd.options.display.max_rows = 6
df.head()
# Out:
#                                    short_description body_type  price  \
# 0        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                     1.8 TFSI sport    Sedans  14500
# 2  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
# 3                            1.4 TDi Design S tronic    Sedans  14500
# 4  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans  16790
#
#                 vat         km registration  kW      hp  Make Availability  \
# 0    VAT deductible  56,013 km      01/2016 NaN   66 kW  Audi          NaN
# 1  Price negotiable  80,000 km      03/2017 NaN  141 kW  Audi          NaN
# 2    VAT deductible  83,450 km      02/2016 NaN   85 kW  Audi          NaN
# 3              None  73,000 km      08/2016 NaN   66 kW  Audi          NaN
# 4              None  16,200 km      05/2016 NaN   66 kW  Audi          NaN
#
#   Available from Comfort & Convenience 1 Air conditioning  \
# 0            NaN                                     True
# 1            NaN                                     True
# 2            NaN                                     True
# 3            NaN                                    False
# 4            NaN                                     True
#
#   Comfort & Convenience 2 Air suspension Comfort & Convenience 3 Armrest  \
# 0                                  False                            True
# 1                                  False                           False
# 2                                  False                           False
# 3                                   True                            True
# 4                                  False                            True
#
#   Comfort & Convenience 4 Automatic climate control  \
# 0                                              True
# 1                                              True
# 2                                             False
# 3                                             False
# 4                                              True
#
#   Comfort & Convenience 5 Auxiliary heating  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                      True
# 4                                     False
#
#   Comfort & Convenience 6 Cruise control  \
# 0                                   True
# 1                                  False
# 2                                   True
# 3                                  False
# 4                                  False
#
#   Comfort & Convenience 7 Electric Starter  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#   Comfort & Convenience 8 Electric tailgate  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#   Comfort & Convenience 9 Electrical side mirrors  \
# 0                                            True
# 1                                           False
# 2                                            True
# 3                                            True
# 4                                            True
#
#   Comfort & Convenience 10 Electrically adjustable seats  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 11 Electrically heated windshield  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 12 Heads-up display  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                      True
# 4                                     False
#
#   Comfort & Convenience 13 Heated steering wheel  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#   Comfort & Convenience 14 Hill Holder  \
# 0                                 True
# 1                                 True
# 2                                 True
# 3                                 True
# 4                                 True
#
#   Comfort & Convenience 15 Keyless central door lock  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 16 Leather seats  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Comfort & Convenience 17 Leather steering wheel  \
# 0                                            True
# 1                                            True
# 2                                            True
# 3                                            True
# 4                                            True
#
#   Comfort & Convenience 18 Light sensor  \
# 0                                  True
# 1                                 False
# 2                                 False
# 3                                  True
# 4                                  True
#
#   Comfort & Convenience 19 Lumbar support  \
# 0                                   False
# 1                                    True
# 2                                   False
# 3                                    True
# 4                                   False
#
#   Comfort & Convenience 20 Massage seats  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Comfort & Convenience 21 Multi-function steering wheel  \
# 0                                               True
# 1                                              False
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Comfort & Convenience 22 Navigation system  \
# 0                                       True
# 1                                      False
# 2                                       True
# 3                                       True
# 4                                      False
#
#   Comfort & Convenience 23 Panorama roof  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Comfort & Convenience 24 Park Distance Control  \
# 0                                           True
# 1                                          False
# 2                                           True
# 3                                          False
# 4                                           True
#
#   Comfort & Convenience 25 Parking assist system camera  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 26 Parking assist system self-steering  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 27 Parking assist system sensors front  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 28 Parking assist system sensors rear  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                              False
# 4                                               True
#
#   Comfort & Convenience 29 Power windows Comfort & Convenience 30 Rain sensor  \
# 0                                   True                                 True
# 1                                   True                                False
# 2                                   True                                False
# 3                                   True                                 True
# 4                                   True                                 True
#
#   Comfort & Convenience 31 Seat heating  \
# 0                                  True
# 1                                 False
# 2                                  True
# 3                                  True
# 4                                 False
#
#   Comfort & Convenience 32 Seat ventilation  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#   Comfort & Convenience 33 Split rear seats  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                      True
# 4                                     False
#
#   Comfort & Convenience 34 Start-stop system Comfort & Convenience 35 Sunroof  \
# 0                                       True                            False
# 1                                       True                            False
# 2                                       True                            False
# 3                                       True                            False
# 4                                       True                            False
#
#   Comfort & Convenience 36 Tinted windows  \
# 0                                   False
# 1                                    True
# 2                                   False
# 3                                   False
# 4                                   False
#
#   Comfort & Convenience 37 Wind deflector Comfort & Convenience 38 Windshield  \
# 0                                   False                               False
# 1                                   False                               False
# 2                                   False                               False
# 3                                   False                               False
# 4                                   False                               False
#
#   Safety & Security 1 ABS Safety & Security 2 Adaptive Cruise Control  \
# 0                    True                                       False
# 1                    True                                       False
# 2                    True                                       False
# 3                    True                                       False
# 4                    True                                       False
#
#   Safety & Security 3 Adaptive headlights Safety & Security 4 Alarm system  \
# 0                                   False                            False
# 1                                   False                            False
# 2                                   False                            False
# 3                                   False                             True
# 4                                   False                            False
#
#   Safety & Security 5 Blind spot monitor  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Safety & Security 6 Central door lock  \
# 0                                  True
# 1                                  True
# 2                                  True
# 3                                 False
# 4                                  True
#
#   Safety & Security 7 Central door lock with remote control  \
# 0                                              False
# 1                                               True
# 2                                              False
# 3                                               True
# 4                                              False
#
#   Safety & Security 8 Daytime running lights  \
# 0                                       True
# 1                                       True
# 2                                       True
# 3                                      False
# 4                                      False
#
#   Safety & Security 9 Driver drowsiness detection  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                            True
# 4                                           False
#
#   Safety & Security 10 Driver-side airbag  \
# 0                                    True
# 1                                    True
# 2                                    True
# 3                                    True
# 4                                    True
#
#   Safety & Security 11 Electronic stability control  \
# 0                                              True
# 1                                              True
# 2                                              True
# 3                                              True
# 4                                              True
#
#   Safety & Security 12 Emergency brake assistant  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#   Safety & Security 13 Emergency system Safety & Security 14 Fog lights  \
# 0                                 False                            True
# 1                                 False                           False
# 2                                 False                           False
# 3                                  True                           False
# 4                                 False                            True
#
#   Safety & Security 15 Head airbag Safety & Security 16 Immobilizer  \
# 0                            False                             True
# 1                             True                             True
# 2                            False                             True
# 3                             True                             True
# 4                            False                             True
#
#   Safety & Security 17 Isofix Safety & Security 18 LED Daytime Running Lights  \
# 0                        True                                           False
# 1                        True                                           False
# 2                        True                                           False
# 3                        True                                           False
# 4                        True                                           False
#
#   Safety & Security 19 LED Headlights  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
#
#   Safety & Security 20 Lane departure warning system  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Safety & Security 21 Night view assist  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Safety & Security 22 Passenger-side airbag  \
# 0                                       True
# 1                                       True
# 2                                       True
# 3                                       True
# 4                                       True
#
#   Safety & Security 23 Power steering Safety & Security 24 Rear airbag  \
# 0                                True                            False
# 1                                True                            False
# 2                                True                            False
# 3                                True                            False
# 4                                True                            False
#
#   Safety & Security 25 Side airbag  \
# 0                             True
# 1                             True
# 2                             True
# 3                             True
# 4                             True
#
#   Safety & Security 26 Tire pressure monitoring system  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Safety & Security 27 Traction control  \
# 0                                  True
# 1                                  True
# 2                                  True
# 3                                 False
# 4                                  True
#
#   Safety & Security 28 Traffic sign recognition  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#   Safety & Security 29 Xenon headlights Extras 1 Alloy wheels  \
# 0                                  True                  True
# 1                                  True                  True
# 2                                 False                  True
# 3                                 False                  True
# 4                                  True                  True
#
#   Extras 2 Cab or rented Car Extras 3 Catalytic Converter  \
# 0                      False                         True
# 1                      False                        False
# 2                      False                        False
# 3                      False                        False
# 4                      False                        False
#
#   Extras 4 Handicapped enabled Extras 5 Right hand drive Extras 6 Roof rack  \
# 0                        False                     False              False
# 1                        False                     False              False
# 2                        False                     False              False
# 3                        False                     False              False
# 4                        False                     False              False
#
#   Extras 7 Shift paddles Extras 8 Ski bag Extras 9 Sliding door  \
# 0                  False            False                 False
# 1                  False            False                 False
# 2                  False            False                 False
# 3                  False            False                 False
# 4                  False            False                 False
#
#   Extras 10 Sport package Extras 11 Sport seats Extras 12 Sport suspension  \
# 0                   False                 False                      False
# 1                   False                  True                       True
# 2                   False                 False                      False
# 3                   False                  True                      False
# 4                    True                 False                       True
#
#   Extras 13 Touch screen Extras 14 Trailer hitch Extras 15 Tuned car  \
# 0                  False                   False               False
# 1                  False                   False               False
# 2                  False                   False               False
# 3                  False                   False               False
# 4                  False                   False               False
#
#   Extras 16 Voice Control Extras 17 Winter tyres  \
# 0                    True                  False
# 1                    True                  False
# 2                    True                  False
# 3                    True                  False
# 4                    True                  False
#
#   Entertainment & Media 1 Bluetooth Entertainment & Media 2 CD player  \
# 0                              True                             False
# 1                              True                             False
# 2                             False                             False
# 3                              True                              True
# 4                              True                              True
#
#   Entertainment & Media 3 Digital radio  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#   Entertainment & Media 4 Hands-free equipment Entertainment & Media 5 MP3  \
# 0                                         True                       False
# 1                                         True                       False
# 2                                        False                        True
# 3                                         True                        True
# 4                                         True                        True
#
#   Entertainment & Media 6 On-board computer Entertainment & Media 7 Radio  \
# 0                                      True                          True
# 1                                      True                          True
# 2                                      True                         False
# 3                                      True                          True
# 4                                      True                          True
#
#   Entertainment & Media 8 Sound system Entertainment & Media 9 Television  \
# 0                                False                              False
# 1                                 True                              False
# 2                                False                              False
# 3                                 True                              False
# 4                                False                              False
#
#   Entertainment & Media 10 USB  Type1 Type2  Type3  \
# 0                        False    NaN  Used    NaN
# 1                        False    NaN  Used    NaN
# 2                        False    NaN  Used    NaN
# 3                         True    NaN  Used    NaN
# 4                         True    NaN  Used    NaN
#
#                          Type4 Previous Owners1 Previous Owners2  \
# 0  Diesel (Particulate Filter)                2              NaN
# 1                     Gasoline              NaN              NaN
# 2  Diesel (Particulate Filter)                1              NaN
# 3  Diesel (Particulate Filter)                1              NaN
# 4  Diesel (Particulate Filter)                1              NaN
#
#   Previous Owners3  Previous Owners4 Previous Owners5  Previous Owners6  \
# 0              NaN               NaN              NaN               NaN
# 1              NaN               NaN              NaN               NaN
# 2              NaN               NaN              NaN               NaN
# 3              NaN               NaN              NaN               NaN
# 4              NaN               NaN              NaN               NaN
#
#   Previous Owners7  Previous Owners8 Next Inspection1    Next Inspection2  \
# 0              NaN               NaN          06/2021  99 g CO2/km (comb)
# 1              NaN               NaN              NaN                 NaN
# 2              NaN               NaN              NaN                 NaN
# 3              NaN               NaN              NaN                 NaN
# 4              NaN               NaN              NaN                 NaN
#
#   Next Inspection3  Next Inspection4 Next Inspection5  Next Inspection6  \
# 0              NaN               NaN              NaN               NaN
# 1              NaN               NaN              NaN               NaN
# 2              NaN               NaN              NaN               NaN
# 3              NaN               NaN              NaN               NaN
# 4              NaN               NaN              NaN               NaN
#
#   Next Inspection7  Next Inspection8 Inspection new1      Inspection new2  \
# 0              NaN               NaN             Yes               Euro 6
# 1              NaN               NaN             NaN                  NaN
# 2              NaN               NaN             NaN                  NaN
# 3              NaN               NaN             NaN                  NaN
# 4              NaN               NaN             Yes  109 g CO2/km (comb)
#
#   Inspection new3  Inspection new4 Inspection new5  Inspection new6  \
# 0             NaN              NaN             NaN              NaN
# 1             NaN              NaN             NaN              NaN
# 2             NaN              NaN             NaN              NaN
# 3             NaN              NaN             NaN              NaN
# 4             NaN              NaN             NaN              NaN
#
#   Inspection new7  Inspection new8 Warranty1 Warranty2           Warranty3  \
# 0             NaN              NaN       NaN       NaN           4 (Green)
# 1             NaN              NaN       NaN       NaN                 NaN
# 2             NaN              NaN       NaN       NaN  99 g CO2/km (comb)
# 3             NaN              NaN       NaN       NaN                 NaN
# 4             NaN              NaN       NaN       NaN              Euro 6
#
#   Warranty4 Warranty5 Warranty6 Warranty7 Warranty8  Warranty9  Full Service1  \
# 0       NaN       NaN       NaN       NaN       NaN        NaN            NaN
# 1       NaN       NaN       NaN       NaN       NaN        NaN            NaN
# 2       NaN       NaN       NaN       NaN       NaN        NaN            NaN
# 3       NaN       NaN       NaN       NaN       NaN        NaN            NaN
# 4       NaN       NaN       NaN       NaN       NaN        NaN            NaN
#
#    Full Service2       Full Service3 Full Service4  Full Service5  \
# 0            NaN                 NaN           NaN            NaN
# 1            NaN                 NaN           NaN            NaN
# 2            NaN                 NaN           NaN            NaN
# 3            NaN  99 g CO2/km (comb)           NaN            NaN
# 4            NaN           4 (Green)           NaN            NaN
#
#   Full Service6  Full Service7 Full Service8  Full Service9  \
# 0           NaN            NaN           NaN            NaN
# 1           NaN            NaN           NaN            NaN
# 2           NaN            NaN           NaN            NaN
# 3           NaN            NaN           NaN            NaN
# 4           NaN            NaN           NaN            NaN
#
#    Non-smoking Vehicle1  Non-smoking Vehicle2 Non-smoking Vehicle3  \
# 0                   NaN                   NaN                  NaN
# 1                   NaN                   NaN                  NaN
# 2                   NaN                   NaN                  NaN
# 3                   NaN                   NaN               Euro 6
# 4                   NaN                   NaN                  NaN
#
#   Non-smoking Vehicle4  Non-smoking Vehicle5 Non-smoking Vehicle6  \
# 0                  NaN                   NaN                  NaN
# 1                  NaN                   NaN                  NaN
# 2                  NaN                   NaN                  NaN
# 3                  NaN                   NaN                  NaN
# 4                  NaN                   NaN                  NaN
#
#    Non-smoking Vehicle7 Non-smoking Vehicle8  Non-smoking Vehicle9  Model1  \
# 0                   NaN                  NaN                   NaN     NaN
# 1                   NaN                  NaN                   NaN     NaN
# 2                   NaN                  NaN                   NaN     NaN
# 3                   NaN                  NaN                   NaN     NaN
# 4                   NaN                  NaN                   NaN     NaN
#
#   Model2  Model3  First Registration1 First Registration2  \
# 0     A1     NaN                  NaN                2016
# 1     A1     NaN                  NaN                2017
# 2     A1     NaN                  NaN                2016
# 3     A1     NaN                  NaN                2016
# 4     A1     NaN                  NaN                2016
#
#    First Registration3  Body Color1 Body Color2  Body Color3 Paint Type  \
# 0                  NaN          NaN       Black          NaN   Metallic
# 1                  NaN          NaN         Red          NaN        NaN
# 2                  NaN          NaN       Black          NaN   Metallic
# 3                  NaN          NaN       Brown          NaN   Metallic
# 4                  NaN          NaN       Black          NaN   Metallic
#
#       Body Color Original    Upholstery  Body1   Body2  Body3 Nr. of Doors  \
# 0           Mythosschwarz  Cloth, Black    NaN  Sedans    NaN            5
# 1                     NaN   Cloth, Grey    NaN  Sedans    NaN            3
# 2  mythosschwarz metallic  Cloth, Black    NaN  Sedans    NaN            4
# 3                     NaN           NaN    NaN  Sedans    NaN            3
# 4  Mythosschwarz Metallic  Cloth, Black    NaN  Sedans    NaN            5
#
#   Nr. of Seats  Gearing Type1 Gearing Type2  Gearing Type3 Displacement  \
# 0            5            NaN     Automatic            NaN     1,422 cc
# 1            4            NaN     Automatic            NaN     1,798 cc
# 2            4            NaN     Automatic            NaN     1,598 cc
# 3            4            NaN     Automatic            NaN     1,422 cc
# 4            5            NaN     Automatic            NaN     1,422 cc
#
#   Cylinders Drive chain  Fuel1                        Fuel2  Fuel3  \
# 0         3       front    NaN  Diesel (Particulate Filter)    NaN
# 1         4       front    NaN                     Gasoline    NaN
# 2       NaN       front    NaN  Diesel (Particulate Filter)    NaN
# 3         3         NaN    NaN  Diesel (Particulate Filter)    NaN
# 4         3       front    NaN  Diesel (Particulate Filter)    NaN
#
#   Consumption4  Consumption5 Consumption6  Consumption7        CO2 Emission1  \
# 0          NaN           NaN          NaN           NaN   99 g CO2/km (comb)
# 1          NaN           NaN          NaN           NaN  129 g CO2/km (comb)
# 2          NaN           NaN          NaN           NaN   99 g CO2/km (comb)
# 3          NaN           NaN          NaN           NaN   99 g CO2/km (comb)
# 4          NaN           NaN          NaN           NaN  109 g CO2/km (comb)
#
#    CO2 Emission2  CO2 Emission3 Emission Class1  Emission Class2  \
# 0            NaN            NaN          Euro 6              NaN
# 1            NaN            NaN          Euro 6              NaN
# 2            NaN            NaN          Euro 6              NaN
# 3            NaN            NaN          Euro 6              NaN
# 4            NaN            NaN          Euro 6              NaN
#
#    Emission Class3 Emission Label1  Emission Label2  Emission Label3 Gears  \
# 0              NaN             NaN              NaN              NaN   NaN
# 1              NaN       4 (Green)              NaN              NaN     7
# 2              NaN       4 (Green)              NaN              NaN   NaN
# 3              NaN             NaN              NaN              NaN     6
# 4              NaN             NaN              NaN              NaN   NaN
#
#   Country version Electricity consumption Last Service Date1  \
# 0             NaN                     NaN                NaN
# 1             NaN                     NaN                NaN
# 2             NaN                     NaN                NaN
# 3             NaN                     NaN                NaN
# 4         Germany                     NaN                NaN
#
#   Last Service Date2 Last Service Date3  Last Service Date4  \
# 0                NaN                NaN                 NaN
# 1                NaN                NaN                 NaN
# 2                NaN                NaN                 NaN
# 3                NaN                NaN                 NaN
# 4                NaN                NaN                 NaN
#
#   Last Service Date5  Last Service Date6 Last Service Date7  \
# 0                NaN                 NaN                NaN
# 1                NaN                 NaN                NaN
# 2                NaN                 NaN                NaN
# 3                NaN                 NaN                NaN
# 4                NaN                 NaN                NaN
#
#    Last Service Date8  Other Fuel Types1  Other Fuel Types2  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 4                 NaN                NaN                NaN
#
#    Other Fuel Types3 Last Timing Belt Service Date1  \
# 0                NaN                            NaN
# 1                NaN                            NaN
# 2                NaN                            NaN
# 3                NaN                            NaN
# 4                NaN                            NaN
#
#   Last Timing Belt Service Date2         Consumption1         Consumption2  \
# 0                            NaN  3.8 l/100 km (comb)  4.3 l/100 km (city)
# 1                            NaN  5.6 l/100 km (comb)  7.1 l/100 km (city)
# 2                            NaN  3.8 l/100 km (comb)  4.4 l/100 km (city)
# 3                            NaN  3.8 l/100 km (comb)  4.3 l/100 km (city)
# 4                            NaN  4.1 l/100 km (comb)  4.6 l/100 km (city)
#
#              Consumption3
# 0  3.5 l/100 km (country)
# 1  4.7 l/100 km (country)
# 2  3.4 l/100 km (country)
# 3  3.5 l/100 km (country)
# 4  3.8 l/100 km (country)

# %% [markdown]
# # Drop Columns

# %%
#drop columns that has lower than 30 percent valid value in it.
drop_30Perc = [i for i in df.columns if round(df[i].notna().mean()*100,2) < 30]
drop_30Perc
# Out:
# ['kW',
#  'Availability',
#  'Available from',
#  'Type1',
#  'Type3',
#  'Previous Owners2',
#  'Previous Owners3',
#  'Previous Owners4',
#  'Previous Owners5',
#  'Previous Owners6',
#  'Previous Owners7',
#  'Previous Owners8',
#  'Next Inspection1',
#  'Next Inspection2',
#  'Next Inspection3',
#  'Next Inspection4',
#  'Next Inspection5',
#  'Next Inspection6',
#  'Next Inspection7',
#  'Next Inspection8',
#  'Inspection new1',
#  'Inspection new2',
#  'Inspection new3',
#  'Inspection new4',
#  'Inspection new5',
#  'Inspection new6',
#  'Inspection new7',
#  'Inspection new8',
#  'Warranty2',
#  'Warranty3',
#  'Warranty4',
#  'Warranty5',
#  'Warranty6',
#  'Warranty7',
#  'Warranty8',
#  'Warranty9',
#  'Full Service1',
#  'Full Service2',
#  'Full Service4',
#  'Full Service5',
#  'Full Service6',
#  'Full Service7',
#  'Full Service8',
#  'Full Service9',
#  'Non-smoking Vehicle1',
#  'Non-smoking Vehicle2',
#  'Non-smoking Vehicle3',
#  'Non-smoking Vehicle4',
#  'Non-smoking Vehicle5',
#  'Non-smoking Vehicle6',
#  'Non-smoking Vehicle7',
#  'Non-smoking Vehicle8',
#  'Non-smoking Vehicle9',
#  'Model1',
#  'Model3',
#  'First Registration1',
#  'First Registration3',
#  'Body Color1',
#  'Body Color3',
#  'Body1',
#  'Body3',
#  'Gearing Type1',
#  'Gearing Type3',
#  'Fuel1',
#  'Fuel3',
#  'Consumption4',
#  'Consumption5',
#  'Consumption6',
#  'Consumption7',
#  'CO2 Emission2',
#  'CO2 Emission3',
#  'Emission Class2',
#  'Emission Class3',
#  'Emission Label1',
#  'Emission Label2',
#  'Emission Label3',
#  'Electricity consumption',
#  'Last Service Date1',
#  'Last Service Date2',
#  'Last Service Date3',
#  'Last Service Date4',
#  'Last Service Date5',
#  'Last Service Date6',
#  'Last Service Date7',
#  'Last Service Date8',
#  'Other Fuel Types1',
#  'Other Fuel Types2',
#  'Other Fuel Types3',
#  'Last Timing Belt Service Date1',
#  'Last Timing Belt Service Date2']

# %%
df.drop(drop_30Perc,axis=1,inplace=True)

# %%
#drop unnecessary columns #subjectif decision

#no need = 'url', 'description','Offer Number'
#same info already exist = "make_model","Body2", "prev_owner"
unnecassary_columns = ['url', 'description', 'Offer Number',"make_model","Body2"\
                       ,"prev_owner","Model Code","Weight"\
                      ,"Full Service","Full Service3","Type4"]
for i in unnecassary_columns:
    try:
        df.drop(i,axis=1,inplace=True)
    except:
        pass

# %%
df.head()
# Out:
#                                    short_description body_type  price  \
# 0        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                     1.8 TFSI sport    Sedans  14500
# 2  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
# 3                            1.4 TDi Design S tronic    Sedans  14500
# 4  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans  16790
#
#                 vat         km registration      hp  Make  \
# 0    VAT deductible  56,013 km      01/2016   66 kW  Audi
# 1  Price negotiable  80,000 km      03/2017  141 kW  Audi
# 2    VAT deductible  83,450 km      02/2016   85 kW  Audi
# 3              None  73,000 km      08/2016   66 kW  Audi
# 4              None  16,200 km      05/2016   66 kW  Audi
#
#   Comfort & Convenience 1 Air conditioning  \
# 0                                     True
# 1                                     True
# 2                                     True
# 3                                    False
# 4                                     True
#
#   Comfort & Convenience 2 Air suspension Comfort & Convenience 3 Armrest  \
# 0                                  False                            True
# 1                                  False                           False
# 2                                  False                           False
# 3                                   True                            True
# 4                                  False                            True
#
#   Comfort & Convenience 4 Automatic climate control  \
# 0                                              True
# 1                                              True
# 2                                             False
# 3                                             False
# 4                                              True
#
#   Comfort & Convenience 5 Auxiliary heating  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                      True
# 4                                     False
#
#   Comfort & Convenience 6 Cruise control  \
# 0                                   True
# 1                                  False
# 2                                   True
# 3                                  False
# 4                                  False
#
#   Comfort & Convenience 7 Electric Starter  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#   Comfort & Convenience 8 Electric tailgate  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#   Comfort & Convenience 9 Electrical side mirrors  \
# 0                                            True
# 1                                           False
# 2                                            True
# 3                                            True
# 4                                            True
#
#   Comfort & Convenience 10 Electrically adjustable seats  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 11 Electrically heated windshield  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 12 Heads-up display  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                      True
# 4                                     False
#
#   Comfort & Convenience 13 Heated steering wheel  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#   Comfort & Convenience 14 Hill Holder  \
# 0                                 True
# 1                                 True
# 2                                 True
# 3                                 True
# 4                                 True
#
#   Comfort & Convenience 15 Keyless central door lock  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 16 Leather seats  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Comfort & Convenience 17 Leather steering wheel  \
# 0                                            True
# 1                                            True
# 2                                            True
# 3                                            True
# 4                                            True
#
#   Comfort & Convenience 18 Light sensor  \
# 0                                  True
# 1                                 False
# 2                                 False
# 3                                  True
# 4                                  True
#
#   Comfort & Convenience 19 Lumbar support  \
# 0                                   False
# 1                                    True
# 2                                   False
# 3                                    True
# 4                                   False
#
#   Comfort & Convenience 20 Massage seats  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Comfort & Convenience 21 Multi-function steering wheel  \
# 0                                               True
# 1                                              False
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Comfort & Convenience 22 Navigation system  \
# 0                                       True
# 1                                      False
# 2                                       True
# 3                                       True
# 4                                      False
#
#   Comfort & Convenience 23 Panorama roof  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Comfort & Convenience 24 Park Distance Control  \
# 0                                           True
# 1                                          False
# 2                                           True
# 3                                          False
# 4                                           True
#
#   Comfort & Convenience 25 Parking assist system camera  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 26 Parking assist system self-steering  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 27 Parking assist system sensors front  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 28 Parking assist system sensors rear  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                              False
# 4                                               True
#
#   Comfort & Convenience 29 Power windows Comfort & Convenience 30 Rain sensor  \
# 0                                   True                                 True
# 1                                   True                                False
# 2                                   True                                False
# 3                                   True                                 True
# 4                                   True                                 True
#
#   Comfort & Convenience 31 Seat heating  \
# 0                                  True
# 1                                 False
# 2                                  True
# 3                                  True
# 4                                 False
#
#   Comfort & Convenience 32 Seat ventilation  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#   Comfort & Convenience 33 Split rear seats  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                      True
# 4                                     False
#
#   Comfort & Convenience 34 Start-stop system Comfort & Convenience 35 Sunroof  \
# 0                                       True                            False
# 1                                       True                            False
# 2                                       True                            False
# 3                                       True                            False
# 4                                       True                            False
#
#   Comfort & Convenience 36 Tinted windows  \
# 0                                   False
# 1                                    True
# 2                                   False
# 3                                   False
# 4                                   False
#
#   Comfort & Convenience 37 Wind deflector Comfort & Convenience 38 Windshield  \
# 0                                   False                               False
# 1                                   False                               False
# 2                                   False                               False
# 3                                   False                               False
# 4                                   False                               False
#
#   Safety & Security 1 ABS Safety & Security 2 Adaptive Cruise Control  \
# 0                    True                                       False
# 1                    True                                       False
# 2                    True                                       False
# 3                    True                                       False
# 4                    True                                       False
#
#   Safety & Security 3 Adaptive headlights Safety & Security 4 Alarm system  \
# 0                                   False                            False
# 1                                   False                            False
# 2                                   False                            False
# 3                                   False                             True
# 4                                   False                            False
#
#   Safety & Security 5 Blind spot monitor  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Safety & Security 6 Central door lock  \
# 0                                  True
# 1                                  True
# 2                                  True
# 3                                 False
# 4                                  True
#
#   Safety & Security 7 Central door lock with remote control  \
# 0                                              False
# 1                                               True
# 2                                              False
# 3                                               True
# 4                                              False
#
#   Safety & Security 8 Daytime running lights  \
# 0                                       True
# 1                                       True
# 2                                       True
# 3                                      False
# 4                                      False
#
#   Safety & Security 9 Driver drowsiness detection  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                            True
# 4                                           False
#
#   Safety & Security 10 Driver-side airbag  \
# 0                                    True
# 1                                    True
# 2                                    True
# 3                                    True
# 4                                    True
#
#   Safety & Security 11 Electronic stability control  \
# 0                                              True
# 1                                              True
# 2                                              True
# 3                                              True
# 4                                              True
#
#   Safety & Security 12 Emergency brake assistant  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#   Safety & Security 13 Emergency system Safety & Security 14 Fog lights  \
# 0                                 False                            True
# 1                                 False                           False
# 2                                 False                           False
# 3                                  True                           False
# 4                                 False                            True
#
#   Safety & Security 15 Head airbag Safety & Security 16 Immobilizer  \
# 0                            False                             True
# 1                             True                             True
# 2                            False                             True
# 3                             True                             True
# 4                            False                             True
#
#   Safety & Security 17 Isofix Safety & Security 18 LED Daytime Running Lights  \
# 0                        True                                           False
# 1                        True                                           False
# 2                        True                                           False
# 3                        True                                           False
# 4                        True                                           False
#
#   Safety & Security 19 LED Headlights  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
#
#   Safety & Security 20 Lane departure warning system  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Safety & Security 21 Night view assist  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Safety & Security 22 Passenger-side airbag  \
# 0                                       True
# 1                                       True
# 2                                       True
# 3                                       True
# 4                                       True
#
#   Safety & Security 23 Power steering Safety & Security 24 Rear airbag  \
# 0                                True                            False
# 1                                True                            False
# 2                                True                            False
# 3                                True                            False
# 4                                True                            False
#
#   Safety & Security 25 Side airbag  \
# 0                             True
# 1                             True
# 2                             True
# 3                             True
# 4                             True
#
#   Safety & Security 26 Tire pressure monitoring system  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Safety & Security 27 Traction control  \
# 0                                  True
# 1                                  True
# 2                                  True
# 3                                 False
# 4                                  True
#
#   Safety & Security 28 Traffic sign recognition  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#   Safety & Security 29 Xenon headlights Extras 1 Alloy wheels  \
# 0                                  True                  True
# 1                                  True                  True
# 2                                 False                  True
# 3                                 False                  True
# 4                                  True                  True
#
#   Extras 2 Cab or rented Car Extras 3 Catalytic Converter  \
# 0                      False                         True
# 1                      False                        False
# 2                      False                        False
# 3                      False                        False
# 4                      False                        False
#
#   Extras 4 Handicapped enabled Extras 5 Right hand drive Extras 6 Roof rack  \
# 0                        False                     False              False
# 1                        False                     False              False
# 2                        False                     False              False
# 3                        False                     False              False
# 4                        False                     False              False
#
#   Extras 7 Shift paddles Extras 8 Ski bag Extras 9 Sliding door  \
# 0                  False            False                 False
# 1                  False            False                 False
# 2                  False            False                 False
# 3                  False            False                 False
# 4                  False            False                 False
#
#   Extras 10 Sport package Extras 11 Sport seats Extras 12 Sport suspension  \
# 0                   False                 False                      False
# 1                   False                  True                       True
# 2                   False                 False                      False
# 3                   False                  True                      False
# 4                    True                 False                       True
#
#   Extras 13 Touch screen Extras 14 Trailer hitch Extras 15 Tuned car  \
# 0                  False                   False               False
# 1                  False                   False               False
# 2                  False                   False               False
# 3                  False                   False               False
# 4                  False                   False               False
#
#   Extras 16 Voice Control Extras 17 Winter tyres  \
# 0                    True                  False
# 1                    True                  False
# 2                    True                  False
# 3                    True                  False
# 4                    True                  False
#
#   Entertainment & Media 1 Bluetooth Entertainment & Media 2 CD player  \
# 0                              True                             False
# 1                              True                             False
# 2                             False                             False
# 3                              True                              True
# 4                              True                              True
#
#   Entertainment & Media 3 Digital radio  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#   Entertainment & Media 4 Hands-free equipment Entertainment & Media 5 MP3  \
# 0                                         True                       False
# 1                                         True                       False
# 2                                        False                        True
# 3                                         True                        True
# 4                                         True                        True
#
#   Entertainment & Media 6 On-board computer Entertainment & Media 7 Radio  \
# 0                                      True                          True
# 1                                      True                          True
# 2                                      True                         False
# 3                                      True                          True
# 4                                      True                          True
#
#   Entertainment & Media 8 Sound system Entertainment & Media 9 Television  \
# 0                                False                              False
# 1                                 True                              False
# 2                                False                              False
# 3                                 True                              False
# 4                                False                              False
#
#   Entertainment & Media 10 USB Type2 Previous Owners1 Warranty1 Model2  \
# 0                        False  Used                2       NaN     A1
# 1                        False  Used              NaN       NaN     A1
# 2                        False  Used                1       NaN     A1
# 3                         True  Used                1       NaN     A1
# 4                         True  Used                1       NaN     A1
#
#   First Registration2 Body Color2 Paint Type     Body Color Original  \
# 0                2016       Black   Metallic           Mythosschwarz
# 1                2017         Red        NaN                     NaN
# 2                2016       Black   Metallic  mythosschwarz metallic
# 3                2016       Brown   Metallic                     NaN
# 4                2016       Black   Metallic  Mythosschwarz Metallic
#
#      Upholstery Nr. of Doors Nr. of Seats Gearing Type2 Displacement  \
# 0  Cloth, Black            5            5     Automatic     1,422 cc
# 1   Cloth, Grey            3            4     Automatic     1,798 cc
# 2  Cloth, Black            4            4     Automatic     1,598 cc
# 3           NaN            3            4     Automatic     1,422 cc
# 4  Cloth, Black            5            5     Automatic     1,422 cc
#
#   Cylinders Drive chain                        Fuel2        CO2 Emission1  \
# 0         3       front  Diesel (Particulate Filter)   99 g CO2/km (comb)
# 1         4       front                     Gasoline  129 g CO2/km (comb)
# 2       NaN       front  Diesel (Particulate Filter)   99 g CO2/km (comb)
# 3         3         NaN  Diesel (Particulate Filter)   99 g CO2/km (comb)
# 4         3       front  Diesel (Particulate Filter)  109 g CO2/km (comb)
#
#   Emission Class1 Gears Country version         Consumption1  \
# 0          Euro 6   NaN             NaN  3.8 l/100 km (comb)
# 1          Euro 6     7             NaN  5.6 l/100 km (comb)
# 2          Euro 6   NaN             NaN  3.8 l/100 km (comb)
# 3          Euro 6     6             NaN  3.8 l/100 km (comb)
# 4          Euro 6   NaN         Germany  4.1 l/100 km (comb)
#
#           Consumption2            Consumption3
# 0  4.3 l/100 km (city)  3.5 l/100 km (country)
# 1  7.1 l/100 km (city)  4.7 l/100 km (country)
# 2  4.4 l/100 km (city)  3.4 l/100 km (country)
# 3  4.3 l/100 km (city)  3.5 l/100 km (country)
# 4  4.6 l/100 km (city)  3.8 l/100 km (country)

# %% [markdown]
# # Crop extra info from cells

# %%
#Delete "km" from km column
df["km"] = df["km"].apply(lambda x : x.replace(",","").replace("-","0") if type(x)==str else x)
df['km'] = df['km'].apply(lambda x : x.split("km")[0].strip())

#Delete "cc" from Displacement column
df['Displacement'] = df['Displacement'].apply(lambda x : x if pd.isna(x) else x.split("cc")[0].strip())
df.rename(columns={'Displacement': 'Displacement (cc)'},inplace=True)
df["Displacement (cc)"] = df["Displacement (cc)"].apply(lambda x : round(int(x.replace(",",""))/1000,1) if type(x)==str else x)

#Delete "kW" from hp column
df['hp'] = df['hp'].apply(lambda x : x if pd.isna(x) else x.split("kW")[0].strip())
df.rename(columns={'hp': 'hp (kW)'},inplace=True)

#extract 1 digit for emission class like 6 4 etc.
df['Emission Class1'] = df['Emission Class1'].str.extract('(\d)').rename(columns={0: 'Emission Class Euro'})

#extract CO2 Emission digits
df['CO2 Emission1'] = df['CO2 Emission1'].apply(lambda x : x if pd.isna(x) else x.split(" ")[0])
df.rename(columns={'CO2 Emission1': 'CO2 Emission (g CO2/km (comb))'},inplace=True)

# extract consumption columns to digits
df['Consumption1'] = df['Consumption1'].apply(lambda x : x if pd.isna(x) else x.split(" ")[0].strip())
df.rename(columns={'Consumption1': 'Consumption l/100 km (comb)'},inplace=True)
df['Consumption2'] = df['Consumption2'].apply(lambda x : x if pd.isna(x) else x.split(" ")[0].strip())
df.rename(columns={'Consumption2': 'Consumption l/100 km (city)'},inplace=True)
df['Consumption3'] = df['Consumption3'].apply(lambda x : x if pd.isna(x) else x.split(" ")[0].strip())
df.rename(columns={'Consumption3': 'Consumption l/100 km (country)'},inplace=True)

# %%
df.head(3)
# Out:
#                                    short_description body_type  price  \
# 0        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                     1.8 TFSI sport    Sedans  14500
# 2  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
#
#                 vat     km registration hp (kW)  Make  \
# 0    VAT deductible  56013      01/2016      66  Audi
# 1  Price negotiable  80000      03/2017     141  Audi
# 2    VAT deductible  83450      02/2016      85  Audi
#
#   Comfort & Convenience 1 Air conditioning  \
# 0                                     True
# 1                                     True
# 2                                     True
#
#   Comfort & Convenience 2 Air suspension Comfort & Convenience 3 Armrest  \
# 0                                  False                            True
# 1                                  False                           False
# 2                                  False                           False
#
#   Comfort & Convenience 4 Automatic climate control  \
# 0                                              True
# 1                                              True
# 2                                             False
#
#   Comfort & Convenience 5 Auxiliary heating  \
# 0                                     False
# 1                                     False
# 2                                     False
#
#   Comfort & Convenience 6 Cruise control  \
# 0                                   True
# 1                                  False
# 2                                   True
#
#   Comfort & Convenience 7 Electric Starter  \
# 0                                    False
# 1                                    False
# 2                                    False
#
#   Comfort & Convenience 8 Electric tailgate  \
# 0                                     False
# 1                                     False
# 2                                     False
#
#   Comfort & Convenience 9 Electrical side mirrors  \
# 0                                            True
# 1                                           False
# 2                                            True
#
#   Comfort & Convenience 10 Electrically adjustable seats  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#   Comfort & Convenience 11 Electrically heated windshield  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#   Comfort & Convenience 12 Heads-up display  \
# 0                                     False
# 1                                     False
# 2                                     False
#
#   Comfort & Convenience 13 Heated steering wheel  \
# 0                                          False
# 1                                          False
# 2                                          False
#
#   Comfort & Convenience 14 Hill Holder  \
# 0                                 True
# 1                                 True
# 2                                 True
#
#   Comfort & Convenience 15 Keyless central door lock  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#   Comfort & Convenience 16 Leather seats  \
# 0                                  False
# 1                                  False
# 2                                  False
#
#   Comfort & Convenience 17 Leather steering wheel  \
# 0                                            True
# 1                                            True
# 2                                            True
#
#   Comfort & Convenience 18 Light sensor  \
# 0                                  True
# 1                                 False
# 2                                 False
#
#   Comfort & Convenience 19 Lumbar support  \
# 0                                   False
# 1                                    True
# 2                                   False
#
#   Comfort & Convenience 20 Massage seats  \
# 0                                  False
# 1                                  False
# 2                                  False
#
#   Comfort & Convenience 21 Multi-function steering wheel  \
# 0                                               True
# 1                                              False
# 2                                               True
#
#   Comfort & Convenience 22 Navigation system  \
# 0                                       True
# 1                                      False
# 2                                       True
#
#   Comfort & Convenience 23 Panorama roof  \
# 0                                  False
# 1                                  False
# 2                                  False
#
#   Comfort & Convenience 24 Park Distance Control  \
# 0                                           True
# 1                                          False
# 2                                           True
#
#   Comfort & Convenience 25 Parking assist system camera  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#   Comfort & Convenience 26 Parking assist system self-steering  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#   Comfort & Convenience 27 Parking assist system sensors front  \
# 0                                              False
# 1                                              False
# 2                                               True
#
#   Comfort & Convenience 28 Parking assist system sensors rear  \
# 0                                               True
# 1                                               True
# 2                                               True
#
#   Comfort & Convenience 29 Power windows Comfort & Convenience 30 Rain sensor  \
# 0                                   True                                 True
# 1                                   True                                False
# 2                                   True                                False
#
#   Comfort & Convenience 31 Seat heating  \
# 0                                  True
# 1                                 False
# 2                                  True
#
#   Comfort & Convenience 32 Seat ventilation  \
# 0                                     False
# 1                                     False
# 2                                     False
#
#   Comfort & Convenience 33 Split rear seats  \
# 0                                     False
# 1                                     False
# 2                                     False
#
#   Comfort & Convenience 34 Start-stop system Comfort & Convenience 35 Sunroof  \
# 0                                       True                            False
# 1                                       True                            False
# 2                                       True                            False
#
#   Comfort & Convenience 36 Tinted windows  \
# 0                                   False
# 1                                    True
# 2                                   False
#
#   Comfort & Convenience 37 Wind deflector Comfort & Convenience 38 Windshield  \
# 0                                   False                               False
# 1                                   False                               False
# 2                                   False                               False
#
#   Safety & Security 1 ABS Safety & Security 2 Adaptive Cruise Control  \
# 0                    True                                       False
# 1                    True                                       False
# 2                    True                                       False
#
#   Safety & Security 3 Adaptive headlights Safety & Security 4 Alarm system  \
# 0                                   False                            False
# 1                                   False                            False
# 2                                   False                            False
#
#   Safety & Security 5 Blind spot monitor  \
# 0                                  False
# 1                                  False
# 2                                  False
#
#   Safety & Security 6 Central door lock  \
# 0                                  True
# 1                                  True
# 2                                  True
#
#   Safety & Security 7 Central door lock with remote control  \
# 0                                              False
# 1                                               True
# 2                                              False
#
#   Safety & Security 8 Daytime running lights  \
# 0                                       True
# 1                                       True
# 2                                       True
#
#   Safety & Security 9 Driver drowsiness detection  \
# 0                                           False
# 1                                           False
# 2                                           False
#
#   Safety & Security 10 Driver-side airbag  \
# 0                                    True
# 1                                    True
# 2                                    True
#
#   Safety & Security 11 Electronic stability control  \
# 0                                              True
# 1                                              True
# 2                                              True
#
#   Safety & Security 12 Emergency brake assistant  \
# 0                                          False
# 1                                          False
# 2                                          False
#
#   Safety & Security 13 Emergency system Safety & Security 14 Fog lights  \
# 0                                 False                            True
# 1                                 False                           False
# 2                                 False                           False
#
#   Safety & Security 15 Head airbag Safety & Security 16 Immobilizer  \
# 0                            False                             True
# 1                             True                             True
# 2                            False                             True
#
#   Safety & Security 17 Isofix Safety & Security 18 LED Daytime Running Lights  \
# 0                        True                                           False
# 1                        True                                           False
# 2                        True                                           False
#
#   Safety & Security 19 LED Headlights  \
# 0                               False
# 1                               False
# 2                               False
#
#   Safety & Security 20 Lane departure warning system  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#   Safety & Security 21 Night view assist  \
# 0                                  False
# 1                                  False
# 2                                  False
#
#   Safety & Security 22 Passenger-side airbag  \
# 0                                       True
# 1                                       True
# 2                                       True
#
#   Safety & Security 23 Power steering Safety & Security 24 Rear airbag  \
# 0                                True                            False
# 1                                True                            False
# 2                                True                            False
#
#   Safety & Security 25 Side airbag  \
# 0                             True
# 1                             True
# 2                             True
#
#   Safety & Security 26 Tire pressure monitoring system  \
# 0                                               True
# 1                                               True
# 2                                               True
#
#   Safety & Security 27 Traction control  \
# 0                                  True
# 1                                  True
# 2                                  True
#
#   Safety & Security 28 Traffic sign recognition  \
# 0                                         False
# 1                                         False
# 2                                         False
#
#   Safety & Security 29 Xenon headlights Extras 1 Alloy wheels  \
# 0                                  True                  True
# 1                                  True                  True
# 2                                 False                  True
#
#   Extras 2 Cab or rented Car Extras 3 Catalytic Converter  \
# 0                      False                         True
# 1                      False                        False
# 2                      False                        False
#
#   Extras 4 Handicapped enabled Extras 5 Right hand drive Extras 6 Roof rack  \
# 0                        False                     False              False
# 1                        False                     False              False
# 2                        False                     False              False
#
#   Extras 7 Shift paddles Extras 8 Ski bag Extras 9 Sliding door  \
# 0                  False            False                 False
# 1                  False            False                 False
# 2                  False            False                 False
#
#   Extras 10 Sport package Extras 11 Sport seats Extras 12 Sport suspension  \
# 0                   False                 False                      False
# 1                   False                  True                       True
# 2                   False                 False                      False
#
#   Extras 13 Touch screen Extras 14 Trailer hitch Extras 15 Tuned car  \
# 0                  False                   False               False
# 1                  False                   False               False
# 2                  False                   False               False
#
#   Extras 16 Voice Control Extras 17 Winter tyres  \
# 0                    True                  False
# 1                    True                  False
# 2                    True                  False
#
#   Entertainment & Media 1 Bluetooth Entertainment & Media 2 CD player  \
# 0                              True                             False
# 1                              True                             False
# 2                             False                             False
#
#   Entertainment & Media 3 Digital radio  \
# 0                                 False
# 1                                 False
# 2                                 False
#
#   Entertainment & Media 4 Hands-free equipment Entertainment & Media 5 MP3  \
# 0                                         True                       False
# 1                                         True                       False
# 2                                        False                        True
#
#   Entertainment & Media 6 On-board computer Entertainment & Media 7 Radio  \
# 0                                      True                          True
# 1                                      True                          True
# 2                                      True                         False
#
#   Entertainment & Media 8 Sound system Entertainment & Media 9 Television  \
# 0                                False                              False
# 1                                 True                              False
# 2                                False                              False
#
#   Entertainment & Media 10 USB Type2 Previous Owners1 Warranty1 Model2  \
# 0                        False  Used                2       NaN     A1
# 1                        False  Used              NaN       NaN     A1
# 2                        False  Used                1       NaN     A1
#
#   First Registration2 Body Color2 Paint Type     Body Color Original  \
# 0                2016       Black   Metallic           Mythosschwarz
# 1                2017         Red        NaN                     NaN
# 2                2016       Black   Metallic  mythosschwarz metallic
#
#      Upholstery Nr. of Doors Nr. of Seats Gearing Type2  Displacement (cc)  \
# 0  Cloth, Black            5            5     Automatic                1.4
# 1   Cloth, Grey            3            4     Automatic                1.8
# 2  Cloth, Black            4            4     Automatic                1.6
#
#   Cylinders Drive chain                        Fuel2  \
# 0         3       front  Diesel (Particulate Filter)
# 1         4       front                     Gasoline
# 2       NaN       front  Diesel (Particulate Filter)
#
#   CO2 Emission (g CO2/km (comb)) Emission Class1 Gears Country version  \
# 0                             99               6   NaN             NaN
# 1                            129               6     7             NaN
# 2                             99               6   NaN             NaN
#
#   Consumption l/100 km (comb) Consumption l/100 km (city)  \
# 0                         3.8                         4.3
# 1                         5.6                         7.1
# 2                         3.8                         4.4
#
#   Consumption l/100 km (country)
# 0                            3.5
# 1                            4.7
# 2                            3.4

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Columns: 125 entries, short_description to Consumption l/100 km (country)
# dtypes: float64(1), int64(1), object(123)
# memory usage: 15.2+ MB

# %%
#get_col_details(df,"Consumption1")

# %%
#get_col_details(df,"Emission Class1")

# %% [markdown]
# # Fill Missing Values and Move cell info to title

# %%
#grp_inx = list(df[df['make_model'] == 'Audi A3']['Body'].index)
#df[df["make_model"] == "Audi A3"]["body_type"].mode() ### Audi a3 lerdeki en cok body type.
#oto[col_name].iloc[grp_inx] = oto[col_name].iloc[grp_inx].fillna()

# %%
## First registration column to fill now if km is 0 or below 100 etc.

# %%
def fill_most(df, group_col, col_name):
    for group in list(df[group_col].unique()):
        grp_inx = list(df[df[group_col]==group][col_name].index)
        df[col_name].iloc[grp_inx] = df[col_name].iloc[grp_inx].fillna(df[df[group_col]==group][col_name].mode()[0])

# %%
#Fill previous Owners column with bfill to make homogenious distrbution
df["Previous Owners1"] =  df["Previous Owners1"].fillna(method="bfill")

# %% [markdown]
# # Feature Engineering (Column addition within)

# %%
##registration ile now arasi icin age olarak yeni bir column ekleyelim

# %% [markdown]
# # Convert Column types to Numeric, if Categorical get_dummies()

# %%
#df["Comfort&Convenience"].str.get_dummies(sep = ",")

# %% [markdown]
# # TEST

# %%
df.head(3)
# Out:
#                                    short_description body_type  price  \
# 0        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                     1.8 TFSI sport    Sedans  14500
# 2  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
#
#                 vat     km registration hp (kW)  Make  \
# 0    VAT deductible  56013      01/2016      66  Audi
# 1  Price negotiable  80000      03/2017     141  Audi
# 2    VAT deductible  83450      02/2016      85  Audi
#
#   Comfort & Convenience 1 Air conditioning  \
# 0                                     True
# 1                                     True
# 2                                     True
#
#   Comfort & Convenience 2 Air suspension Comfort & Convenience 3 Armrest  \
# 0                                  False                            True
# 1                                  False                           False
# 2                                  False                           False
#
#   Comfort & Convenience 4 Automatic climate control  \
# 0                                              True
# 1                                              True
# 2                                             False
#
#   Comfort & Convenience 5 Auxiliary heating  \
# 0                                     False
# 1                                     False
# 2                                     False
#
#   Comfort & Convenience 6 Cruise control  \
# 0                                   True
# 1                                  False
# 2                                   True
#
#   Comfort & Convenience 7 Electric Starter  \
# 0                                    False
# 1                                    False
# 2                                    False
#
#   Comfort & Convenience 8 Electric tailgate  \
# 0                                     False
# 1                                     False
# 2                                     False
#
#   Comfort & Convenience 9 Electrical side mirrors  \
# 0                                            True
# 1                                           False
# 2                                            True
#
#   Comfort & Convenience 10 Electrically adjustable seats  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#   Comfort & Convenience 11 Electrically heated windshield  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#   Comfort & Convenience 12 Heads-up display  \
# 0                                     False
# 1                                     False
# 2                                     False
#
#   Comfort & Convenience 13 Heated steering wheel  \
# 0                                          False
# 1                                          False
# 2                                          False
#
#   Comfort & Convenience 14 Hill Holder  \
# 0                                 True
# 1                                 True
# 2                                 True
#
#   Comfort & Convenience 15 Keyless central door lock  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#   Comfort & Convenience 16 Leather seats  \
# 0                                  False
# 1                                  False
# 2                                  False
#
#   Comfort & Convenience 17 Leather steering wheel  \
# 0                                            True
# 1                                            True
# 2                                            True
#
#   Comfort & Convenience 18 Light sensor  \
# 0                                  True
# 1                                 False
# 2                                 False
#
#   Comfort & Convenience 19 Lumbar support  \
# 0                                   False
# 1                                    True
# 2                                   False
#
#   Comfort & Convenience 20 Massage seats  \
# 0                                  False
# 1                                  False
# 2                                  False
#
#   Comfort & Convenience 21 Multi-function steering wheel  \
# 0                                               True
# 1                                              False
# 2                                               True
#
#   Comfort & Convenience 22 Navigation system  \
# 0                                       True
# 1                                      False
# 2                                       True
#
#   Comfort & Convenience 23 Panorama roof  \
# 0                                  False
# 1                                  False
# 2                                  False
#
#   Comfort & Convenience 24 Park Distance Control  \
# 0                                           True
# 1                                          False
# 2                                           True
#
#   Comfort & Convenience 25 Parking assist system camera  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#   Comfort & Convenience 26 Parking assist system self-steering  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#   Comfort & Convenience 27 Parking assist system sensors front  \
# 0                                              False
# 1                                              False
# 2                                               True
#
#   Comfort & Convenience 28 Parking assist system sensors rear  \
# 0                                               True
# 1                                               True
# 2                                               True
#
#   Comfort & Convenience 29 Power windows Comfort & Convenience 30 Rain sensor  \
# 0                                   True                                 True
# 1                                   True                                False
# 2                                   True                                False
#
#   Comfort & Convenience 31 Seat heating  \
# 0                                  True
# 1                                 False
# 2                                  True
#
#   Comfort & Convenience 32 Seat ventilation  \
# 0                                     False
# 1                                     False
# 2                                     False
#
#   Comfort & Convenience 33 Split rear seats  \
# 0                                     False
# 1                                     False
# 2                                     False
#
#   Comfort & Convenience 34 Start-stop system Comfort & Convenience 35 Sunroof  \
# 0                                       True                            False
# 1                                       True                            False
# 2                                       True                            False
#
#   Comfort & Convenience 36 Tinted windows  \
# 0                                   False
# 1                                    True
# 2                                   False
#
#   Comfort & Convenience 37 Wind deflector Comfort & Convenience 38 Windshield  \
# 0                                   False                               False
# 1                                   False                               False
# 2                                   False                               False
#
#   Safety & Security 1 ABS Safety & Security 2 Adaptive Cruise Control  \
# 0                    True                                       False
# 1                    True                                       False
# 2                    True                                       False
#
#   Safety & Security 3 Adaptive headlights Safety & Security 4 Alarm system  \
# 0                                   False                            False
# 1                                   False                            False
# 2                                   False                            False
#
#   Safety & Security 5 Blind spot monitor  \
# 0                                  False
# 1                                  False
# 2                                  False
#
#   Safety & Security 6 Central door lock  \
# 0                                  True
# 1                                  True
# 2                                  True
#
#   Safety & Security 7 Central door lock with remote control  \
# 0                                              False
# 1                                               True
# 2                                              False
#
#   Safety & Security 8 Daytime running lights  \
# 0                                       True
# 1                                       True
# 2                                       True
#
#   Safety & Security 9 Driver drowsiness detection  \
# 0                                           False
# 1                                           False
# 2                                           False
#
#   Safety & Security 10 Driver-side airbag  \
# 0                                    True
# 1                                    True
# 2                                    True
#
#   Safety & Security 11 Electronic stability control  \
# 0                                              True
# 1                                              True
# 2                                              True
#
#   Safety & Security 12 Emergency brake assistant  \
# 0                                          False
# 1                                          False
# 2                                          False
#
#   Safety & Security 13 Emergency system Safety & Security 14 Fog lights  \
# 0                                 False                            True
# 1                                 False                           False
# 2                                 False                           False
#
#   Safety & Security 15 Head airbag Safety & Security 16 Immobilizer  \
# 0                            False                             True
# 1                             True                             True
# 2                            False                             True
#
#   Safety & Security 17 Isofix Safety & Security 18 LED Daytime Running Lights  \
# 0                        True                                           False
# 1                        True                                           False
# 2                        True                                           False
#
#   Safety & Security 19 LED Headlights  \
# 0                               False
# 1                               False
# 2                               False
#
#   Safety & Security 20 Lane departure warning system  \
# 0                                              False
# 1                                              False
# 2                                              False
#
#   Safety & Security 21 Night view assist  \
# 0                                  False
# 1                                  False
# 2                                  False
#
#   Safety & Security 22 Passenger-side airbag  \
# 0                                       True
# 1                                       True
# 2                                       True
#
#   Safety & Security 23 Power steering Safety & Security 24 Rear airbag  \
# 0                                True                            False
# 1                                True                            False
# 2                                True                            False
#
#   Safety & Security 25 Side airbag  \
# 0                             True
# 1                             True
# 2                             True
#
#   Safety & Security 26 Tire pressure monitoring system  \
# 0                                               True
# 1                                               True
# 2                                               True
#
#   Safety & Security 27 Traction control  \
# 0                                  True
# 1                                  True
# 2                                  True
#
#   Safety & Security 28 Traffic sign recognition  \
# 0                                         False
# 1                                         False
# 2                                         False
#
#   Safety & Security 29 Xenon headlights Extras 1 Alloy wheels  \
# 0                                  True                  True
# 1                                  True                  True
# 2                                 False                  True
#
#   Extras 2 Cab or rented Car Extras 3 Catalytic Converter  \
# 0                      False                         True
# 1                      False                        False
# 2                      False                        False
#
#   Extras 4 Handicapped enabled Extras 5 Right hand drive Extras 6 Roof rack  \
# 0                        False                     False              False
# 1                        False                     False              False
# 2                        False                     False              False
#
#   Extras 7 Shift paddles Extras 8 Ski bag Extras 9 Sliding door  \
# 0                  False            False                 False
# 1                  False            False                 False
# 2                  False            False                 False
#
#   Extras 10 Sport package Extras 11 Sport seats Extras 12 Sport suspension  \
# 0                   False                 False                      False
# 1                   False                  True                       True
# 2                   False                 False                      False
#
#   Extras 13 Touch screen Extras 14 Trailer hitch Extras 15 Tuned car  \
# 0                  False                   False               False
# 1                  False                   False               False
# 2                  False                   False               False
#
#   Extras 16 Voice Control Extras 17 Winter tyres  \
# 0                    True                  False
# 1                    True                  False
# 2                    True                  False
#
#   Entertainment & Media 1 Bluetooth Entertainment & Media 2 CD player  \
# 0                              True                             False
# 1                              True                             False
# 2                             False                             False
#
#   Entertainment & Media 3 Digital radio  \
# 0                                 False
# 1                                 False
# 2                                 False
#
#   Entertainment & Media 4 Hands-free equipment Entertainment & Media 5 MP3  \
# 0                                         True                       False
# 1                                         True                       False
# 2                                        False                        True
#
#   Entertainment & Media 6 On-board computer Entertainment & Media 7 Radio  \
# 0                                      True                          True
# 1                                      True                          True
# 2                                      True                         False
#
#   Entertainment & Media 8 Sound system Entertainment & Media 9 Television  \
# 0                                False                              False
# 1                                 True                              False
# 2                                False                              False
#
#   Entertainment & Media 10 USB Type2 Previous Owners1 Warranty1 Model2  \
# 0                        False  Used                2       NaN     A1
# 1                        False  Used                1       NaN     A1
# 2                        False  Used                1       NaN     A1
#
#   First Registration2 Body Color2 Paint Type     Body Color Original  \
# 0                2016       Black   Metallic           Mythosschwarz
# 1                2017         Red        NaN                     NaN
# 2                2016       Black   Metallic  mythosschwarz metallic
#
#      Upholstery Nr. of Doors Nr. of Seats Gearing Type2  Displacement (cc)  \
# 0  Cloth, Black            5            5     Automatic                1.4
# 1   Cloth, Grey            3            4     Automatic                1.8
# 2  Cloth, Black            4            4     Automatic                1.6
#
#   Cylinders Drive chain                        Fuel2  \
# 0         3       front  Diesel (Particulate Filter)
# 1         4       front                     Gasoline
# 2       NaN       front  Diesel (Particulate Filter)
#
#   CO2 Emission (g CO2/km (comb)) Emission Class1 Gears Country version  \
# 0                             99               6   NaN             NaN
# 1                            129               6     7             NaN
# 2                             99               6   NaN             NaN
#
#   Consumption l/100 km (comb) Consumption l/100 km (city)  \
# 0                         3.8                         4.3
# 1                         5.6                         7.1
# 2                         3.8                         4.4
#
#   Consumption l/100 km (country)
# 0                            3.5
# 1                            4.7
# 2                            3.4

# %%
#doldur = df[(df["Make"] == "Audi" & df["Model2"] == "A3")]["body_type"].mode()

# %%
df[(df["Make"] == "Audi") & (df["Model2"] == "A3")  ][["body_type","Displacement (cc)"]]
# Out:
#           body_type  Displacement (cc)
# 2615    Convertible                1.5
# 2616         Sedans                1.6
# 2617         Sedans                NaN
# ...             ...                ...
# 5709  Station wagon                1.0
# 5710         Sedans                1.0
# 5711         Sedans                1.0
#
# [3097 rows x 2 columns]

# %%
#df[(df["Make"] == "Audi") & (df["Model2"] == "A3")  & (df["Displacement (cc)"] == 1.5)]["body_type"].mode()[0]
def func_spec(df,target_col,col1, col2, col3):
    for group1 in list(df[col1].unique()):
        for group2 in list(df[df[col1]==group1][[col2]].unique()):
            for group3 in list(df[(df[col1]==group1) & (df[col2]==group2)][[col3]].unique()):
                grp_inx = list(df[(df[col1]==group1) & (df[col2]==group2) & (df[col3]==group3)][target_col].index)
                fill_value = df[(df[col1] == group1) & (df[col2] == group2)  & (df[col3] == group3)][target_col].mode()[0]
                df[target_col].iloc[grp_inx] = df[target_col].iloc[grp_inx].fillna(fill_value)

# %%
#func_spec(df,'body_type','Make', 'Model2', 'Displacement (cc)')

# %%
#grp_inx = list(df[df['make_model'] == 'Audi A3']['body_type'].index)
#df[df["make_model"] == "Audi A3"]["body_type"].mode() ### Audi a3 lerdeki en cok body type
#df["body_type"].iloc[grp_inx] = df["body_type"].iloc[grp_inx].fillna(doldur)

# %%
def fill_most2(df, group_col, col_name):
    for group in list(df[group_col].unique()):
        grp_inx = list(df[df[group_col]==group][col_name].index)
        df[col_name].iloc[grp_inx] = df[col_name].iloc[grp_inx].fillna(df[df[group_col]==group][col_name].mode()[0])

# %%
def fill_most2(df, ref_col, target_col):
    for group in list(df[ref_col].unique()):
        grp_inx = list(df[df[ref_col]==group][target_col].index)
        df[target_col].iloc[grp_inx] = df[target_col].iloc[grp_inx].fillna(df[df[ref_col]==group][target_col].mode()[0])

# %%
df.head(5)
# Out:
#                                    short_description body_type  price  \
# 0        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                     1.8 TFSI sport    Sedans  14500
# 2  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
# 3                            1.4 TDi Design S tronic    Sedans  14500
# 4  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans  16790
#
#                 vat     km registration hp (kW)  Make  \
# 0    VAT deductible  56013      01/2016      66  Audi
# 1  Price negotiable  80000      03/2017     141  Audi
# 2    VAT deductible  83450      02/2016      85  Audi
# 3              None  73000      08/2016      66  Audi
# 4              None  16200      05/2016      66  Audi
#
#   Comfort & Convenience 1 Air conditioning  \
# 0                                     True
# 1                                     True
# 2                                     True
# 3                                    False
# 4                                     True
#
#   Comfort & Convenience 2 Air suspension Comfort & Convenience 3 Armrest  \
# 0                                  False                            True
# 1                                  False                           False
# 2                                  False                           False
# 3                                   True                            True
# 4                                  False                            True
#
#   Comfort & Convenience 4 Automatic climate control  \
# 0                                              True
# 1                                              True
# 2                                             False
# 3                                             False
# 4                                              True
#
#   Comfort & Convenience 5 Auxiliary heating  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                      True
# 4                                     False
#
#   Comfort & Convenience 6 Cruise control  \
# 0                                   True
# 1                                  False
# 2                                   True
# 3                                  False
# 4                                  False
#
#   Comfort & Convenience 7 Electric Starter  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#   Comfort & Convenience 8 Electric tailgate  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#   Comfort & Convenience 9 Electrical side mirrors  \
# 0                                            True
# 1                                           False
# 2                                            True
# 3                                            True
# 4                                            True
#
#   Comfort & Convenience 10 Electrically adjustable seats  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 11 Electrically heated windshield  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 12 Heads-up display  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                      True
# 4                                     False
#
#   Comfort & Convenience 13 Heated steering wheel  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#   Comfort & Convenience 14 Hill Holder  \
# 0                                 True
# 1                                 True
# 2                                 True
# 3                                 True
# 4                                 True
#
#   Comfort & Convenience 15 Keyless central door lock  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 16 Leather seats  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Comfort & Convenience 17 Leather steering wheel  \
# 0                                            True
# 1                                            True
# 2                                            True
# 3                                            True
# 4                                            True
#
#   Comfort & Convenience 18 Light sensor  \
# 0                                  True
# 1                                 False
# 2                                 False
# 3                                  True
# 4                                  True
#
#   Comfort & Convenience 19 Lumbar support  \
# 0                                   False
# 1                                    True
# 2                                   False
# 3                                    True
# 4                                   False
#
#   Comfort & Convenience 20 Massage seats  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Comfort & Convenience 21 Multi-function steering wheel  \
# 0                                               True
# 1                                              False
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Comfort & Convenience 22 Navigation system  \
# 0                                       True
# 1                                      False
# 2                                       True
# 3                                       True
# 4                                      False
#
#   Comfort & Convenience 23 Panorama roof  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Comfort & Convenience 24 Park Distance Control  \
# 0                                           True
# 1                                          False
# 2                                           True
# 3                                          False
# 4                                           True
#
#   Comfort & Convenience 25 Parking assist system camera  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 26 Parking assist system self-steering  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 27 Parking assist system sensors front  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                              False
# 4                                              False
#
#   Comfort & Convenience 28 Parking assist system sensors rear  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                              False
# 4                                               True
#
#   Comfort & Convenience 29 Power windows Comfort & Convenience 30 Rain sensor  \
# 0                                   True                                 True
# 1                                   True                                False
# 2                                   True                                False
# 3                                   True                                 True
# 4                                   True                                 True
#
#   Comfort & Convenience 31 Seat heating  \
# 0                                  True
# 1                                 False
# 2                                  True
# 3                                  True
# 4                                 False
#
#   Comfort & Convenience 32 Seat ventilation  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#   Comfort & Convenience 33 Split rear seats  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                      True
# 4                                     False
#
#   Comfort & Convenience 34 Start-stop system Comfort & Convenience 35 Sunroof  \
# 0                                       True                            False
# 1                                       True                            False
# 2                                       True                            False
# 3                                       True                            False
# 4                                       True                            False
#
#   Comfort & Convenience 36 Tinted windows  \
# 0                                   False
# 1                                    True
# 2                                   False
# 3                                   False
# 4                                   False
#
#   Comfort & Convenience 37 Wind deflector Comfort & Convenience 38 Windshield  \
# 0                                   False                               False
# 1                                   False                               False
# 2                                   False                               False
# 3                                   False                               False
# 4                                   False                               False
#
#   Safety & Security 1 ABS Safety & Security 2 Adaptive Cruise Control  \
# 0                    True                                       False
# 1                    True                                       False
# 2                    True                                       False
# 3                    True                                       False
# 4                    True                                       False
#
#   Safety & Security 3 Adaptive headlights Safety & Security 4 Alarm system  \
# 0                                   False                            False
# 1                                   False                            False
# 2                                   False                            False
# 3                                   False                             True
# 4                                   False                            False
#
#   Safety & Security 5 Blind spot monitor  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Safety & Security 6 Central door lock  \
# 0                                  True
# 1                                  True
# 2                                  True
# 3                                 False
# 4                                  True
#
#   Safety & Security 7 Central door lock with remote control  \
# 0                                              False
# 1                                               True
# 2                                              False
# 3                                               True
# 4                                              False
#
#   Safety & Security 8 Daytime running lights  \
# 0                                       True
# 1                                       True
# 2                                       True
# 3                                      False
# 4                                      False
#
#   Safety & Security 9 Driver drowsiness detection  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                            True
# 4                                           False
#
#   Safety & Security 10 Driver-side airbag  \
# 0                                    True
# 1                                    True
# 2                                    True
# 3                                    True
# 4                                    True
#
#   Safety & Security 11 Electronic stability control  \
# 0                                              True
# 1                                              True
# 2                                              True
# 3                                              True
# 4                                              True
#
#   Safety & Security 12 Emergency brake assistant  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#   Safety & Security 13 Emergency system Safety & Security 14 Fog lights  \
# 0                                 False                            True
# 1                                 False                           False
# 2                                 False                           False
# 3                                  True                           False
# 4                                 False                            True
#
#   Safety & Security 15 Head airbag Safety & Security 16 Immobilizer  \
# 0                            False                             True
# 1                             True                             True
# 2                            False                             True
# 3                             True                             True
# 4                            False                             True
#
#   Safety & Security 17 Isofix Safety & Security 18 LED Daytime Running Lights  \
# 0                        True                                           False
# 1                        True                                           False
# 2                        True                                           False
# 3                        True                                           False
# 4                        True                                           False
#
#   Safety & Security 19 LED Headlights  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
#
#   Safety & Security 20 Lane departure warning system  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#   Safety & Security 21 Night view assist  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#   Safety & Security 22 Passenger-side airbag  \
# 0                                       True
# 1                                       True
# 2                                       True
# 3                                       True
# 4                                       True
#
#   Safety & Security 23 Power steering Safety & Security 24 Rear airbag  \
# 0                                True                            False
# 1                                True                            False
# 2                                True                            False
# 3                                True                            False
# 4                                True                            False
#
#   Safety & Security 25 Side airbag  \
# 0                             True
# 1                             True
# 2                             True
# 3                             True
# 4                             True
#
#   Safety & Security 26 Tire pressure monitoring system  \
# 0                                               True
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#   Safety & Security 27 Traction control  \
# 0                                  True
# 1                                  True
# 2                                  True
# 3                                 False
# 4                                  True
#
#   Safety & Security 28 Traffic sign recognition  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#   Safety & Security 29 Xenon headlights Extras 1 Alloy wheels  \
# 0                                  True                  True
# 1                                  True                  True
# 2                                 False                  True
# 3                                 False                  True
# 4                                  True                  True
#
#   Extras 2 Cab or rented Car Extras 3 Catalytic Converter  \
# 0                      False                         True
# 1                      False                        False
# 2                      False                        False
# 3                      False                        False
# 4                      False                        False
#
#   Extras 4 Handicapped enabled Extras 5 Right hand drive Extras 6 Roof rack  \
# 0                        False                     False              False
# 1                        False                     False              False
# 2                        False                     False              False
# 3                        False                     False              False
# 4                        False                     False              False
#
#   Extras 7 Shift paddles Extras 8 Ski bag Extras 9 Sliding door  \
# 0                  False            False                 False
# 1                  False            False                 False
# 2                  False            False                 False
# 3                  False            False                 False
# 4                  False            False                 False
#
#   Extras 10 Sport package Extras 11 Sport seats Extras 12 Sport suspension  \
# 0                   False                 False                      False
# 1                   False                  True                       True
# 2                   False                 False                      False
# 3                   False                  True                      False
# 4                    True                 False                       True
#
#   Extras 13 Touch screen Extras 14 Trailer hitch Extras 15 Tuned car  \
# 0                  False                   False               False
# 1                  False                   False               False
# 2                  False                   False               False
# 3                  False                   False               False
# 4                  False                   False               False
#
#   Extras 16 Voice Control Extras 17 Winter tyres  \
# 0                    True                  False
# 1                    True                  False
# 2                    True                  False
# 3                    True                  False
# 4                    True                  False
#
#   Entertainment & Media 1 Bluetooth Entertainment & Media 2 CD player  \
# 0                              True                             False
# 1                              True                             False
# 2                             False                             False
# 3                              True                              True
# 4                              True                              True
#
#   Entertainment & Media 3 Digital radio  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#   Entertainment & Media 4 Hands-free equipment Entertainment & Media 5 MP3  \
# 0                                         True                       False
# 1                                         True                       False
# 2                                        False                        True
# 3                                         True                        True
# 4                                         True                        True
#
#   Entertainment & Media 6 On-board computer Entertainment & Media 7 Radio  \
# 0                                      True                          True
# 1                                      True                          True
# 2                                      True                         False
# 3                                      True                          True
# 4                                      True                          True
#
#   Entertainment & Media 8 Sound system Entertainment & Media 9 Television  \
# 0                                False                              False
# 1                                 True                              False
# 2                                False                              False
# 3                                 True                              False
# 4                                False                              False
#
#   Entertainment & Media 10 USB Type2 Previous Owners1 Warranty1 Model2  \
# 0                        False  Used                2       NaN     A1
# 1                        False  Used                1       NaN     A1
# 2                        False  Used                1       NaN     A1
# 3                         True  Used                1       NaN     A1
# 4                         True  Used                1       NaN     A1
#
#   First Registration2 Body Color2 Paint Type     Body Color Original  \
# 0                2016       Black   Metallic           Mythosschwarz
# 1                2017         Red        NaN                     NaN
# 2                2016       Black   Metallic  mythosschwarz metallic
# 3                2016       Brown   Metallic                     NaN
# 4                2016       Black   Metallic  Mythosschwarz Metallic
#
#      Upholstery Nr. of Doors Nr. of Seats Gearing Type2  Displacement (cc)  \
# 0  Cloth, Black            5            5     Automatic                1.4
# 1   Cloth, Grey            3            4     Automatic                1.8
# 2  Cloth, Black            4            4     Automatic                1.6
# 3           NaN            3            4     Automatic                1.4
# 4  Cloth, Black            5            5     Automatic                1.4
#
#   Cylinders Drive chain                        Fuel2  \
# 0         3       front  Diesel (Particulate Filter)
# 1         4       front                     Gasoline
# 2       NaN       front  Diesel (Particulate Filter)
# 3         3         NaN  Diesel (Particulate Filter)
# 4         3       front  Diesel (Particulate Filter)
#
#   CO2 Emission (g CO2/km (comb)) Emission Class1 Gears Country version  \
# 0                             99               6   NaN             NaN
# 1                            129               6     7             NaN
# 2                             99               6   NaN             NaN
# 3                             99               6     6             NaN
# 4                            109               6   NaN         Germany
#
#   Consumption l/100 km (comb) Consumption l/100 km (city)  \
# 0                         3.8                         4.3
# 1                         5.6                         7.1
# 2                         3.8                         4.4
# 3                         3.8                         4.3
# 4                         4.1                         4.6
#
#   Consumption l/100 km (country)
# 0                            3.5
# 1                            4.7
# 2                            3.4
# 3                            3.5
# 4                            3.8

# %%
df["Paint Type"].value_counts(dropna = False)
# Out:
# Metallic       9794
# NaN            5772
# Uni/basic       347
# Perl effect       6
# Name: Paint Type, dtype: int64

# %%
df["Country version"].value_counts(dropna = False)
# Out:
# NaN           8333
# Germany       4502
# Italy         1038
#               ...
# Slovenia         1
# Luxembourg       1
# Serbia           1
# Name: Country version, Length: 24, dtype: int64

# %%
df["Cylinders"].value_counts(dropna = False)
# Out:
# 4      8105
# NaN    5680
# 3      2104
#        ...
# 2         2
# 8         2
# 1         1
# Name: Cylinders, Length: 8, dtype: int64

# %%
df["Comfort & Convenience 1 Air conditioning"].value_counts(dropna = False)
# Out:
# True     14315
# NaN        920
# False      684
# Name: Comfort & Convenience 1 Air conditioning, dtype: int64
